# %% [markdown]
# # Artificial Intelligence for Robotics 03
#
# ## General Information:
# Please do not add or delete any cells. Answers belong into the corresponding cells (below the question). If a function is given (either as a signature or a full function), you should not change the name, arguments or return value of the function.
#
# If you encounter empty cells underneath the answer that can not be edited, please ignore them, they are for testing purposes.
#
# When editing an assignment there can be the case that there are variables in the kernel. To make sure your assignment works, please restart the kernel and run all cells before submitting (e.g. via Kernel -> Restart & Run All).
#
# Code cells where you are supposed to give your answer often include the line `raise NotImplementedError`. This makes it easier to automatically grade answers. If you edit the cell please outcomment or delete this line.
#
# ## Submission:
# Please submit your notebook via the web interface (in the main view -> Assignments -> Submit). The assignments are **due on Monday at 20:00**.
#
# ## Group Work:
# Please enter your UID (your username here) and those of your group partners into the next cell. We apply plagiarism checking, so do not submit others solutions! If an assignment has a copied solution, the task will be graded with 0 points for all people with the same solution.
#
# ## Questions about the Assignment:
# If you have questions about the assignment please post them in the LEA forum before the deadline. Don't wait until the last day to post questions!

# %% [markdown]
# ### Please add the usernames of all your team members in the manner member1, member2 in next cell (example given below)
#
# member1 = 'example'
#
# member2 = 'example2'
#
# #### If you are not working in a group, then please add member2 as none2s

# %%
# YOUR CODE HERE
member1 = 'ahoosh2s'
member2 = 'anuhel2s'
#raise NotImplementedError()

# %%
# Execute this cell to make sure you correctly filled in the usernames of the team members

def group_name_test():
    for member_id in [member1, member2]:
        assert isinstance(member_id, str), "Please give your member id as a string."
        assert len(member_id) > 0, "You need to fill in the member id for both members"
        assert member_id.endswith("2s"), "The member id should end with 2s (Your JupyterHub username)"

group_name_test() 
print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# # Task 1
#
# **[36 Point(s)]**

# %% [markdown]
# # Introduction to Algorithms
#
# You can get help from the excerpt of *Cormen’s* very nice book *Introduction to Algorithms*, available as a PDF ﬁle (`cormen_introalgorithms`) in LEA, to solve the following tasks.

# %% [markdown]
# ## Task 1.1
#
# **[10 Point(s)]**

# %% [markdown]
# ### Task 1 [10 Points]
#
# Why is a special notation needed to classify algorithms? Doesnt it suffice to merely measure the runtime in seconds? **Explain**.

# %% [markdown]
# The runtime model is not a comprehensive explanation because it is influenced by software and hardware components. Additionally, runtime does not explain the relationship between the size of the input and the growth of runtime. For example, O(n) is a linear notation, while O(n^m) is exponential in nature, with its growth far exceeding O(n) for larger inputs. The difference between algorithms in terms of runtime cannot be fully explained through runtime results alone, so comparing algorithms in terms of time-efficiency and space-efficiency is impossible using, for example, a table of different runtime tests.

# %% [markdown]
# ## Task 1.2
#
# **[6 Point(s)]**

# %% [markdown]
# ### Task 2 [6 Points]
#
# Let $g : \mathbb{N} \rightarrow \mathbb{R}+$ be an arbitrary function. The set of functions $f : \mathbb{N} \rightarrow \mathbb{R}+$, which do not gorw faster than the function $g$ after a specific point $n_0$, is denoted as $O(g(n))$. More specifically:
#
# $$
# O(g(n) := f(n) \vert \exists c \in \mathbb{R}, \exists n_o \in \mathbb{N} : 0 \leq f(n) \leq c g(n) \forall n \geq n_0)
# $$
#
# **Prove** the following:
# - $f(n) = 100n^2 \in O(n^2)$
# - $f(n) = n^6 + 100n^5 \in O(n^6)$

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Task 1.3
#
# **[3 Point(s)]**

# %% [markdown]
# ### Task 3 [3 Points]
#
# What is the asymptotic time complexity of the following python code? Assume that `ANY_CONST` is an arbitrary constant in your program, which has assigned a 2D array as its value.
#
# ```python
# sum_ = 0
# for i in range(0, J):
#     for j in range(0, K):
#         if arr[i][j] <= ANY_CONST:
#             sum_ = sum_ + arr[i][j]
#             print(sum_)
# ```

# %% [markdown]
# ## Task 1.4
#
# **[15 Point(s)]**

# %% [markdown]
# ### Task 4 [12 Points]
#
# For each function $f(n)$ and time $t$ in the following table, determine the largest size $n$ of a problem that can be solved in time $t$, assuming that the algorithm to solve the problem takes $f(n)$ microseconds.
#
# Show your **path to the solution** for:
# - $log(n)$
# - $2^n$
# - $nlog(n)$.
#
# | | 1 second | 1 minute | 1 hour | 1 day | 1 month | 1 year | 1 century |
# |-|----------|----------|--------|-------|---------|--------|-------------|
# | $\log_{10} n$ | | | | | | | |
# | $\sqrt{n}$ | | | | | | | |
# | $n$ | | | | | | | |
# | $n \log_{10} n$ | | | | | | | |
# | $n^2$ | | | | | | | |
# | $n^3$ | | | | | | | |
# | $2^n$ | | | | | | | |
# | $n!$ | | | | | | | |
#
#  > If you need to write any code, please do so in the code cell below.

# %% [markdown]
# t=log(n)⟹n=10t
#
# t=2**n ⟹ n=log2(t)
#
# n*log(n) => is calculated numerically
#
#
# | | 1 second | 1 minute | 1 hour | 1 day | 1 month | 1 year | 1 century |
# |-|----------|----------|--------|-------|---------|--------|-------------|
# | $\log_{10} n$ |107309 |181445 |1754047 |12038693 |51523268 |138503720 |428796745 |
# | $\sqrt{n}$ | |2440 |60000 |1000000 |16000000 |55000000 |179000000 |
# | $n$ |1000000 |60000000 |3600000000 |86400000000 |2592000000000 |31536000000000 |3156000000000000 |
# | $n \log_{10} n$ |16404 |162888 |1572184 |10000000 |21858983 |61963474 |185000000 |
# | $n^2$ |1000 |2449 |60000|9289 |161602 |179993 |1771012 |
# | $n^3$ |100 |394 |1442 |1987 |2954 |3110 |14621 |
# | $2^n$ |19 |25 |31 |36 |41 |43 |46 |
# | $n!$ |12 |14 |15 |16 |20 |22 |23 |

# %% [markdown]
# ## Task 1.5
#
# **[2 Point(s)]**

# %%
# YOUR CODE HERE
import numpy as np
time_in_microseconds = {
    "1 second": 1_000_000,
    "1 minute": 60_000_000,
    "1 hour": 3_600_000_000,
    "1 day": 86_400_000_000,
    "1 month": 2_592_000_000_000,
    "1 year": 31_536_000_000_000,
    "1 century": 3_156_000_000_000_000,
}

def log_n():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 1  # Start from 1 to avoid log(0)
        while n * np.log(n) <= t:  # Check for log(n) <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies log(n) <= t
    return results

# Print results
print("The results for log(n): {}".format(log_n()))

def sqrt_n():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 1  # Start from 1 to avoid sqrt(0)
        while np.sqrt(n) <= t:  # Check for sqrt(n) <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies sqrt(n) <= t
    return results

# Print formatted results
print("The results for sqrt(n): {}".format(sqrt_n()))

def calculate_n():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = t  # The largest n that can be handled in time t
        results[item] = n  # Store n directly, since n can equal t
    return results

# Print formatted results
print("The results for n: {}".format(calculate_n()))

def n_log_n():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 1  # Start from 1 to avoid log(0)
        while n * np.log(n) <= t:  # Check for n * log(n) <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies n * log(n) <= t
    return results

# Print formatted results
print("The results for n * log(n): {}".format(n_log_n()))

def n_squared():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 1  # Start from 1
        while n**2 <= t:  # Check for n^2 <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies n^2 <= t
    return results

# Print formatted results
print("The results for n^2: {}".format(n_squared()))

def n_cubed():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 1  # Start from 1
        while n**3 <= t:  # Check for n^3 <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies n^3 <= t
    return results

# Print formatted results
print("The results for n^3: {}".format(n_cubed()))

def power_of_two():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 0  # Start from 0, since 2^0 = 1
        while 2**n <= t:  # Check for 2^n <= t
            n += 1
        results[item] = n - 1  # Store the largest n that satisfies 2^n <= t
    return results

# Print formatted results
print("The results for 2^n: {}".format(power_of_two()))

def factorial_limit():
    results = {}
    for item in time_in_microseconds:
        t = time_in_microseconds[item]
        n = 0  # Start from 0 since 0! = 1
        factorial = 1  # Initialize factorial(0) = 1
        while factorial <= t:  # Check for n! <= t
            n += 1
            factorial *= n  # Calculate n! incrementally
        results[item] = n - 1  # Store the largest n that satisfies n! <= t
    return results

# Print formatted results
print("The results for n!: {}".format(factorial_limit()))

#raise NotImplementedError()

# %% [markdown]
# # Task 2
#
# **[80 Point(s)]**

# %% [markdown]
# # Uninformed Search
#
# In this Assignment you will implement the unfinformed search strategies *Breadth First Search*, *Depth First Search* and *Iterative Deepening Depth First Search*.

# %% [markdown]
# ## Task 2.1
#
# **[10 Point(s)]**

# %% [markdown]
# ## Grid World [10 Points]
#
# You will find three text files, each representing a map for the programming assignment in the maps folder. A search agent is supposed to explore each of these three maps using *breadth-first search*, *depth-first search* and *iterative-deepening depth-first search*.
#
# ### Grid World
# You will find three text files in `./Complexity_and_Uninformed_Search_files/data`, each representing a map. They are to be interpreted as follows:
# - The text file is considered a grid.
# - Each character in the text file represents a `cell` in this grid.
#   - `*`: goal
#   - `space`: free
#   - `S`: initial position of the agent
#   - Any other character represents an obstacle
#
# **Implement a parsing mechanism to load the `.txt` files into a meaningful data structure into memory. Please also fill the docstring of the function and add typehints such that I can understand what arguments are expected and what it returns.**

# %%
from typing import List, Tuple

def parse_grid(file_path: str) -> Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]:
    """
    Parses a grid map from a text file into a 2D list and identifies the start ('S') and goal ('*') positions.

    Parameters
    ----------
    file_path : str
        Path to the text file containing the grid map.

    Returns
    -------
    Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]
        - A 2D list (grid) representing the map.
        - A tuple (row, col) representing the start position ('S').
        - A tuple (row, col) representing the goal position ('*').

    Raises
    ------
    ValueError
        If the start ('S') or goal ('*') position is not found in the grid.
    """
    grid = []
    start = None
    goal = None

    # Step 1: Read the file without stripping spaces
    try:
        with open(file_path, 'r') as f:
            for line in f:
                grid.append(list(line.rstrip('\n')))  # Only remove newlines, not spaces
    except FileNotFoundError:
        raise ValueError(f"File not found: {file_path}")

    # Step 2: Find the start ('S') and goal ('*') positions
    for i in range(len(grid)):          # Loop through rows
        for j in range(len(grid[i])):  # Loop through columns
            if grid[i][j] == 'S':      # Check for start position
                start = (i, j)
            elif grid[i][j] == '*':    # Check for goal position
                goal = (i, j)

    # Ensure both start and goal positions are found
    if start is None or goal is None:
        raise ValueError("The grid must contain both a start ('S') and a goal ('*').")

    return grid, start, goal


    # YOUR CODE HERE
    #raise NotImplementedError()

# YOUR CODE HERE
#raise NotImplementedError()

# %%
# Test

# Please write your code test here!

# %% [markdown]
# ## Task 2.2
#
# **[10 Point(s)]**

# %% [markdown]
# ## Agent
# The agent must follow the following rules:
# - The agent can move from one call to another at each step.
# - The agent can **only move to the left, right, up or down** from the current position. The surrounding
# cells should be considered as the children of the current cell.
# - The agent does **not have any previous knowledge** about the environment (such as goal positions or obstacles) so it has to **explore**.
# - The agent **cannot move through obstacles** and the **map is closed**.

# %% [markdown]
# ## Path Visualization [10 Points]
#
# The function `assign_character` is used to indicate the direction of traversal of the search agent through the nodes of the search tree. Please use the following symbols for visualizing the respective movement of the agent:
#  - `U+2500`: ─
#  - `U+2502`: │
#  - `U+250C`: ┌
#  - `U+2510`: ┐
#  - `U+2514`: └
#  - `U+2518`: ┘
#  - `U+251C`: ├
#  - `U+2524`: ┤
#  - `U+252C`: ┬
#  - `U+2534`: ┴
#  - `U+253C`: ┼
#  - `U+2574`: ╴
#  - `U+2575`: ╵
#  - `U+2576`: ╶
#  - `U+2577`: ╷
#
# With the `write_to_file` function you should be able to save the individual paths to each goal, as well as the final fully explored map with the search path to a `.txt` file.
#
# 1. **Implement the `assign_character` function and complete the docstring, such that one can tell how the function is called, what it returns and how it works.**
# 1. **Implement the `write_to_file` function and comeplete the docstring.**

# %%
from typing import List, Tuple


class Node:
    """Represents a node in the search tree."""
    def __init__(self, x: int, y: int, parent=None):
        self.x = x
        self.y = y
        self.parent = parent  # Parent node for backtracking


def assign_character(maze_map: List[List[str]], current_node: Node, prev_node: Node):
    """
    Assigns characters to indicate the direction of traversal of the agent.
    
    Parameters
    ----------
    maze_map : List[List[str]]
        The grid map as a 2D list of characters.
    current_node : Node
        The current node in the path.
    prev_node : Node
        The previous node in the path.
    """
    if prev_node is None:
        return  # No character assignment for the start position

    move_x = current_node.x - prev_node.x
    move_y = current_node.y - prev_node.y

    # Determine the character based on movement direction
    if move_x == 1 and move_y == 0:     # Downward move
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_x == -1 and move_y == 0:  # Upward move
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_x == 0 and move_y == 1:   # Rightward move
        maze_map[prev_node.x][prev_node.y] = '─'
    elif move_x == 0 and move_y == -1:  # Leftward move
        maze_map[prev_node.x][prev_node.y] = '─'
    else:
        # For advanced intersections and corners, add more cases here if needed
        pass


def path_to_goal(node: Node, maze_map: List[List[str]]):
    """
    Backtracks from the goal node to the start node and assigns path characters.
    
    Parameters
    ----------
    node : Node
        The goal node to start backtracking from.
    maze_map : List[List[str]]
        The grid map as a 2D list.
    """
    while node.parent:  # Until we reach the start node
        assign_character(maze_map, node, node.parent)
        node = node.parent  # Move backward along the path
    maze_map[node.x][node.y] = 'S'  # Mark the start position explicitly


def print_path(maze_map: List[List[str]]):
    """
    Prints the current state of the grid map with the traversal path.
    
    Parameters
    ----------
    maze_map : List[List[str]]
        The grid map as a 2D list.
    """
    for row in maze_map:
        print("".join(row))
    print()


def write_to_file(file_name: str, maze_map: List[List[str]], path: str):
    """
    Writes the traversed path or fully explored map to a `.txt` file.
    
    Parameters
    ----------
    file_name : str
        The name of the output text file.
    maze_map : List[List[str]]
        The grid map as a 2D list, including the traversal path.
    path : str
        The directory where the file will be saved.
    """
    with open(path + file_name, "w", encoding="utf-8") as file:  # Specify UTF-8 encoding
        for row in maze_map:
            file.write("".join(row) + "\n")


def main():
    # Example maze map
    maze_map = [
        ['S', ' ', ' ', ' ', '*', ' '],
        [' ', '#', '#', ' ', '#', ' '],
        [' ', ' ', '#', ' ', '#', ' '],
        [' ', ' ', '#', ' ', ' ', ' '],
        [' ', ' ', ' ', ' ', '#', ' '],
    ]

    # Create nodes for testing
    start_node = Node(0, 0)  # Start position (S)
    goal_node = Node(0, 4, parent=start_node)  # Goal position (*)
    intermediate_node = Node(0, 3, parent=start_node)

    # Simulate a path
    goal_node.parent = intermediate_node
    intermediate_node.parent = start_node

    # Backtrack and mark the path
    path_to_goal(goal_node, maze_map)

    # Print the map with the path
    print("Maze with Path:")
    print_path(maze_map)

    # Save the map to a file
    write_to_file("output_maze.txt", maze_map, "./")


if __name__ == "__main__":
    main()

    # YOUR CODE HERE
    #raise NotImplementedError()

# %%
# Test

# Please write your code test here!

# %% [markdown]
# ## Task 2.3
#
# **[20 Point(s)]**

# %% [markdown]
# ## Breadth First Search [20 Points]
#
# Implement *Breadth-First Search*. Make sure to fill the docstring of the function and add typehints such that one can understand what arguments are expected and what it returns.
#
# Run the search algorithm for each map and save the results into `./data/results/<search_algo_name>_<map_number>.txt`.

# %%
import logging
from collections import deque
from typing import List, Tuple

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


class Node:
    """Represents a node in the BFS search tree."""
    def __init__(self, x: int, y: int, state: str = None, parent: 'Node' = None):
        self.x = x
        self.y = y
        self.state = state
        self.parent = parent


def parse_grid(file_path: str) -> Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]:
    """
    Parses a grid map from a text file into a 2D list and identifies the start ('S') and goal ('*') positions.
    """
    logging.info(f"Parsing the grid from file: {file_path}")
    grid = []
    start = None
    goal = None

    try:
        with open(file_path, 'r') as f:
            for line in f:
                grid.append(list(line.rstrip('\n')))  # Only remove newlines, not spaces
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
        raise ValueError(f"File not found: {file_path}")

    for i in range(len(grid)):          # Loop through rows
        for j in range(len(grid[i])):  # Loop through columns
            if grid[i][j].lower() == 's':  # Start position (case-insensitive)
                start = (i, j)
            elif grid[i][j] == '*':    # Goal position
                goal = (i, j)

    if start is None or goal is None:
        logging.error("The grid must contain both a start ('S') and a goal ('*').")
        raise ValueError("The grid must contain both a start ('S') and a goal ('*').")

    logging.info(f"Start position found at: {start}")
    logging.info(f"Goal position found at: {goal}")
    return grid, start, goal


def assign_character(maze_map: List[List[str]], current_node: Node, prev_node: Node):
    """Assigns characters ('─', '│') to indicate the path direction in the maze."""
    move_x = current_node.x - prev_node.x
    move_y = current_node.y - prev_node.y

    if move_x == 1:  # Moving down
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_x == -1:  # Moving up
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_y == 1:  # Moving right
        maze_map[prev_node.x][prev_node.y] = '─'
    elif move_y == -1:  # Moving left
        maze_map[prev_node.x][prev_node.y] = '─'


def path_to_goal(node: Node, maze_map: List[List[str]]):
    """Backtracks from the goal node to the start node and assigns path characters."""
    logging.info("Backtracking to mark the path from goal to start.")
    while node.parent:  # Until we reach the start node
        assign_character(maze_map, node, node.parent)
        logging.info(f"Marking path at: ({node.x}, {node.y})")
        node = node.parent  # Move backward along the path
    maze_map[node.x][node.y] = 'S'  # Mark the start position explicitly


def breadth_first_search(grid: List[List[str]], start: Tuple[int, int], goal: Tuple[int, int]) -> List[List[str]]:
    """
    Implements the Breadth-First Search (BFS) algorithm to find the shortest path
    from the start ('S') to the goal ('*') in a grid.
    """
    logging.info("Starting Breadth-First Search (BFS).")
    rows, cols = len(grid), len(grid[0])
    movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Possible moves: up, down, left, right
    queue = deque([Node(start[0], start[1], state='S', parent=None)])  # Initialize the queue with the start node
    visited = set()  # Set to keep track of visited cells

    while queue:
        node = queue.popleft()  # Take the first node from the queue
        visited.add((node.x, node.y))  # Mark it as visited
        logging.info(f"Visiting node at: ({node.x}, {node.y})")

        # Check if the goal is reached
        if (node.x, node.y) == goal:
            logging.info(f"Goal reached at: ({node.x}, {node.y})")
            path_to_goal(node, grid)  # Backtrack to mark the path on the grid
            return grid  # Return the updated grid

        # Explore neighbors
        for move_x, move_y in movements:
            new_x, new_y = node.x + move_x, node.y + move_y

            # Check if the new position is within bounds, not visited, and passable
            if (
                0 <= new_x < rows and 0 <= new_y < cols and
                (new_x, new_y) not in visited and
                grid[new_x][new_y] in (' ', '*')
            ):
                logging.info(f"Adding neighbor to queue: ({new_x}, {new_y})")
                queue.append(Node(new_x, new_y, state=grid[new_x][new_y], parent=node))

    logging.error("No path found from start to goal.")
    raise ValueError("No path found from start to goal.")


def save_grid_to_file(file_path: str, grid: List[List[str]]):
    """Saves the grid to a text file."""
    logging.info(f"Saving the grid to file: {file_path}")
    with open(file_path, 'w') as f:
        for row in grid:
            f.write(''.join(row) + '\n')


def main():
    input_file = "map1.txt"  # Path to your maze file
    output_file = "output_maze.txt"  # Path to save the output

    try:
        grid, start, goal = parse_grid(input_file)
        marked_grid = breadth_first_search(grid, start, goal)

        logging.info("Maze with path:")
        for row in marked_grid:
            logging.info("".join(row))

        save_grid_to_file(output_file, marked_grid)
        logging.info(f"Result saved to {output_file}")

    except ValueError as e:
        logging.error(e)


if __name__ == "__main__":
    main()

# %%
import logging
from typing import List, Tuple
from collections import deque

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


class Node:
    """Represents a node in the BFS search tree."""
    def __init__(self, x: int, y: int, parent: 'Node' = None):
        self.x = x
        self.y = y
        self.parent = parent


def parse_grid(file_path: str) -> Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]:
    """
    Parses a grid map from a text file into a 2D list and identifies the start ('S') and goal ('*') positions.
    """
    logging.info(f"Parsing the grid from file: {file_path}")
    grid = []
    start = None
    goal = None

    try:
        with open(file_path, 'r') as f:
            for line in f:
                grid.append(list(line.rstrip('\n')))  # Only remove newlines, not spaces
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
        raise ValueError(f"File not found: {file_path}")

    for i in range(len(grid)):          # Loop through rows
        for j in range(len(grid[i])):  # Loop through columns
            if grid[i][j].lower() == 's':  # Start position (case-insensitive)
                start = (i, j)
            elif grid[i][j] == '*':    # Goal position
                goal = (i, j)

    if start is None or goal is None:
        logging.error("The grid must contain both a start ('S') and a goal ('*').")
        raise ValueError("The grid must contain both a start ('S') and a goal ('*').")

    logging.info(f"Start position found at: {start}")
    logging.info(f"Goal position found at: {goal}")
    return grid, start, goal


def path_to_goal(node: Node, maze_map: List[List[str]]):
    """Backtracks from the goal node to the start node and assigns path characters."""
    logging.info("Backtracking to mark the path from goal to start.")
    while node.parent:  # Until we reach the start node
        prev_node = node.parent
        move_x = node.x - prev_node.x
        move_y = node.y - prev_node.y

        # Assign path characters based on the direction
        if move_x == 1 or move_x == -1:  # Vertical movement
            maze_map[prev_node.x][prev_node.y] = '│'
        elif move_y == 1 or move_y == -1:  # Horizontal movement
            maze_map[prev_node.x][prev_node.y] = '─'

        logging.info(f"Marking path at: ({node.x}, {node.y})")
        node = prev_node  # Move backward along the path

    maze_map[node.x][node.y] = 'S'  # Mark the start position explicitly


def breadth_first_search(grid: List[List[str]], start: Tuple[int, int], goal: Tuple[int, int]) -> List[List[str]]:
    """
    Implements the Breadth-First Search (BFS) algorithm to find the shortest path
    from the start ('S') to the goal ('*') in a grid.

    Parameters
    ----------
    grid : List[List[str]]
        A 2D list representing the grid.
    start : Tuple[int, int]
        The (row, col) coordinates of the start position ('S').
    goal : Tuple[int, int]
        The (row, col) coordinates of the goal position ('*').

    Returns
    -------
    List[List[str]]
        The grid with the shortest path marked from the start ('S') to the goal ('*').
    """
    logging.info("Starting Breadth-First Search (BFS).")
    rows, cols = len(grid), len(grid[0])
    movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Possible moves: up, down, left, right
    visited = set()  # Set to keep track of visited cells
    queue = deque([Node(start[0], start[1])])  # Initialize BFS queue with the start node

    while queue:
        current_node = queue.popleft()
        x, y = current_node.x, current_node.y

        # Check if we reached the goal
        if (x, y) == goal:
            logging.info(f"Goal reached at: ({x}, {y})")
            path_to_goal(Node(x=x, y=y, parent=current_node.parent), grid)
            return grid

        # Mark the current node as visited
        visited.add((x, y))
        logging.info(f"Visiting node at: ({x}, {y})")

        # Explore neighbors
        for move_x, move_y in movements:
            new_x, new_y = x + move_x, y + move_y
            if (
                0 <= new_x < rows and 0 <= new_y < cols and
                grid[new_x][new_y] in (' ', '*') and
                (new_x, new_y) not in visited
            ):
                queue.append(Node(new_x, new_y, parent=current_node))

    # If we finish the loop and didn't find a path
    logging.error("No path found from start to goal.")
    raise ValueError("No path found from start to goal.")


def save_grid_to_file(file_path: str, grid: List[List[str]]):
    """Saves the grid to a text file."""
    logging.info(f"Saving the grid to file: {file_path}")
    try:
        with open(file_path, 'w', encoding='utf-8') as f:  # Use UTF-8 encoding
            for row in grid:
                f.write(''.join(row) + '\n')
        logging.info(f"Grid successfully saved to {file_path}")
    except Exception as e:
        logging.error(f"Error saving grid to file: {e}")


def main():
    input_file = "map1.txt"  # Path to your maze file
    output_file = "output_shortest_path.txt"  # Path to save the shortest path output

    try:
        grid, start, goal = parse_grid(input_file)
        marked_grid = breadth_first_search(grid, start, goal)

        logging.info("Maze with shortest path:")
        for row in marked_grid:
            logging.info("".join(row))

        save_grid_to_file(output_file, marked_grid)
        logging.info(f"Result saved to {output_file}")

    except ValueError as e:
        logging.error(e)


if __name__ == "__main__":
    main()

# %%
# Test

# Please write your code test here!

# %% [markdown]
# ## Task 2.4
#
# **[20 Point(s)]**

# %% [markdown]
# ## Depth First Search [20 Points]
#
# Implement *Depth-First Search*. Make sure to fill the docstring of the function and add typehints such that one can understand what arguments are expected and what it returns.
#
# Run the search algorithm for each map and save the results into `./data/results/<search_algo_name>_<map_number>.txt`.

# %%
import logging
from typing import List, Tuple

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


class Node:
    """Represents a node in the DFS search tree."""
    def __init__(self, x: int, y: int, state: str = None, parent: 'Node' = None):
        self.x = x
        self.y = y
        self.state = state
        self.parent = parent


def parse_grid(file_path: str) -> Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]:
    """
    Parses a grid map from a text file into a 2D list and identifies the start ('S') and goal ('*') positions.
    """
    logging.info(f"Parsing the grid from file: {file_path}")
    grid = []
    start = None
    goal = None

    try:
        with open(file_path, 'r') as f:
            for line in f:
                grid.append(list(line.rstrip('\n')))  # Only remove newlines, not spaces
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
        raise ValueError(f"File not found: {file_path}")

    for i in range(len(grid)):          # Loop through rows
        for j in range(len(grid[i])):  # Loop through columns
            if grid[i][j].lower() == 's':  # Start position (case-insensitive)
                start = (i, j)
            elif grid[i][j] == '*':    # Goal position
                goal = (i, j)

    if start is None or goal is None:
        logging.error("The grid must contain both a start ('S') and a goal ('*').")
        raise ValueError("The grid must contain both a start ('S') and a goal ('*').")

    logging.info(f"Start position found at: {start}")
    logging.info(f"Goal position found at: {goal}")
    return grid, start, goal


def assign_character(maze_map: List[List[str]], current_node: Node, prev_node: Node):
    """Assigns characters ('─', '│') to indicate the path direction in the maze."""
    move_x = current_node.x - prev_node.x
    move_y = current_node.y - prev_node.y

    if move_x == 1:  # Moving down
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_x == -1:  # Moving up
        maze_map[prev_node.x][prev_node.y] = '│'
    elif move_y == 1:  # Moving right
        maze_map[prev_node.x][prev_node.y] = '─'
    elif move_y == -1:  # Moving left
        maze_map[prev_node.x][prev_node.y] = '─'


def path_to_goal(node: Node, maze_map: List[List[str]]):
    """Backtracks from the goal node to the start node and assigns path characters."""
    logging.info("Backtracking to mark the path from goal to start.")
    while node.parent:  # Until we reach the start node
        assign_character(maze_map, node, node.parent)
        logging.info(f"Marking path at: ({node.x}, {node.y})")
        node = node.parent  # Move backward along the path
    maze_map[node.x][node.y] = 'S'  # Mark the start position explicitly


def depth_first_search(grid: List[List[str]], start: Tuple[int, int], goal: Tuple[int, int]) -> List[List[str]]:
    """
    Implements the Depth-First Search (DFS) algorithm to find a path
    from the start ('S') to the goal ('*') in a grid.

    Parameters
    ----------
    grid : List[List[str]]
        A 2D list representing the grid.
    start : Tuple[int, int]
        The (row, col) coordinates of the start position ('S').
    goal : Tuple[int, int]
        The (row, col) coordinates of the goal position ('*').

    Returns
    -------
    List[List[str]]
        The grid with the path marked from the start ('S') to the goal ('*').
    """
    logging.info("Starting Depth-First Search (DFS).")
    rows, cols = len(grid), len(grid[0])
    movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Possible moves: up, down, left, right
    visited = set()  # Set to keep track of visited cells

    def dfs_recursive(x: int, y: int, parent: Node) -> bool:
        """Recursive helper function for DFS."""
        if (x, y) in visited:
            return False  # Already visited

        visited.add((x, y))
        logging.info(f"Visiting node at: ({x}, {y})")

        # Check if the goal is reached
        if (x, y) == goal:
            logging.info(f"Goal reached at: ({x}, {y})")
            path_to_goal(Node(x=x, y=y, state='*', parent=parent), grid)
            return True

        # Explore neighbors
        for move_x, move_y in movements:
            new_x, new_y = x + move_x, y + move_y
            if (
                0 <= new_x < rows and 0 <= new_y < cols and
                grid[new_x][new_y] in (' ', '*')
            ):
                if dfs_recursive(new_x, new_y, Node(x=x, y=y, state=grid[x][y], parent=parent)):
                    return True  # Path found

        return False  # No path found from this node

    # Start DFS from the starting position
    if not dfs_recursive(start[0], start[1], None):
        logging.error("No path found from start to goal.")
        raise ValueError("No path found from start to goal.")

    return grid


def save_grid_to_file(file_path: str, grid: List[List[str]]):
    """Saves the grid to a text file."""
    logging.info(f"Saving the grid to file: {file_path}")
    try:
        with open(file_path, 'w', encoding='utf-8') as f:  # Use UTF-8 encoding
            for row in grid:
                f.write(''.join(row) + '\n')
        logging.info(f"Grid successfully saved to {file_path}")
    except Exception as e:
        logging.error(f"Error saving grid to file: {e}")


def main():
    input_file = "map1.txt"  # Path to your maze file
    output_file = "output_maze_dfs.txt"  # Path to save the output

    try:
        grid, start, goal = parse_grid(input_file)
        marked_grid = depth_first_search(grid, start, goal)

        logging.info("Maze with path:")
        for row in marked_grid:
            logging.info("".join(row))

        save_grid_to_file(output_file, marked_grid)
        logging.info(f"Result saved to {output_file}")

    except ValueError as e:
        logging.error(e)


if __name__ == "__main__":
    main()
# Out:
# 2024-11-24 00:22:00,101 - INFO - Parsing the grid from file: map1.txt
# 2024-11-24 00:22:00,103 - INFO - Start position found at: (1, 3)
# 2024-11-24 00:22:00,104 - INFO - Goal position found at: (19, 72)
# 2024-11-24 00:22:00,104 - INFO - Starting Depth-First Search (DFS).
# 2024-11-24 00:22:00,105 - INFO - Visiting node at: (1, 3)
# 2024-11-24 00:22:00,106 - INFO - Visiting node at: (2, 3)
# 2024-11-24 00:22:00,107 - INFO - Visiting node at: (2, 2)
# 2024-11-24 00:22:00,108 - INFO - Visiting node at: (1, 2)
# 2024-11-24 00:22:00,108 - INFO - Visiting node at: (1, 1)
# 2024-11-24 00:22:00,108 - INFO - Visiting node at: (2, 1)
# 2024-11-24 00:22:00,108 - INFO - Visiting node at: (2, 4)
# 2024-11-24 00:22:00,110 - INFO - Visiting node at: (1, 4)
# 2024-11-24 00:22:00,110 - INFO - Visiting node at: (1, 5)
# 2024-11-24 00:22:00,111 - INFO - Visiting node at: (2, 5)
# 2024-11-24 00:22:00,111 - INFO - Visiting node at: (2, 6)
# 2024-11-24 00:22:00,111 - INFO - Visiting node at: (1, 6)
# 2024-11-24 00:22:00,112 - INFO - Visiting node at: (1, 7)
# 2024-11-24 00:22:00,112 - INFO - Visiting node at: (2, 7)
# 2024-11-24 00:22:00,112 - INFO - Visiting node at: (2, 8)
# 2024-11-24 00:22:00,113 - INFO - Visiting node at: (1, 8)
# 2024-11-24 00:22:00,113 - INFO - Visiting node at: (1, 9)
# 2024-11-24 00:22:00,114 - INFO - Visiting node at: (2, 9)
# 2024-11-24 00:22:00,114 - INFO - Visiting node at: (2, 10)
# 2024-11-24 00:22:00,116 - INFO - Visiting node at: (1, 10)
# 2024-11-24 00:22:00,116 - INFO - Visiting node at: (1, 11)
# 2024-11-24 00:22:00,117 - INFO - Visiting node at: (2, 11)
# 2024-11-24 00:22:00,117 - INFO - Visiting node at: (2, 12)
# 2024-11-24 00:22:00,118 - INFO - Visiting node at: (1, 12)
# 2024-11-24 00:22:00,118 - INFO - Visiting node at: (1, 13)
# 2024-11-24 00:22:00,119 - INFO - Visiting node at: (2, 13)
# 2024-11-24 00:22:00,119 - INFO - Visiting node at: (2, 14)
# 2024-11-24 00:22:00,120 - INFO - Visiting node at: (1, 14)
# 2024-11-24 00:22:00,120 - INFO - Visiting node at: (1, 15)
# 2024-11-24 00:22:00,121 - INFO - Visiting node at: (2, 15)
# 2024-11-24 00:22:00,121 - INFO - Visiting node at: (2, 16)
# 2024-11-24 00:22:00,121 - INFO - Visiting node at: (1, 16)
# 2024-11-24 00:22:00,122 - INFO - Visiting node at: (1, 17)
# 2024-11-24 00:22:00,122 - INFO - Visiting node at: (2, 17)
# 2024-11-24 00:22:00,122 - INFO - Visiting node at: (2, 18)
# 2024-11-24 00:22:00,122 - INFO - Visiting node at: (1, 18)
# 2024-11-24 00:22:00,123 - INFO - Visiting node at: (1, 19)
# 2024-11-24 00:22:00,123 - INFO - Visiting node at: (2, 19)
# 2024-11-24 00:22:00,123 - INFO - Visiting node at: (2, 20)
# 2024-11-24 00:22:00,123 - INFO - Visiting node at: (1, 20)
# 2024-11-24 00:22:00,124 - INFO - Visiting node at: (1, 21)
# 2024-11-24 00:22:00,124 - INFO - Visiting node at: (2, 21)
# 2024-11-24 00:22:00,124 - INFO - Visiting node at: (3, 21)
# 2024-11-24 00:22:00,124 - INFO - Visiting node at: (4, 21)
# 2024-11-24 00:22:00,125 - INFO - Visiting node at: (5, 21)
# 2024-11-24 00:22:00,125 - INFO - Visiting node at: (5, 20)
# 2024-11-24 00:22:00,125 - INFO - Visiting node at: (4, 20)
# 2024-11-24 00:22:00,125 - INFO - Visiting node at: (4, 19)
# 2024-11-24 00:22:00,127 - INFO - Visiting node at: (5, 19)
# 2024-11-24 00:22:00,127 - INFO - Visiting node at: (5, 18)
# 2024-11-24 00:22:00,128 - INFO - Visiting node at: (4, 18)
# 2024-11-24 00:22:00,128 - INFO - Visiting node at: (4, 17)
# 2024-11-24 00:22:00,128 - INFO - Visiting node at: (5, 17)
# 2024-11-24 00:22:00,129 - INFO - Visiting node at: (6, 17)
# 2024-11-24 00:22:00,129 - INFO - Visiting node at: (7, 17)
# 2024-11-24 00:22:00,130 - INFO - Visiting node at: (8, 17)
# 2024-11-24 00:22:00,130 - INFO - Visiting node at: (9, 17)
# 2024-11-24 00:22:00,130 - INFO - Visiting node at: (10, 17)
# 2024-11-24 00:22:00,131 - INFO - Visiting node at: (11, 17)
# 2024-11-24 00:22:00,131 - INFO - Visiting node at: (12, 17)
# 2024-11-24 00:22:00,131 - INFO - Visiting node at: (13, 17)
# 2024-11-24 00:22:00,131 - INFO - Visiting node at: (13, 16)
# 2024-11-24 00:22:00,133 - INFO - Visiting node at: (12, 16)
# 2024-11-24 00:22:00,133 - INFO - Visiting node at: (11, 16)
# 2024-11-24 00:22:00,133 - INFO - Visiting node at: (10, 16)
# 2024-11-24 00:22:00,134 - INFO - Visiting node at: (9, 16)
# 2024-11-24 00:22:00,134 - INFO - Visiting node at: (8, 16)
# 2024-11-24 00:22:00,134 - INFO - Visiting node at: (7, 16)
# 2024-11-24 00:22:00,135 - INFO - Visiting node at: (6, 16)
# 2024-11-24 00:22:00,135 - INFO - Visiting node at: (5, 16)
# 2024-11-24 00:22:00,135 - INFO - Visiting node at: (4, 16)
# 2024-11-24 00:22:00,135 - INFO - Visiting node at: (4, 15)
# 2024-11-24 00:22:00,136 - INFO - Visiting node at: (5, 15)
# 2024-11-24 00:22:00,136 - INFO - Visiting node at: (6, 15)
# 2024-11-24 00:22:00,136 - INFO - Visiting node at: (7, 15)
# 2024-11-24 00:22:00,137 - INFO - Visiting node at: (8, 15)
# 2024-11-24 00:22:00,138 - INFO - Visiting node at: (9, 15)
# 2024-11-24 00:22:00,138 - INFO - Visiting node at: (10, 15)
# 2024-11-24 00:22:00,138 - INFO - Visiting node at: (11, 15)
# 2024-11-24 00:22:00,138 - INFO - Visiting node at: (12, 15)
# 2024-11-24 00:22:00,139 - INFO - Visiting node at: (13, 15)
# 2024-11-24 00:22:00,139 - INFO - Visiting node at: (13, 14)
# 2024-11-24 00:22:00,139 - INFO - Visiting node at: (12, 14)
# 2024-11-24 00:22:00,140 - INFO - Visiting node at: (11, 14)
# 2024-11-24 00:22:00,140 - INFO - Visiting node at: (10, 14)
# 2024-11-24 00:22:00,140 - INFO - Visiting node at: (9, 14)
# 2024-11-24 00:22:00,141 - INFO - Visiting node at: (8, 14)
# 2024-11-24 00:22:00,141 - INFO - Visiting node at: (7, 14)
# 2024-11-24 00:22:00,141 - INFO - Visiting node at: (6, 14)
# 2024-11-24 00:22:00,141 - INFO - Visiting node at: (5, 14)
# 2024-11-24 00:22:00,142 - INFO - Visiting node at: (4, 14)
# 2024-11-24 00:22:00,142 - INFO - Visiting node at: (4, 13)
# 2024-11-24 00:22:00,142 - INFO - Visiting node at: (5, 13)
# 2024-11-24 00:22:00,142 - INFO - Visiting node at: (6, 13)
# 2024-11-24 00:22:00,143 - INFO - Visiting node at: (7, 13)
# 2024-11-24 00:22:00,143 - INFO - Visiting node at: (8, 13)
# 2024-11-24 00:22:00,143 - INFO - Visiting node at: (9, 13)
# 2024-11-24 00:22:00,144 - INFO - Visiting node at: (10, 13)
# 2024-11-24 00:22:00,144 - INFO - Visiting node at: (11, 13)
# 2024-11-24 00:22:00,144 - INFO - Visiting node at: (12, 13)
# 2024-11-24 00:22:00,145 - INFO - Visiting node at: (13, 13)
# 2024-11-24 00:22:00,145 - INFO - Visiting node at: (13, 12)
# 2024-11-24 00:22:00,145 - INFO - Visiting node at: (12, 12)
# 2024-11-24 00:22:00,145 - INFO - Visiting node at: (11, 12)
# 2024-11-24 00:22:00,145 - INFO - Visiting node at: (10, 12)
# 2024-11-24 00:22:00,147 - INFO - Visiting node at: (9, 12)
# 2024-11-24 00:22:00,147 - INFO - Visiting node at: (8, 12)
# 2024-11-24 00:22:00,147 - INFO - Visiting node at: (7, 12)
# 2024-11-24 00:22:00,148 - INFO - Visiting node at: (6, 12)
# 2024-11-24 00:22:00,148 - INFO - Visiting node at: (5, 12)
# 2024-11-24 00:22:00,149 - INFO - Visiting node at: (4, 12)
# 2024-11-24 00:22:00,150 - INFO - Visiting node at: (4, 11)
# 2024-11-24 00:22:00,150 - INFO - Visiting node at: (5, 11)
# 2024-11-24 00:22:00,150 - INFO - Visiting node at: (6, 11)
# 2024-11-24 00:22:00,151 - INFO - Visiting node at: (7, 11)
# 2024-11-24 00:22:00,151 - INFO - Visiting node at: (8, 11)
# 2024-11-24 00:22:00,151 - INFO - Visiting node at: (9, 11)
# 2024-11-24 00:22:00,152 - INFO - Visiting node at: (10, 11)
# 2024-11-24 00:22:00,152 - INFO - Visiting node at: (11, 11)
# 2024-11-24 00:22:00,152 - INFO - Visiting node at: (12, 11)
# 2024-11-24 00:22:00,152 - INFO - Visiting node at: (13, 11)
# 2024-11-24 00:22:00,153 - INFO - Visiting node at: (13, 10)
# 2024-11-24 00:22:00,153 - INFO - Visiting node at: (12, 10)
# 2024-11-24 00:22:00,153 - INFO - Visiting node at: (11, 10)
# 2024-11-24 00:22:00,154 - INFO - Visiting node at: (10, 10)
# 2024-11-24 00:22:00,154 - INFO - Visiting node at: (9, 10)
# 2024-11-24 00:22:00,154 - INFO - Visiting node at: (8, 10)
# 2024-11-24 00:22:00,154 - INFO - Visiting node at: (7, 10)
# 2024-11-24 00:22:00,155 - INFO - Visiting node at: (6, 10)
# 2024-11-24 00:22:00,155 - INFO - Visiting node at: (5, 10)
# 2024-11-24 00:22:00,155 - INFO - Visiting node at: (4, 10)
# 2024-11-24 00:22:00,155 - INFO - Visiting node at: (4, 9)
# 2024-11-24 00:22:00,156 - INFO - Visiting node at: (5, 9)
# 2024-11-24 00:22:00,157 - INFO - Visiting node at: (6, 9)
# 2024-11-24 00:22:00,157 - INFO - Visiting node at: (7, 9)
# 2024-11-24 00:22:00,157 - INFO - Visiting node at: (8, 9)
# 2024-11-24 00:22:00,158 - INFO - Visiting node at: (9, 9)
# 2024-11-24 00:22:00,158 - INFO - Visiting node at: (10, 9)
# 2024-11-24 00:22:00,158 - INFO - Visiting node at: (11, 9)
# 2024-11-24 00:22:00,159 - INFO - Visiting node at: (12, 9)
# 2024-11-24 00:22:00,159 - INFO - Visiting node at: (13, 9)
# 2024-11-24 00:22:00,159 - INFO - Visiting node at: (13, 8)
# 2024-11-24 00:22:00,159 - INFO - Visiting node at: (12, 8)
# 2024-11-24 00:22:00,161 - INFO - Visiting node at: (11, 8)
# 2024-11-24 00:22:00,161 - INFO - Visiting node at: (10, 8)
# 2024-11-24 00:22:00,161 - INFO - Visiting node at: (9, 8)
# 2024-11-24 00:22:00,161 - INFO - Visiting node at: (8, 8)
# 2024-11-24 00:22:00,162 - INFO - Visiting node at: (7, 8)
# 2024-11-24 00:22:00,162 - INFO - Visiting node at: (6, 8)
# 2024-11-24 00:22:00,162 - INFO - Visiting node at: (5, 8)
# 2024-11-24 00:22:00,163 - INFO - Visiting node at: (4, 8)
# 2024-11-24 00:22:00,163 - INFO - Visiting node at: (4, 7)
# 2024-11-24 00:22:00,163 - INFO - Visiting node at: (5, 7)
# 2024-11-24 00:22:00,164 - INFO - Visiting node at: (6, 7)
# 2024-11-24 00:22:00,164 - INFO - Visiting node at: (7, 7)
# 2024-11-24 00:22:00,164 - INFO - Visiting node at: (8, 7)
# 2024-11-24 00:22:00,165 - INFO - Visiting node at: (9, 7)
# 2024-11-24 00:22:00,165 - INFO - Visiting node at: (10, 7)
# 2024-11-24 00:22:00,165 - INFO - Visiting node at: (11, 7)
# 2024-11-24 00:22:00,166 - INFO - Visiting node at: (12, 7)
# 2024-11-24 00:22:00,166 - INFO - Visiting node at: (13, 7)
# 2024-11-24 00:22:00,167 - INFO - Visiting node at: (13, 6)
# 2024-11-24 00:22:00,167 - INFO - Visiting node at: (12, 6)
# 2024-11-24 00:22:00,167 - INFO - Visiting node at: (11, 6)
# 2024-11-24 00:22:00,167 - INFO - Visiting node at: (10, 6)
# 2024-11-24 00:22:00,168 - INFO - Visiting node at: (9, 6)
# 2024-11-24 00:22:00,168 - INFO - Visiting node at: (8, 6)
# 2024-11-24 00:22:00,168 - INFO - Visiting node at: (7, 6)
# 2024-11-24 00:22:00,169 - INFO - Visiting node at: (6, 6)
# 2024-11-24 00:22:00,169 - INFO - Visiting node at: (5, 6)
# 2024-11-24 00:22:00,169 - INFO - Visiting node at: (4, 6)
# 2024-11-24 00:22:00,170 - INFO - Visiting node at: (4, 5)
# 2024-11-24 00:22:00,170 - INFO - Visiting node at: (5, 5)
# 2024-11-24 00:22:00,171 - INFO - Visiting node at: (6, 5)
# 2024-11-24 00:22:00,172 - INFO - Visiting node at: (7, 5)
# 2024-11-24 00:22:00,172 - INFO - Visiting node at: (8, 5)
# 2024-11-24 00:22:00,172 - INFO - Visiting node at: (9, 5)
# 2024-11-24 00:22:00,172 - INFO - Visiting node at: (10, 5)
# 2024-11-24 00:22:00,172 - INFO - Visiting node at: (11, 5)
# 2024-11-24 00:22:00,174 - INFO - Visiting node at: (12, 5)
# 2024-11-24 00:22:00,174 - INFO - Visiting node at: (13, 5)
# 2024-11-24 00:22:00,174 - INFO - Visiting node at: (13, 4)
# 2024-11-24 00:22:00,174 - INFO - Visiting node at: (12, 4)
# 2024-11-24 00:22:00,174 - INFO - Visiting node at: (11, 4)
# 2024-11-24 00:22:00,175 - INFO - Visiting node at: (10, 4)
# 2024-11-24 00:22:00,175 - INFO - Visiting node at: (9, 4)
# 2024-11-24 00:22:00,175 - INFO - Visiting node at: (8, 4)
# 2024-11-24 00:22:00,175 - INFO - Visiting node at: (7, 4)
# 2024-11-24 00:22:00,176 - INFO - Visiting node at: (6, 4)
# 2024-11-24 00:22:00,176 - INFO - Visiting node at: (5, 4)
# 2024-11-24 00:22:00,176 - INFO - Visiting node at: (4, 4)
# 2024-11-24 00:22:00,177 - INFO - Visiting node at: (4, 3)
# 2024-11-24 00:22:00,177 - INFO - Visiting node at: (5, 3)
# 2024-11-24 00:22:00,177 - INFO - Visiting node at: (6, 3)
# 2024-11-24 00:22:00,178 - INFO - Visiting node at: (7, 3)
# 2024-11-24 00:22:00,178 - INFO - Visiting node at: (8, 3)
# 2024-11-24 00:22:00,179 - INFO - Visiting node at: (9, 3)
# 2024-11-24 00:22:00,179 - INFO - Visiting node at: (10, 3)
# 2024-11-24 00:22:00,179 - INFO - Visiting node at: (11, 3)
# 2024-11-24 00:22:00,180 - INFO - Visiting node at: (12, 3)
# 2024-11-24 00:22:00,180 - INFO - Visiting node at: (13, 3)
# 2024-11-24 00:22:00,180 - INFO - Visiting node at: (13, 2)
# 2024-11-24 00:22:00,180 - INFO - Visiting node at: (12, 2)
# 2024-11-24 00:22:00,181 - INFO - Visiting node at: (11, 2)
# 2024-11-24 00:22:00,181 - INFO - Visiting node at: (10, 2)
# 2024-11-24 00:22:00,181 - INFO - Visiting node at: (9, 2)
# 2024-11-24 00:22:00,182 - INFO - Visiting node at: (8, 2)
# 2024-11-24 00:22:00,182 - INFO - Visiting node at: (7, 2)
# 2024-11-24 00:22:00,182 - INFO - Visiting node at: (6, 2)
# 2024-11-24 00:22:00,182 - INFO - Visiting node at: (5, 2)
# 2024-11-24 00:22:00,183 - INFO - Visiting node at: (4, 2)
# 2024-11-24 00:22:00,183 - INFO - Visiting node at: (4, 1)
# 2024-11-24 00:22:00,183 - INFO - Visiting node at: (5, 1)
# 2024-11-24 00:22:00,184 - INFO - Visiting node at: (6, 1)
# 2024-11-24 00:22:00,184 - INFO - Visiting node at: (7, 1)
# 2024-11-24 00:22:00,184 - INFO - Visiting node at: (8, 1)
# 2024-11-24 00:22:00,184 - INFO - Visiting node at: (9, 1)
# 2024-11-24 00:22:00,185 - INFO - Visiting node at: (10, 1)
# 2024-11-24 00:22:00,185 - INFO - Visiting node at: (11, 1)
# 2024-11-24 00:22:00,185 - INFO - Visiting node at: (12, 1)
# 2024-11-24 00:22:00,185 - INFO - Visiting node at: (13, 1)
# 2024-11-24 00:22:00,186 - INFO - Visiting node at: (13, 18)
# 2024-11-24 00:22:00,186 - INFO - Visiting node at: (12, 18)
# 2024-11-24 00:22:00,186 - INFO - Visiting node at: (11, 18)
# 2024-11-24 00:22:00,186 - INFO - Visiting node at: (10, 18)
# 2024-11-24 00:22:00,187 - INFO - Visiting node at: (9, 18)
# 2024-11-24 00:22:00,188 - INFO - Visiting node at: (8, 18)
# 2024-11-24 00:22:00,188 - INFO - Visiting node at: (7, 18)
# 2024-11-24 00:22:00,189 - INFO - Visiting node at: (6, 18)
# 2024-11-24 00:22:00,189 - INFO - Visiting node at: (7, 19)
# 2024-11-24 00:22:00,189 - INFO - Visiting node at: (8, 19)
# 2024-11-24 00:22:00,189 - INFO - Visiting node at: (9, 19)
# 2024-11-24 00:22:00,190 - INFO - Visiting node at: (10, 19)
# 2024-11-24 00:22:00,190 - INFO - Visiting node at: (11, 19)
# 2024-11-24 00:22:00,192 - INFO - Visiting node at: (12, 19)
# 2024-11-24 00:22:00,192 - INFO - Visiting node at: (13, 19)
# 2024-11-24 00:22:00,193 - INFO - Visiting node at: (13, 20)
# 2024-11-24 00:22:00,193 - INFO - Visiting node at: (12, 20)
# 2024-11-24 00:22:00,193 - INFO - Visiting node at: (11, 20)
# 2024-11-24 00:22:00,194 - INFO - Visiting node at: (10, 20)
# 2024-11-24 00:22:00,194 - INFO - Visiting node at: (9, 20)
# 2024-11-24 00:22:00,194 - INFO - Visiting node at: (8, 20)
# 2024-11-24 00:22:00,194 - INFO - Visiting node at: (7, 20)
# 2024-11-24 00:22:00,195 - INFO - Visiting node at: (7, 21)
# 2024-11-24 00:22:00,195 - INFO - Visiting node at: (8, 21)
# 2024-11-24 00:22:00,195 - INFO - Visiting node at: (9, 21)
# 2024-11-24 00:22:00,195 - INFO - Visiting node at: (10, 21)
# 2024-11-24 00:22:00,196 - INFO - Visiting node at: (11, 21)
# 2024-11-24 00:22:00,196 - INFO - Visiting node at: (12, 21)
# 2024-11-24 00:22:00,196 - INFO - Visiting node at: (13, 21)
# 2024-11-24 00:22:00,196 - INFO - Visiting node at: (13, 22)
# 2024-11-24 00:22:00,197 - INFO - Visiting node at: (12, 22)
# 2024-11-24 00:22:00,197 - INFO - Visiting node at: (11, 22)
# 2024-11-24 00:22:00,197 - INFO - Visiting node at: (10, 22)
# 2024-11-24 00:22:00,197 - INFO - Visiting node at: (9, 22)
# 2024-11-24 00:22:00,198 - INFO - Visiting node at: (8, 22)
# 2024-11-24 00:22:00,198 - INFO - Visiting node at: (7, 22)
# 2024-11-24 00:22:00,198 - INFO - Visiting node at: (7, 23)
# 2024-11-24 00:22:00,198 - INFO - Visiting node at: (8, 23)
# 2024-11-24 00:22:00,199 - INFO - Visiting node at: (9, 23)
# 2024-11-24 00:22:00,199 - INFO - Visiting node at: (10, 23)
# 2024-11-24 00:22:00,199 - INFO - Visiting node at: (11, 23)
# 2024-11-24 00:22:00,200 - INFO - Visiting node at: (12, 23)
# 2024-11-24 00:22:00,200 - INFO - Visiting node at: (13, 23)
# 2024-11-24 00:22:00,200 - INFO - Visiting node at: (13, 24)
# 2024-11-24 00:22:00,201 - INFO - Visiting node at: (12, 24)
# 2024-11-24 00:22:00,201 - INFO - Visiting node at: (11, 24)
# 2024-11-24 00:22:00,201 - INFO - Visiting node at: (10, 24)
# 2024-11-24 00:22:00,203 - INFO - Visiting node at: (9, 24)
# 2024-11-24 00:22:00,204 - INFO - Visiting node at: (8, 24)
# 2024-11-24 00:22:00,204 - INFO - Visiting node at: (7, 24)
# 2024-11-24 00:22:00,205 - INFO - Visiting node at: (7, 25)
# 2024-11-24 00:22:00,206 - INFO - Visiting node at: (8, 25)
# 2024-11-24 00:22:00,206 - INFO - Visiting node at: (9, 25)
# 2024-11-24 00:22:00,206 - INFO - Visiting node at: (10, 25)
# 2024-11-24 00:22:00,207 - INFO - Visiting node at: (11, 25)
# 2024-11-24 00:22:00,207 - INFO - Visiting node at: (12, 25)
# 2024-11-24 00:22:00,208 - INFO - Visiting node at: (13, 25)
# 2024-11-24 00:22:00,210 - INFO - Visiting node at: (13, 26)
# 2024-11-24 00:22:00,210 - INFO - Visiting node at: (12, 26)
# 2024-11-24 00:22:00,210 - INFO - Visiting node at: (11, 26)
# 2024-11-24 00:22:00,211 - INFO - Visiting node at: (10, 26)
# 2024-11-24 00:22:00,211 - INFO - Visiting node at: (9, 26)
# 2024-11-24 00:22:00,212 - INFO - Visiting node at: (8, 26)
# 2024-11-24 00:22:00,213 - INFO - Visiting node at: (7, 26)
# 2024-11-24 00:22:00,213 - INFO - Visiting node at: (7, 27)
# 2024-11-24 00:22:00,213 - INFO - Visiting node at: (8, 27)
# 2024-11-24 00:22:00,214 - INFO - Visiting node at: (9, 27)
# 2024-11-24 00:22:00,214 - INFO - Visiting node at: (10, 27)
# 2024-11-24 00:22:00,214 - INFO - Visiting node at: (11, 27)
# 2024-11-24 00:22:00,215 - INFO - Visiting node at: (12, 27)
# 2024-11-24 00:22:00,215 - INFO - Visiting node at: (13, 27)
# 2024-11-24 00:22:00,216 - INFO - Visiting node at: (13, 28)
# 2024-11-24 00:22:00,216 - INFO - Visiting node at: (12, 28)
# 2024-11-24 00:22:00,217 - INFO - Visiting node at: (11, 28)
# 2024-11-24 00:22:00,217 - INFO - Visiting node at: (10, 28)
# 2024-11-24 00:22:00,218 - INFO - Visiting node at: (9, 28)
# 2024-11-24 00:22:00,218 - INFO - Visiting node at: (8, 28)
# 2024-11-24 00:22:00,219 - INFO - Visiting node at: (7, 28)
# 2024-11-24 00:22:00,219 - INFO - Visiting node at: (7, 29)
# 2024-11-24 00:22:00,219 - INFO - Visiting node at: (8, 29)
# 2024-11-24 00:22:00,220 - INFO - Visiting node at: (9, 29)
# 2024-11-24 00:22:00,220 - INFO - Visiting node at: (10, 29)
# 2024-11-24 00:22:00,220 - INFO - Visiting node at: (11, 29)
# 2024-11-24 00:22:00,222 - INFO - Visiting node at: (12, 29)
# 2024-11-24 00:22:00,222 - INFO - Visiting node at: (13, 29)
# 2024-11-24 00:22:00,223 - INFO - Visiting node at: (13, 30)
# 2024-11-24 00:22:00,223 - INFO - Visiting node at: (12, 30)
# 2024-11-24 00:22:00,224 - INFO - Visiting node at: (11, 30)
# 2024-11-24 00:22:00,224 - INFO - Visiting node at: (10, 30)
# 2024-11-24 00:22:00,224 - INFO - Visiting node at: (9, 30)
# 2024-11-24 00:22:00,225 - INFO - Visiting node at: (8, 30)
# 2024-11-24 00:22:00,225 - INFO - Visiting node at: (7, 30)
# 2024-11-24 00:22:00,225 - INFO - Visiting node at: (7, 31)
# 2024-11-24 00:22:00,227 - INFO - Visiting node at: (8, 31)
# 2024-11-24 00:22:00,227 - INFO - Visiting node at: (9, 31)
# 2024-11-24 00:22:00,228 - INFO - Visiting node at: (10, 31)
# 2024-11-24 00:22:00,228 - INFO - Visiting node at: (11, 31)
# 2024-11-24 00:22:00,229 - INFO - Visiting node at: (12, 31)
# 2024-11-24 00:22:00,229 - INFO - Visiting node at: (13, 31)
# 2024-11-24 00:22:00,230 - INFO - Visiting node at: (13, 32)
# 2024-11-24 00:22:00,231 - INFO - Visiting node at: (12, 32)
# 2024-11-24 00:22:00,231 - INFO - Visiting node at: (11, 32)
# 2024-11-24 00:22:00,232 - INFO - Visiting node at: (10, 32)
# 2024-11-24 00:22:00,232 - INFO - Visiting node at: (9, 32)
# 2024-11-24 00:22:00,232 - INFO - Visiting node at: (8, 32)
# 2024-11-24 00:22:00,233 - INFO - Visiting node at: (7, 32)
# 2024-11-24 00:22:00,233 - INFO - Visiting node at: (7, 33)
# 2024-11-24 00:22:00,233 - INFO - Visiting node at: (8, 33)
# 2024-11-24 00:22:00,235 - INFO - Visiting node at: (9, 33)
# 2024-11-24 00:22:00,235 - INFO - Visiting node at: (10, 33)
# 2024-11-24 00:22:00,236 - INFO - Visiting node at: (11, 33)
# 2024-11-24 00:22:00,236 - INFO - Visiting node at: (12, 33)
# 2024-11-24 00:22:00,236 - INFO - Visiting node at: (13, 33)
# 2024-11-24 00:22:00,236 - INFO - Visiting node at: (14, 33)
# 2024-11-24 00:22:00,237 - INFO - Visiting node at: (15, 33)
# 2024-11-24 00:22:00,237 - INFO - Visiting node at: (16, 33)
# 2024-11-24 00:22:00,237 - INFO - Visiting node at: (17, 33)
# 2024-11-24 00:22:00,237 - INFO - Visiting node at: (18, 33)
# 2024-11-24 00:22:00,237 - INFO - Visiting node at: (19, 33)
# 2024-11-24 00:22:00,238 - INFO - Visiting node at: (19, 32)
# 2024-11-24 00:22:00,238 - INFO - Visiting node at: (18, 32)
# 2024-11-24 00:22:00,239 - INFO - Visiting node at: (17, 32)
# 2024-11-24 00:22:00,239 - INFO - Visiting node at: (16, 32)
# 2024-11-24 00:22:00,239 - INFO - Visiting node at: (15, 32)
# 2024-11-24 00:22:00,239 - INFO - Visiting node at: (15, 31)
# 2024-11-24 00:22:00,239 - INFO - Visiting node at: (16, 31)
# 2024-11-24 00:22:00,240 - INFO - Visiting node at: (17, 31)
# 2024-11-24 00:22:00,240 - INFO - Visiting node at: (18, 31)
# 2024-11-24 00:22:00,240 - INFO - Visiting node at: (19, 31)
# 2024-11-24 00:22:00,240 - INFO - Visiting node at: (19, 30)
# 2024-11-24 00:22:00,240 - INFO - Visiting node at: (18, 30)
# 2024-11-24 00:22:00,241 - INFO - Visiting node at: (17, 30)
# 2024-11-24 00:22:00,241 - INFO - Visiting node at: (16, 30)
# 2024-11-24 00:22:00,241 - INFO - Visiting node at: (15, 30)
# 2024-11-24 00:22:00,242 - INFO - Visiting node at: (15, 29)
# 2024-11-24 00:22:00,242 - INFO - Visiting node at: (16, 29)
# 2024-11-24 00:22:00,242 - INFO - Visiting node at: (17, 29)
# 2024-11-24 00:22:00,242 - INFO - Visiting node at: (18, 29)
# 2024-11-24 00:22:00,243 - INFO - Visiting node at: (19, 29)
# 2024-11-24 00:22:00,243 - INFO - Visiting node at: (19, 28)
# 2024-11-24 00:22:00,243 - INFO - Visiting node at: (18, 28)
# 2024-11-24 00:22:00,243 - INFO - Visiting node at: (17, 28)
# 2024-11-24 00:22:00,243 - INFO - Visiting node at: (16, 28)
# 2024-11-24 00:22:00,244 - INFO - Visiting node at: (15, 28)
# 2024-11-24 00:22:00,244 - INFO - Visiting node at: (15, 27)
# 2024-11-24 00:22:00,244 - INFO - Visiting node at: (16, 27)
# 2024-11-24 00:22:00,244 - INFO - Visiting node at: (17, 27)
# 2024-11-24 00:22:00,245 - INFO - Visiting node at: (18, 27)
# 2024-11-24 00:22:00,245 - INFO - Visiting node at: (19, 27)
# 2024-11-24 00:22:00,245 - INFO - Visiting node at: (19, 26)
# 2024-11-24 00:22:00,246 - INFO - Visiting node at: (18, 26)
# 2024-11-24 00:22:00,246 - INFO - Visiting node at: (17, 26)
# 2024-11-24 00:22:00,247 - INFO - Visiting node at: (16, 26)
# 2024-11-24 00:22:00,247 - INFO - Visiting node at: (15, 26)
# 2024-11-24 00:22:00,249 - INFO - Visiting node at: (15, 25)
# 2024-11-24 00:22:00,249 - INFO - Visiting node at: (16, 25)
# 2024-11-24 00:22:00,250 - INFO - Visiting node at: (17, 25)
# 2024-11-24 00:22:00,250 - INFO - Visiting node at: (18, 25)
# 2024-11-24 00:22:00,250 - INFO - Visiting node at: (19, 25)
# 2024-11-24 00:22:00,250 - INFO - Visiting node at: (19, 24)
# 2024-11-24 00:22:00,250 - INFO - Visiting node at: (18, 24)
# 2024-11-24 00:22:00,251 - INFO - Visiting node at: (17, 24)
# 2024-11-24 00:22:00,251 - INFO - Visiting node at: (16, 24)
# 2024-11-24 00:22:00,251 - INFO - Visiting node at: (15, 24)
# 2024-11-24 00:22:00,252 - INFO - Visiting node at: (15, 23)
# 2024-11-24 00:22:00,252 - INFO - Visiting node at: (16, 23)
# 2024-11-24 00:22:00,252 - INFO - Visiting node at: (17, 23)
# 2024-11-24 00:22:00,252 - INFO - Visiting node at: (18, 23)
# 2024-11-24 00:22:00,253 - INFO - Visiting node at: (19, 23)
# 2024-11-24 00:22:00,253 - INFO - Visiting node at: (19, 22)
# 2024-11-24 00:22:00,253 - INFO - Visiting node at: (18, 22)
# 2024-11-24 00:22:00,254 - INFO - Visiting node at: (17, 22)
# 2024-11-24 00:22:00,254 - INFO - Visiting node at: (16, 22)
# 2024-11-24 00:22:00,254 - INFO - Visiting node at: (15, 22)
# 2024-11-24 00:22:00,255 - INFO - Visiting node at: (15, 21)
# 2024-11-24 00:22:00,255 - INFO - Visiting node at: (16, 21)
# 2024-11-24 00:22:00,255 - INFO - Visiting node at: (17, 21)
# 2024-11-24 00:22:00,255 - INFO - Visiting node at: (18, 21)
# 2024-11-24 00:22:00,256 - INFO - Visiting node at: (19, 21)
# 2024-11-24 00:22:00,256 - INFO - Visiting node at: (19, 20)
# 2024-11-24 00:22:00,257 - INFO - Visiting node at: (18, 20)
# 2024-11-24 00:22:00,257 - INFO - Visiting node at: (17, 20)
# 2024-11-24 00:22:00,257 - INFO - Visiting node at: (16, 20)
# 2024-11-24 00:22:00,257 - INFO - Visiting node at: (15, 20)
# 2024-11-24 00:22:00,259 - INFO - Visiting node at: (15, 19)
# 2024-11-24 00:22:00,259 - INFO - Visiting node at: (16, 19)
# 2024-11-24 00:22:00,259 - INFO - Visiting node at: (17, 19)
# 2024-11-24 00:22:00,260 - INFO - Visiting node at: (18, 19)
# 2024-11-24 00:22:00,260 - INFO - Visiting node at: (19, 19)
# 2024-11-24 00:22:00,261 - INFO - Visiting node at: (19, 18)
# 2024-11-24 00:22:00,261 - INFO - Visiting node at: (18, 18)
# 2024-11-24 00:22:00,261 - INFO - Visiting node at: (17, 18)
# 2024-11-24 00:22:00,261 - INFO - Visiting node at: (16, 18)
# 2024-11-24 00:22:00,262 - INFO - Visiting node at: (15, 18)
# 2024-11-24 00:22:00,262 - INFO - Visiting node at: (15, 17)
# 2024-11-24 00:22:00,262 - INFO - Visiting node at: (16, 17)
# 2024-11-24 00:22:00,263 - INFO - Visiting node at: (17, 17)
# 2024-11-24 00:22:00,263 - INFO - Visiting node at: (18, 17)
# 2024-11-24 00:22:00,263 - INFO - Visiting node at: (19, 17)
# 2024-11-24 00:22:00,263 - INFO - Visiting node at: (19, 16)
# 2024-11-24 00:22:00,264 - INFO - Visiting node at: (18, 16)
# 2024-11-24 00:22:00,264 - INFO - Visiting node at: (17, 16)
# 2024-11-24 00:22:00,264 - INFO - Visiting node at: (16, 16)
# 2024-11-24 00:22:00,265 - INFO - Visiting node at: (15, 16)
# 2024-11-24 00:22:00,265 - INFO - Visiting node at: (15, 15)
# 2024-11-24 00:22:00,265 - INFO - Visiting node at: (16, 15)
# 2024-11-24 00:22:00,266 - INFO - Visiting node at: (17, 15)
# 2024-11-24 00:22:00,266 - INFO - Visiting node at: (18, 15)
# 2024-11-24 00:22:00,266 - INFO - Visiting node at: (19, 15)
# 2024-11-24 00:22:00,266 - INFO - Visiting node at: (19, 14)
# 2024-11-24 00:22:00,267 - INFO - Visiting node at: (18, 14)
# 2024-11-24 00:22:00,267 - INFO - Visiting node at: (17, 14)
# 2024-11-24 00:22:00,267 - INFO - Visiting node at: (16, 14)
# 2024-11-24 00:22:00,267 - INFO - Visiting node at: (15, 14)
# 2024-11-24 00:22:00,268 - INFO - Visiting node at: (15, 13)
# 2024-11-24 00:22:00,268 - INFO - Visiting node at: (16, 13)
# 2024-11-24 00:22:00,268 - INFO - Visiting node at: (17, 13)
# 2024-11-24 00:22:00,269 - INFO - Visiting node at: (18, 13)
# 2024-11-24 00:22:00,269 - INFO - Visiting node at: (19, 13)
# 2024-11-24 00:22:00,270 - INFO - Visiting node at: (19, 12)
# 2024-11-24 00:22:00,270 - INFO - Visiting node at: (18, 12)
# 2024-11-24 00:22:00,270 - INFO - Visiting node at: (17, 12)
# 2024-11-24 00:22:00,271 - INFO - Visiting node at: (16, 12)
# 2024-11-24 00:22:00,271 - INFO - Visiting node at: (15, 12)
# 2024-11-24 00:22:00,271 - INFO - Visiting node at: (15, 11)
# 2024-11-24 00:22:00,272 - INFO - Visiting node at: (16, 11)
# 2024-11-24 00:22:00,272 - INFO - Visiting node at: (17, 11)
# 2024-11-24 00:22:00,272 - INFO - Visiting node at: (18, 11)
# 2024-11-24 00:22:00,273 - INFO - Visiting node at: (19, 11)
# 2024-11-24 00:22:00,273 - INFO - Visiting node at: (19, 10)
# 2024-11-24 00:22:00,273 - INFO - Visiting node at: (18, 10)
# 2024-11-24 00:22:00,273 - INFO - Visiting node at: (17, 10)
# 2024-11-24 00:22:00,274 - INFO - Visiting node at: (16, 10)
# 2024-11-24 00:22:00,274 - INFO - Visiting node at: (15, 10)
# 2024-11-24 00:22:00,275 - INFO - Visiting node at: (15, 9)
# 2024-11-24 00:22:00,275 - INFO - Visiting node at: (16, 9)
# 2024-11-24 00:22:00,275 - INFO - Visiting node at: (17, 9)
# 2024-11-24 00:22:00,275 - INFO - Visiting node at: (18, 9)
# 2024-11-24 00:22:00,276 - INFO - Visiting node at: (19, 9)
# 2024-11-24 00:22:00,276 - INFO - Visiting node at: (19, 8)
# 2024-11-24 00:22:00,276 - INFO - Visiting node at: (18, 8)
# 2024-11-24 00:22:00,276 - INFO - Visiting node at: (17, 8)
# 2024-11-24 00:22:00,276 - INFO - Visiting node at: (16, 8)
# 2024-11-24 00:22:00,278 - INFO - Visiting node at: (15, 8)
# 2024-11-24 00:22:00,278 - INFO - Visiting node at: (15, 7)
# 2024-11-24 00:22:00,278 - INFO - Visiting node at: (16, 7)
# 2024-11-24 00:22:00,279 - INFO - Visiting node at: (17, 7)
# 2024-11-24 00:22:00,279 - INFO - Visiting node at: (18, 7)
# 2024-11-24 00:22:00,279 - INFO - Visiting node at: (19, 7)
# 2024-11-24 00:22:00,280 - INFO - Visiting node at: (19, 6)
# 2024-11-24 00:22:00,280 - INFO - Visiting node at: (18, 6)
# 2024-11-24 00:22:00,280 - INFO - Visiting node at: (17, 6)
# 2024-11-24 00:22:00,280 - INFO - Visiting node at: (16, 6)
# 2024-11-24 00:22:00,281 - INFO - Visiting node at: (15, 6)
# 2024-11-24 00:22:00,281 - INFO - Visiting node at: (15, 5)
# 2024-11-24 00:22:00,281 - INFO - Visiting node at: (16, 5)
# 2024-11-24 00:22:00,281 - INFO - Visiting node at: (17, 5)
# 2024-11-24 00:22:00,281 - INFO - Visiting node at: (18, 5)
# 2024-11-24 00:22:00,282 - INFO - Visiting node at: (19, 5)
# 2024-11-24 00:22:00,282 - INFO - Visiting node at: (19, 4)
# 2024-11-24 00:22:00,282 - INFO - Visiting node at: (18, 4)
# 2024-11-24 00:22:00,283 - INFO - Visiting node at: (17, 4)
# 2024-11-24 00:22:00,283 - INFO - Visiting node at: (16, 4)
# 2024-11-24 00:22:00,283 - INFO - Visiting node at: (15, 4)
# 2024-11-24 00:22:00,284 - INFO - Visiting node at: (15, 3)
# 2024-11-24 00:22:00,284 - INFO - Visiting node at: (16, 3)
# 2024-11-24 00:22:00,284 - INFO - Visiting node at: (17, 3)
# 2024-11-24 00:22:00,286 - INFO - Visiting node at: (18, 3)
# 2024-11-24 00:22:00,286 - INFO - Visiting node at: (19, 3)
# 2024-11-24 00:22:00,286 - INFO - Visiting node at: (19, 2)
# 2024-11-24 00:22:00,286 - INFO - Visiting node at: (18, 2)
# 2024-11-24 00:22:00,287 - INFO - Visiting node at: (17, 2)
# 2024-11-24 00:22:00,287 - INFO - Visiting node at: (16, 2)
# 2024-11-24 00:22:00,287 - INFO - Visiting node at: (15, 2)
# 2024-11-24 00:22:00,287 - INFO - Visiting node at: (15, 1)
# 2024-11-24 00:22:00,287 - INFO - Visiting node at: (16, 1)
# 2024-11-24 00:22:00,288 - INFO - Visiting node at: (17, 1)
# 2024-11-24 00:22:00,288 - INFO - Visiting node at: (18, 1)
# 2024-11-24 00:22:00,289 - INFO - Visiting node at: (19, 1)
# 2024-11-24 00:22:00,290 - INFO - Visiting node at: (19, 34)
# 2024-11-24 00:22:00,290 - INFO - Visiting node at: (18, 34)
# 2024-11-24 00:22:00,290 - INFO - Visiting node at: (17, 34)
# 2024-11-24 00:22:00,291 - INFO - Visiting node at: (16, 34)
# 2024-11-24 00:22:00,291 - INFO - Visiting node at: (15, 34)
# 2024-11-24 00:22:00,292 - INFO - Visiting node at: (14, 34)
# 2024-11-24 00:22:00,292 - INFO - Visiting node at: (13, 34)
# 2024-11-24 00:22:00,293 - INFO - Visiting node at: (12, 34)
# 2024-11-24 00:22:00,293 - INFO - Visiting node at: (11, 34)
# 2024-11-24 00:22:00,293 - INFO - Visiting node at: (10, 34)
# 2024-11-24 00:22:00,294 - INFO - Visiting node at: (9, 34)
# 2024-11-24 00:22:00,294 - INFO - Visiting node at: (8, 34)
# 2024-11-24 00:22:00,295 - INFO - Visiting node at: (7, 34)
# 2024-11-24 00:22:00,295 - INFO - Visiting node at: (7, 35)
# 2024-11-24 00:22:00,295 - INFO - Visiting node at: (8, 35)
# 2024-11-24 00:22:00,296 - INFO - Visiting node at: (9, 35)
# 2024-11-24 00:22:00,296 - INFO - Visiting node at: (10, 35)
# 2024-11-24 00:22:00,296 - INFO - Visiting node at: (11, 35)
# 2024-11-24 00:22:00,298 - INFO - Visiting node at: (12, 35)
# 2024-11-24 00:22:00,298 - INFO - Visiting node at: (13, 35)
# 2024-11-24 00:22:00,298 - INFO - Visiting node at: (14, 35)
# 2024-11-24 00:22:00,299 - INFO - Visiting node at: (15, 35)
# 2024-11-24 00:22:00,300 - INFO - Visiting node at: (16, 35)
# 2024-11-24 00:22:00,300 - INFO - Visiting node at: (17, 35)
# 2024-11-24 00:22:00,300 - INFO - Visiting node at: (18, 35)
# 2024-11-24 00:22:00,300 - INFO - Visiting node at: (19, 35)
# 2024-11-24 00:22:00,300 - INFO - Visiting node at: (19, 36)
# 2024-11-24 00:22:00,301 - INFO - Visiting node at: (18, 36)
# 2024-11-24 00:22:00,301 - INFO - Visiting node at: (17, 36)
# 2024-11-24 00:22:00,301 - INFO - Visiting node at: (16, 36)
# 2024-11-24 00:22:00,301 - INFO - Visiting node at: (15, 36)
# 2024-11-24 00:22:00,302 - INFO - Visiting node at: (14, 36)
# 2024-11-24 00:22:00,302 - INFO - Visiting node at: (13, 36)
# 2024-11-24 00:22:00,303 - INFO - Visiting node at: (12, 36)
# 2024-11-24 00:22:00,303 - INFO - Visiting node at: (11, 36)
# 2024-11-24 00:22:00,303 - INFO - Visiting node at: (10, 36)
# 2024-11-24 00:22:00,303 - INFO - Visiting node at: (9, 36)
# 2024-11-24 00:22:00,304 - INFO - Visiting node at: (8, 36)
# 2024-11-24 00:22:00,304 - INFO - Visiting node at: (7, 36)
# 2024-11-24 00:22:00,304 - INFO - Visiting node at: (7, 37)
# 2024-11-24 00:22:00,305 - INFO - Visiting node at: (8, 37)
# 2024-11-24 00:22:00,305 - INFO - Visiting node at: (9, 37)
# 2024-11-24 00:22:00,305 - INFO - Visiting node at: (10, 37)
# 2024-11-24 00:22:00,305 - INFO - Visiting node at: (11, 37)
# 2024-11-24 00:22:00,305 - INFO - Visiting node at: (12, 37)
# 2024-11-24 00:22:00,306 - INFO - Visiting node at: (13, 37)
# 2024-11-24 00:22:00,306 - INFO - Visiting node at: (14, 37)
# 2024-11-24 00:22:00,306 - INFO - Visiting node at: (15, 37)
# 2024-11-24 00:22:00,306 - INFO - Visiting node at: (16, 37)
# 2024-11-24 00:22:00,307 - INFO - Visiting node at: (17, 37)
# 2024-11-24 00:22:00,307 - INFO - Visiting node at: (18, 37)
# 2024-11-24 00:22:00,308 - INFO - Visiting node at: (19, 37)
# 2024-11-24 00:22:00,308 - INFO - Visiting node at: (19, 38)
# 2024-11-24 00:22:00,308 - INFO - Visiting node at: (18, 38)
# 2024-11-24 00:22:00,309 - INFO - Visiting node at: (17, 38)
# 2024-11-24 00:22:00,309 - INFO - Visiting node at: (16, 38)
# 2024-11-24 00:22:00,309 - INFO - Visiting node at: (15, 38)
# 2024-11-24 00:22:00,309 - INFO - Visiting node at: (14, 38)
# 2024-11-24 00:22:00,309 - INFO - Visiting node at: (13, 38)
# 2024-11-24 00:22:00,310 - INFO - Visiting node at: (12, 38)
# 2024-11-24 00:22:00,310 - INFO - Visiting node at: (11, 38)
# 2024-11-24 00:22:00,310 - INFO - Visiting node at: (11, 39)
# 2024-11-24 00:22:00,310 - INFO - Visiting node at: (12, 39)
# 2024-11-24 00:22:00,312 - INFO - Visiting node at: (13, 39)
# 2024-11-24 00:22:00,312 - INFO - Visiting node at: (14, 39)
# 2024-11-24 00:22:00,312 - INFO - Visiting node at: (15, 39)
# 2024-11-24 00:22:00,313 - INFO - Visiting node at: (16, 39)
# 2024-11-24 00:22:00,313 - INFO - Visiting node at: (17, 39)
# 2024-11-24 00:22:00,313 - INFO - Visiting node at: (18, 39)
# 2024-11-24 00:22:00,314 - INFO - Visiting node at: (19, 39)
# 2024-11-24 00:22:00,314 - INFO - Visiting node at: (19, 40)
# 2024-11-24 00:22:00,314 - INFO - Visiting node at: (18, 40)
# 2024-11-24 00:22:00,314 - INFO - Visiting node at: (17, 40)
# 2024-11-24 00:22:00,315 - INFO - Visiting node at: (16, 40)
# 2024-11-24 00:22:00,315 - INFO - Visiting node at: (15, 40)
# 2024-11-24 00:22:00,315 - INFO - Visiting node at: (14, 40)
# 2024-11-24 00:22:00,315 - INFO - Visiting node at: (13, 40)
# 2024-11-24 00:22:00,316 - INFO - Visiting node at: (12, 40)
# 2024-11-24 00:22:00,316 - INFO - Visiting node at: (11, 40)
# 2024-11-24 00:22:00,316 - INFO - Visiting node at: (11, 41)
# 2024-11-24 00:22:00,316 - INFO - Visiting node at: (12, 41)
# 2024-11-24 00:22:00,316 - INFO - Visiting node at: (13, 41)
# 2024-11-24 00:22:00,317 - INFO - Visiting node at: (14, 41)
# 2024-11-24 00:22:00,317 - INFO - Visiting node at: (15, 41)
# 2024-11-24 00:22:00,317 - INFO - Visiting node at: (16, 41)
# 2024-11-24 00:22:00,318 - INFO - Visiting node at: (17, 41)
# 2024-11-24 00:22:00,318 - INFO - Visiting node at: (18, 41)
# 2024-11-24 00:22:00,318 - INFO - Visiting node at: (19, 41)
# 2024-11-24 00:22:00,319 - INFO - Visiting node at: (19, 42)
# 2024-11-24 00:22:00,319 - INFO - Visiting node at: (18, 42)
# 2024-11-24 00:22:00,319 - INFO - Visiting node at: (17, 42)
# 2024-11-24 00:22:00,319 - INFO - Visiting node at: (16, 42)
# 2024-11-24 00:22:00,320 - INFO - Visiting node at: (15, 42)
# 2024-11-24 00:22:00,320 - INFO - Visiting node at: (14, 42)
# 2024-11-24 00:22:00,320 - INFO - Visiting node at: (13, 42)
# 2024-11-24 00:22:00,321 - INFO - Visiting node at: (12, 42)
# 2024-11-24 00:22:00,321 - INFO - Visiting node at: (11, 42)
# 2024-11-24 00:22:00,322 - INFO - Visiting node at: (11, 43)
# 2024-11-24 00:22:00,322 - INFO - Visiting node at: (12, 43)
# 2024-11-24 00:22:00,322 - INFO - Visiting node at: (13, 43)
# 2024-11-24 00:22:00,322 - INFO - Visiting node at: (14, 43)
# 2024-11-24 00:22:00,323 - INFO - Visiting node at: (15, 43)
# 2024-11-24 00:22:00,323 - INFO - Visiting node at: (16, 43)
# 2024-11-24 00:22:00,323 - INFO - Visiting node at: (17, 43)
# 2024-11-24 00:22:00,323 - INFO - Visiting node at: (18, 43)
# 2024-11-24 00:22:00,324 - INFO - Visiting node at: (19, 43)
# 2024-11-24 00:22:00,324 - INFO - Visiting node at: (19, 44)
# 2024-11-24 00:22:00,324 - INFO - Visiting node at: (18, 44)
# 2024-11-24 00:22:00,325 - INFO - Visiting node at: (17, 44)
# 2024-11-24 00:22:00,325 - INFO - Visiting node at: (16, 44)
# 2024-11-24 00:22:00,326 - INFO - Visiting node at: (15, 44)
# 2024-11-24 00:22:00,326 - INFO - Visiting node at: (14, 44)
# 2024-11-24 00:22:00,326 - INFO - Visiting node at: (13, 44)
# 2024-11-24 00:22:00,327 - INFO - Visiting node at: (12, 44)
# 2024-11-24 00:22:00,327 - INFO - Visiting node at: (11, 44)
# 2024-11-24 00:22:00,327 - INFO - Visiting node at: (11, 45)
# 2024-11-24 00:22:00,328 - INFO - Visiting node at: (12, 45)
# 2024-11-24 00:22:00,328 - INFO - Visiting node at: (13, 45)
# 2024-11-24 00:22:00,328 - INFO - Visiting node at: (14, 45)
# 2024-11-24 00:22:00,328 - INFO - Visiting node at: (15, 45)
# 2024-11-24 00:22:00,329 - INFO - Visiting node at: (16, 45)
# 2024-11-24 00:22:00,329 - INFO - Visiting node at: (17, 45)
# 2024-11-24 00:22:00,329 - INFO - Visiting node at: (18, 45)
# 2024-11-24 00:22:00,329 - INFO - Visiting node at: (19, 45)
# 2024-11-24 00:22:00,330 - INFO - Visiting node at: (19, 46)
# 2024-11-24 00:22:00,330 - INFO - Visiting node at: (18, 46)
# 2024-11-24 00:22:00,330 - INFO - Visiting node at: (17, 46)
# 2024-11-24 00:22:00,331 - INFO - Visiting node at: (16, 46)
# 2024-11-24 00:22:00,333 - INFO - Visiting node at: (15, 46)
# 2024-11-24 00:22:00,333 - INFO - Visiting node at: (14, 46)
# 2024-11-24 00:22:00,333 - INFO - Visiting node at: (13, 46)
# 2024-11-24 00:22:00,334 - INFO - Visiting node at: (12, 46)
# 2024-11-24 00:22:00,334 - INFO - Visiting node at: (11, 46)
# 2024-11-24 00:22:00,334 - INFO - Visiting node at: (11, 47)
# 2024-11-24 00:22:00,334 - INFO - Visiting node at: (12, 47)
# 2024-11-24 00:22:00,335 - INFO - Visiting node at: (13, 47)
# 2024-11-24 00:22:00,335 - INFO - Visiting node at: (14, 47)
# 2024-11-24 00:22:00,335 - INFO - Visiting node at: (15, 47)
# 2024-11-24 00:22:00,335 - INFO - Visiting node at: (16, 47)
# 2024-11-24 00:22:00,335 - INFO - Visiting node at: (17, 47)
# 2024-11-24 00:22:00,336 - INFO - Visiting node at: (18, 47)
# 2024-11-24 00:22:00,336 - INFO - Visiting node at: (19, 47)
# 2024-11-24 00:22:00,336 - INFO - Visiting node at: (12, 48)
# 2024-11-24 00:22:00,337 - INFO - Visiting node at: (11, 48)
# 2024-11-24 00:22:00,337 - INFO - Visiting node at: (11, 49)
# 2024-11-24 00:22:00,337 - INFO - Visiting node at: (12, 49)
# 2024-11-24 00:22:00,338 - INFO - Visiting node at: (13, 49)
# 2024-11-24 00:22:00,338 - INFO - Visiting node at: (14, 49)
# 2024-11-24 00:22:00,338 - INFO - Visiting node at: (15, 49)
# 2024-11-24 00:22:00,338 - INFO - Visiting node at: (16, 49)
# 2024-11-24 00:22:00,338 - INFO - Visiting node at: (17, 49)
# 2024-11-24 00:22:00,339 - INFO - Visiting node at: (18, 49)
# 2024-11-24 00:22:00,339 - INFO - Visiting node at: (19, 49)
# 2024-11-24 00:22:00,339 - INFO - Visiting node at: (19, 50)
# 2024-11-24 00:22:00,339 - INFO - Visiting node at: (18, 50)
# 2024-11-24 00:22:00,341 - INFO - Visiting node at: (17, 50)
# 2024-11-24 00:22:00,341 - INFO - Visiting node at: (16, 50)
# 2024-11-24 00:22:00,341 - INFO - Visiting node at: (15, 50)
# 2024-11-24 00:22:00,341 - INFO - Visiting node at: (14, 50)
# 2024-11-24 00:22:00,342 - INFO - Visiting node at: (13, 50)
# 2024-11-24 00:22:00,342 - INFO - Visiting node at: (12, 50)
# 2024-11-24 00:22:00,343 - INFO - Visiting node at: (11, 50)
# 2024-11-24 00:22:00,343 - INFO - Visiting node at: (11, 51)
# 2024-11-24 00:22:00,343 - INFO - Visiting node at: (12, 51)
# 2024-11-24 00:22:00,344 - INFO - Visiting node at: (13, 51)
# 2024-11-24 00:22:00,345 - INFO - Visiting node at: (14, 51)
# 2024-11-24 00:22:00,345 - INFO - Visiting node at: (15, 51)
# 2024-11-24 00:22:00,346 - INFO - Visiting node at: (16, 51)
# 2024-11-24 00:22:00,346 - INFO - Visiting node at: (17, 51)
# 2024-11-24 00:22:00,346 - INFO - Visiting node at: (18, 51)
# 2024-11-24 00:22:00,347 - INFO - Visiting node at: (19, 51)
# 2024-11-24 00:22:00,349 - INFO - Visiting node at: (19, 52)
# 2024-11-24 00:22:00,350 - INFO - Visiting node at: (18, 52)
# 2024-11-24 00:22:00,350 - INFO - Visiting node at: (17, 52)
# 2024-11-24 00:22:00,350 - INFO - Visiting node at: (16, 52)
# 2024-11-24 00:22:00,351 - INFO - Visiting node at: (15, 52)
# 2024-11-24 00:22:00,352 - INFO - Visiting node at: (14, 52)
# 2024-11-24 00:22:00,353 - INFO - Visiting node at: (13, 52)
# 2024-11-24 00:22:00,353 - INFO - Visiting node at: (12, 52)
# 2024-11-24 00:22:00,354 - INFO - Visiting node at: (11, 52)
# 2024-11-24 00:22:00,355 - INFO - Visiting node at: (11, 53)
# 2024-11-24 00:22:00,356 - INFO - Visiting node at: (12, 53)
# 2024-11-24 00:22:00,356 - INFO - Visiting node at: (13, 53)
# 2024-11-24 00:22:00,357 - INFO - Visiting node at: (14, 53)
# 2024-11-24 00:22:00,357 - INFO - Visiting node at: (15, 53)
# 2024-11-24 00:22:00,358 - INFO - Visiting node at: (16, 53)
# 2024-11-24 00:22:00,358 - INFO - Visiting node at: (17, 53)
# 2024-11-24 00:22:00,359 - INFO - Visiting node at: (18, 53)
# 2024-11-24 00:22:00,359 - INFO - Visiting node at: (19, 53)
# 2024-11-24 00:22:00,359 - INFO - Visiting node at: (19, 54)
# 2024-11-24 00:22:00,360 - INFO - Visiting node at: (18, 54)
# 2024-11-24 00:22:00,360 - INFO - Visiting node at: (17, 54)
# 2024-11-24 00:22:00,361 - INFO - Visiting node at: (16, 54)
# 2024-11-24 00:22:00,361 - INFO - Visiting node at: (15, 54)
# 2024-11-24 00:22:00,362 - INFO - Visiting node at: (14, 54)
# 2024-11-24 00:22:00,362 - INFO - Visiting node at: (13, 54)
# 2024-11-24 00:22:00,362 - INFO - Visiting node at: (12, 54)
# 2024-11-24 00:22:00,363 - INFO - Visiting node at: (11, 54)
# 2024-11-24 00:22:00,363 - INFO - Visiting node at: (11, 55)
# 2024-11-24 00:22:00,363 - INFO - Visiting node at: (12, 55)
# 2024-11-24 00:22:00,364 - INFO - Visiting node at: (13, 55)
# 2024-11-24 00:22:00,364 - INFO - Visiting node at: (14, 55)
# 2024-11-24 00:22:00,365 - INFO - Visiting node at: (15, 55)
# 2024-11-24 00:22:00,365 - INFO - Visiting node at: (16, 55)
# 2024-11-24 00:22:00,366 - INFO - Visiting node at: (17, 55)
# 2024-11-24 00:22:00,366 - INFO - Visiting node at: (18, 55)
# 2024-11-24 00:22:00,366 - INFO - Visiting node at: (19, 55)
# 2024-11-24 00:22:00,368 - INFO - Visiting node at: (19, 56)
# 2024-11-24 00:22:00,368 - INFO - Visiting node at: (18, 56)
# 2024-11-24 00:22:00,368 - INFO - Visiting node at: (17, 56)
# 2024-11-24 00:22:00,369 - INFO - Visiting node at: (16, 56)
# 2024-11-24 00:22:00,369 - INFO - Visiting node at: (15, 56)
# 2024-11-24 00:22:00,369 - INFO - Visiting node at: (14, 56)
# 2024-11-24 00:22:00,370 - INFO - Visiting node at: (13, 56)
# 2024-11-24 00:22:00,370 - INFO - Visiting node at: (12, 56)
# 2024-11-24 00:22:00,370 - INFO - Visiting node at: (11, 56)
# 2024-11-24 00:22:00,370 - INFO - Visiting node at: (11, 57)
# 2024-11-24 00:22:00,371 - INFO - Visiting node at: (12, 57)
# 2024-11-24 00:22:00,371 - INFO - Visiting node at: (13, 57)
# 2024-11-24 00:22:00,371 - INFO - Visiting node at: (14, 57)
# 2024-11-24 00:22:00,372 - INFO - Visiting node at: (15, 57)
# 2024-11-24 00:22:00,373 - INFO - Visiting node at: (16, 57)
# 2024-11-24 00:22:00,373 - INFO - Visiting node at: (17, 57)
# 2024-11-24 00:22:00,376 - INFO - Visiting node at: (18, 57)
# 2024-11-24 00:22:00,378 - INFO - Visiting node at: (19, 57)
# 2024-11-24 00:22:00,378 - INFO - Visiting node at: (19, 58)
# 2024-11-24 00:22:00,379 - INFO - Visiting node at: (18, 58)
# 2024-11-24 00:22:00,379 - INFO - Visiting node at: (17, 58)
# 2024-11-24 00:22:00,380 - INFO - Visiting node at: (16, 58)
# 2024-11-24 00:22:00,381 - INFO - Visiting node at: (15, 58)
# 2024-11-24 00:22:00,381 - INFO - Visiting node at: (14, 58)
# 2024-11-24 00:22:00,381 - INFO - Visiting node at: (13, 58)
# 2024-11-24 00:22:00,381 - INFO - Visiting node at: (12, 58)
# 2024-11-24 00:22:00,383 - INFO - Visiting node at: (11, 58)
# 2024-11-24 00:22:00,383 - INFO - Visiting node at: (11, 59)
# 2024-11-24 00:22:00,383 - INFO - Visiting node at: (12, 59)
# 2024-11-24 00:22:00,383 - INFO - Visiting node at: (13, 59)
# 2024-11-24 00:22:00,384 - INFO - Visiting node at: (14, 59)
# 2024-11-24 00:22:00,384 - INFO - Visiting node at: (15, 59)
# 2024-11-24 00:22:00,384 - INFO - Visiting node at: (16, 59)
# 2024-11-24 00:22:00,385 - INFO - Visiting node at: (17, 59)
# 2024-11-24 00:22:00,385 - INFO - Visiting node at: (18, 59)
# 2024-11-24 00:22:00,388 - INFO - Visiting node at: (19, 59)
# 2024-11-24 00:22:00,389 - INFO - Visiting node at: (19, 60)
# 2024-11-24 00:22:00,389 - INFO - Visiting node at: (18, 60)
# 2024-11-24 00:22:00,389 - INFO - Visiting node at: (17, 60)
# 2024-11-24 00:22:00,389 - INFO - Visiting node at: (16, 60)
# 2024-11-24 00:22:00,390 - INFO - Visiting node at: (15, 60)
# 2024-11-24 00:22:00,390 - INFO - Visiting node at: (14, 60)
# 2024-11-24 00:22:00,390 - INFO - Visiting node at: (13, 60)
# 2024-11-24 00:22:00,391 - INFO - Visiting node at: (12, 60)
# 2024-11-24 00:22:00,393 - INFO - Visiting node at: (11, 60)
# 2024-11-24 00:22:00,393 - INFO - Visiting node at: (11, 61)
# 2024-11-24 00:22:00,393 - INFO - Visiting node at: (12, 61)
# 2024-11-24 00:22:00,394 - INFO - Visiting node at: (13, 61)
# 2024-11-24 00:22:00,394 - INFO - Visiting node at: (14, 61)
# 2024-11-24 00:22:00,394 - INFO - Visiting node at: (15, 61)
# 2024-11-24 00:22:00,394 - INFO - Visiting node at: (16, 61)
# 2024-11-24 00:22:00,394 - INFO - Visiting node at: (17, 61)
# 2024-11-24 00:22:00,395 - INFO - Visiting node at: (18, 61)
# 2024-11-24 00:22:00,395 - INFO - Visiting node at: (19, 61)
# 2024-11-24 00:22:00,395 - INFO - Visiting node at: (19, 62)
# 2024-11-24 00:22:00,396 - INFO - Visiting node at: (18, 62)
# 2024-11-24 00:22:00,396 - INFO - Visiting node at: (17, 62)
# 2024-11-24 00:22:00,396 - INFO - Visiting node at: (16, 62)
# 2024-11-24 00:22:00,397 - INFO - Visiting node at: (15, 62)
# 2024-11-24 00:22:00,397 - INFO - Visiting node at: (14, 62)
# 2024-11-24 00:22:00,397 - INFO - Visiting node at: (13, 62)
# 2024-11-24 00:22:00,398 - INFO - Visiting node at: (12, 62)
# 2024-11-24 00:22:00,398 - INFO - Visiting node at: (11, 62)
# 2024-11-24 00:22:00,399 - INFO - Visiting node at: (11, 63)
# 2024-11-24 00:22:00,399 - INFO - Visiting node at: (12, 63)
# 2024-11-24 00:22:00,399 - INFO - Visiting node at: (13, 63)
# 2024-11-24 00:22:00,399 - INFO - Visiting node at: (14, 63)
# 2024-11-24 00:22:00,400 - INFO - Visiting node at: (15, 63)
# 2024-11-24 00:22:00,400 - INFO - Visiting node at: (16, 63)
# 2024-11-24 00:22:00,400 - INFO - Visiting node at: (17, 63)
# 2024-11-24 00:22:00,400 - INFO - Visiting node at: (18, 63)
# 2024-11-24 00:22:00,401 - INFO - Visiting node at: (19, 63)
# 2024-11-24 00:22:00,401 - INFO - Visiting node at: (19, 64)
# 2024-11-24 00:22:00,401 - INFO - Visiting node at: (18, 64)
# 2024-11-24 00:22:00,403 - INFO - Visiting node at: (17, 64)
# 2024-11-24 00:22:00,403 - INFO - Visiting node at: (16, 64)
# 2024-11-24 00:22:00,403 - INFO - Visiting node at: (15, 64)
# 2024-11-24 00:22:00,404 - INFO - Visiting node at: (14, 64)
# 2024-11-24 00:22:00,404 - INFO - Visiting node at: (13, 64)
# 2024-11-24 00:22:00,404 - INFO - Visiting node at: (12, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (11, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (10, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (9, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (8, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (7, 64)
# 2024-11-24 00:22:00,405 - INFO - Visiting node at: (6, 64)
# 2024-11-24 00:22:00,406 - INFO - Visiting node at: (5, 64)
# 2024-11-24 00:22:00,406 - INFO - Visiting node at: (4, 64)
# 2024-11-24 00:22:00,406 - INFO - Visiting node at: (3, 64)
# 2024-11-24 00:22:00,406 - INFO - Visiting node at: (2, 64)
# 2024-11-24 00:22:00,407 - INFO - Visiting node at: (1, 64)
# 2024-11-24 00:22:00,407 - INFO - Visiting node at: (1, 63)
# 2024-11-24 00:22:00,407 - INFO - Visiting node at: (2, 63)
# 2024-11-24 00:22:00,408 - INFO - Visiting node at: (3, 63)
# ...
# 2024-11-24 00:22:00,700 - INFO - Marking path at: (16, 38)
# 2024-11-24 00:22:00,700 - INFO - Marking path at: (17, 38)
# 2024-11-24 00:22:00,701 - INFO - Marking path at: (18, 38)
# 2024-11-24 00:22:00,701 - INFO - Marking path at: (19, 38)
# 2024-11-24 00:22:00,701 - INFO - Marking path at: (19, 37)
# 2024-11-24 00:22:00,702 - INFO - Marking path at: (18, 37)
# 2024-11-24 00:22:00,702 - INFO - Marking path at: (17, 37)
# 2024-11-24 00:22:00,702 - INFO - Marking path at: (16, 37)
# 2024-11-24 00:22:00,703 - INFO - Marking path at: (15, 37)
# 2024-11-24 00:22:00,704 - INFO - Marking path at: (14, 37)
# 2024-11-24 00:22:00,704 - INFO - Marking path at: (13, 37)
# 2024-11-24 00:22:00,704 - INFO - Marking path at: (12, 37)
# 2024-11-24 00:22:00,705 - INFO - Marking path at: (11, 37)
# 2024-11-24 00:22:00,705 - INFO - Marking path at: (10, 37)
# 2024-11-24 00:22:00,706 - INFO - Marking path at: (9, 37)
# 2024-11-24 00:22:00,706 - INFO - Marking path at: (8, 37)
# 2024-11-24 00:22:00,707 - INFO - Marking path at: (7, 37)
# 2024-11-24 00:22:00,707 - INFO - Marking path at: (7, 36)
# 2024-11-24 00:22:00,707 - INFO - Marking path at: (8, 36)
# 2024-11-24 00:22:00,708 - INFO - Marking path at: (9, 36)
# 2024-11-24 00:22:00,708 - INFO - Marking path at: (10, 36)
# 2024-11-24 00:22:00,708 - INFO - Marking path at: (11, 36)
# 2024-11-24 00:22:00,708 - INFO - Marking path at: (12, 36)
# 2024-11-24 00:22:00,709 - INFO - Marking path at: (13, 36)
# 2024-11-24 00:22:00,709 - INFO - Marking path at: (14, 36)
# 2024-11-24 00:22:00,709 - INFO - Marking path at: (15, 36)
# 2024-11-24 00:22:00,710 - INFO - Marking path at: (16, 36)
# 2024-11-24 00:22:00,710 - INFO - Marking path at: (17, 36)
# 2024-11-24 00:22:00,710 - INFO - Marking path at: (18, 36)
# 2024-11-24 00:22:00,710 - INFO - Marking path at: (19, 36)
# 2024-11-24 00:22:00,711 - INFO - Marking path at: (19, 35)
# 2024-11-24 00:22:00,711 - INFO - Marking path at: (18, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (17, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (16, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (15, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (14, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (13, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (12, 35)
# 2024-11-24 00:22:00,712 - INFO - Marking path at: (11, 35)
# 2024-11-24 00:22:00,714 - INFO - Marking path at: (10, 35)
# 2024-11-24 00:22:00,714 - INFO - Marking path at: (9, 35)
# 2024-11-24 00:22:00,714 - INFO - Marking path at: (8, 35)
# 2024-11-24 00:22:00,716 - INFO - Marking path at: (7, 35)
# 2024-11-24 00:22:00,716 - INFO - Marking path at: (7, 34)
# 2024-11-24 00:22:00,716 - INFO - Marking path at: (8, 34)
# 2024-11-24 00:22:00,716 - INFO - Marking path at: (9, 34)
# 2024-11-24 00:22:00,717 - INFO - Marking path at: (10, 34)
# 2024-11-24 00:22:00,717 - INFO - Marking path at: (11, 34)
# 2024-11-24 00:22:00,717 - INFO - Marking path at: (12, 34)
# 2024-11-24 00:22:00,717 - INFO - Marking path at: (13, 34)
# 2024-11-24 00:22:00,718 - INFO - Marking path at: (14, 34)
# 2024-11-24 00:22:00,718 - INFO - Marking path at: (15, 34)
# 2024-11-24 00:22:00,718 - INFO - Marking path at: (16, 34)
# 2024-11-24 00:22:00,718 - INFO - Marking path at: (17, 34)
# 2024-11-24 00:22:00,718 - INFO - Marking path at: (18, 34)
# 2024-11-24 00:22:00,719 - INFO - Marking path at: (19, 34)
# 2024-11-24 00:22:00,719 - INFO - Marking path at: (19, 33)
# 2024-11-24 00:22:00,719 - INFO - Marking path at: (18, 33)
# 2024-11-24 00:22:00,721 - INFO - Marking path at: (17, 33)
# 2024-11-24 00:22:00,721 - INFO - Marking path at: (16, 33)
# 2024-11-24 00:22:00,722 - INFO - Marking path at: (15, 33)
# 2024-11-24 00:22:00,723 - INFO - Marking path at: (14, 33)
# 2024-11-24 00:22:00,723 - INFO - Marking path at: (13, 33)
# 2024-11-24 00:22:00,723 - INFO - Marking path at: (12, 33)
# 2024-11-24 00:22:00,723 - INFO - Marking path at: (11, 33)
# 2024-11-24 00:22:00,724 - INFO - Marking path at: (10, 33)
# 2024-11-24 00:22:00,724 - INFO - Marking path at: (9, 33)
# 2024-11-24 00:22:00,724 - INFO - Marking path at: (8, 33)
# 2024-11-24 00:22:00,724 - INFO - Marking path at: (7, 33)
# 2024-11-24 00:22:00,725 - INFO - Marking path at: (7, 32)
# 2024-11-24 00:22:00,725 - INFO - Marking path at: (8, 32)
# 2024-11-24 00:22:00,725 - INFO - Marking path at: (9, 32)
# 2024-11-24 00:22:00,725 - INFO - Marking path at: (10, 32)
# 2024-11-24 00:22:00,725 - INFO - Marking path at: (11, 32)
# 2024-11-24 00:22:00,726 - INFO - Marking path at: (12, 32)
# 2024-11-24 00:22:00,726 - INFO - Marking path at: (13, 32)
# 2024-11-24 00:22:00,726 - INFO - Marking path at: (13, 31)
# 2024-11-24 00:22:00,727 - INFO - Marking path at: (12, 31)
# 2024-11-24 00:22:00,727 - INFO - Marking path at: (11, 31)
# 2024-11-24 00:22:00,727 - INFO - Marking path at: (10, 31)
# 2024-11-24 00:22:00,729 - INFO - Marking path at: (9, 31)
# 2024-11-24 00:22:00,729 - INFO - Marking path at: (8, 31)
# 2024-11-24 00:22:00,729 - INFO - Marking path at: (7, 31)
# 2024-11-24 00:22:00,729 - INFO - Marking path at: (7, 30)
# 2024-11-24 00:22:00,729 - INFO - Marking path at: (8, 30)
# 2024-11-24 00:22:00,730 - INFO - Marking path at: (9, 30)
# 2024-11-24 00:22:00,730 - INFO - Marking path at: (10, 30)
# 2024-11-24 00:22:00,730 - INFO - Marking path at: (11, 30)
# 2024-11-24 00:22:00,731 - INFO - Marking path at: (12, 30)
# 2024-11-24 00:22:00,731 - INFO - Marking path at: (13, 30)
# 2024-11-24 00:22:00,731 - INFO - Marking path at: (13, 29)
# 2024-11-24 00:22:00,732 - INFO - Marking path at: (12, 29)
# 2024-11-24 00:22:00,732 - INFO - Marking path at: (11, 29)
# 2024-11-24 00:22:00,732 - INFO - Marking path at: (10, 29)
# 2024-11-24 00:22:00,733 - INFO - Marking path at: (9, 29)
# 2024-11-24 00:22:00,733 - INFO - Marking path at: (8, 29)
# 2024-11-24 00:22:00,733 - INFO - Marking path at: (7, 29)
# 2024-11-24 00:22:00,733 - INFO - Marking path at: (7, 28)
# 2024-11-24 00:22:00,734 - INFO - Marking path at: (8, 28)
# 2024-11-24 00:22:00,738 - INFO - Marking path at: (9, 28)
# 2024-11-24 00:22:00,739 - INFO - Marking path at: (10, 28)
# 2024-11-24 00:22:00,739 - INFO - Marking path at: (11, 28)
# 2024-11-24 00:22:00,740 - INFO - Marking path at: (12, 28)
# 2024-11-24 00:22:00,740 - INFO - Marking path at: (13, 28)
# 2024-11-24 00:22:00,740 - INFO - Marking path at: (13, 27)
# 2024-11-24 00:22:00,740 - INFO - Marking path at: (12, 27)
# 2024-11-24 00:22:00,741 - INFO - Marking path at: (11, 27)
# 2024-11-24 00:22:00,741 - INFO - Marking path at: (10, 27)
# 2024-11-24 00:22:00,741 - INFO - Marking path at: (9, 27)
# 2024-11-24 00:22:00,741 - INFO - Marking path at: (8, 27)
# 2024-11-24 00:22:00,742 - INFO - Marking path at: (7, 27)
# 2024-11-24 00:22:00,743 - INFO - Marking path at: (7, 26)
# 2024-11-24 00:22:00,743 - INFO - Marking path at: (8, 26)
# 2024-11-24 00:22:00,744 - INFO - Marking path at: (9, 26)
# 2024-11-24 00:22:00,744 - INFO - Marking path at: (10, 26)
# 2024-11-24 00:22:00,745 - INFO - Marking path at: (11, 26)
# 2024-11-24 00:22:00,745 - INFO - Marking path at: (12, 26)
# 2024-11-24 00:22:00,746 - INFO - Marking path at: (13, 26)
# 2024-11-24 00:22:00,746 - INFO - Marking path at: (13, 25)
# 2024-11-24 00:22:00,746 - INFO - Marking path at: (12, 25)
# 2024-11-24 00:22:00,746 - INFO - Marking path at: (11, 25)
# 2024-11-24 00:22:00,747 - INFO - Marking path at: (10, 25)
# 2024-11-24 00:22:00,747 - INFO - Marking path at: (9, 25)
# 2024-11-24 00:22:00,748 - INFO - Marking path at: (8, 25)
# 2024-11-24 00:22:00,748 - INFO - Marking path at: (7, 25)
# 2024-11-24 00:22:00,749 - INFO - Marking path at: (7, 24)
# 2024-11-24 00:22:00,749 - INFO - Marking path at: (8, 24)
# 2024-11-24 00:22:00,750 - INFO - Marking path at: (9, 24)
# 2024-11-24 00:22:00,751 - INFO - Marking path at: (10, 24)
# 2024-11-24 00:22:00,752 - INFO - Marking path at: (11, 24)
# 2024-11-24 00:22:00,752 - INFO - Marking path at: (12, 24)
# 2024-11-24 00:22:00,752 - INFO - Marking path at: (13, 24)
# 2024-11-24 00:22:00,753 - INFO - Marking path at: (13, 23)
# 2024-11-24 00:22:00,753 - INFO - Marking path at: (12, 23)
# 2024-11-24 00:22:00,754 - INFO - Marking path at: (11, 23)
# 2024-11-24 00:22:00,754 - INFO - Marking path at: (10, 23)
# 2024-11-24 00:22:00,755 - INFO - Marking path at: (9, 23)
# 2024-11-24 00:22:00,756 - INFO - Marking path at: (8, 23)
# 2024-11-24 00:22:00,756 - INFO - Marking path at: (7, 23)
# 2024-11-24 00:22:00,756 - INFO - Marking path at: (7, 22)
# 2024-11-24 00:22:00,757 - INFO - Marking path at: (8, 22)
# 2024-11-24 00:22:00,757 - INFO - Marking path at: (9, 22)
# 2024-11-24 00:22:00,758 - INFO - Marking path at: (10, 22)
# 2024-11-24 00:22:00,758 - INFO - Marking path at: (11, 22)
# 2024-11-24 00:22:00,758 - INFO - Marking path at: (12, 22)
# 2024-11-24 00:22:00,759 - INFO - Marking path at: (13, 22)
# 2024-11-24 00:22:00,759 - INFO - Marking path at: (13, 21)
# 2024-11-24 00:22:00,759 - INFO - Marking path at: (12, 21)
# 2024-11-24 00:22:00,760 - INFO - Marking path at: (11, 21)
# 2024-11-24 00:22:00,761 - INFO - Marking path at: (10, 21)
# 2024-11-24 00:22:00,761 - INFO - Marking path at: (9, 21)
# 2024-11-24 00:22:00,761 - INFO - Marking path at: (8, 21)
# 2024-11-24 00:22:00,762 - INFO - Marking path at: (7, 21)
# 2024-11-24 00:22:00,762 - INFO - Marking path at: (7, 20)
# 2024-11-24 00:22:00,763 - INFO - Marking path at: (8, 20)
# 2024-11-24 00:22:00,763 - INFO - Marking path at: (9, 20)
# 2024-11-24 00:22:00,763 - INFO - Marking path at: (10, 20)
# 2024-11-24 00:22:00,764 - INFO - Marking path at: (11, 20)
# 2024-11-24 00:22:00,764 - INFO - Marking path at: (12, 20)
# 2024-11-24 00:22:00,764 - INFO - Marking path at: (13, 20)
# 2024-11-24 00:22:00,765 - INFO - Marking path at: (13, 19)
# 2024-11-24 00:22:00,765 - INFO - Marking path at: (12, 19)
# 2024-11-24 00:22:00,765 - INFO - Marking path at: (11, 19)
# 2024-11-24 00:22:00,765 - INFO - Marking path at: (10, 19)
# 2024-11-24 00:22:00,767 - INFO - Marking path at: (9, 19)
# 2024-11-24 00:22:00,767 - INFO - Marking path at: (8, 19)
# 2024-11-24 00:22:00,767 - INFO - Marking path at: (7, 19)
# 2024-11-24 00:22:00,767 - INFO - Marking path at: (7, 18)
# 2024-11-24 00:22:00,767 - INFO - Marking path at: (8, 18)
# 2024-11-24 00:22:00,768 - INFO - Marking path at: (9, 18)
# 2024-11-24 00:22:00,768 - INFO - Marking path at: (10, 18)
# 2024-11-24 00:22:00,768 - INFO - Marking path at: (11, 18)
# 2024-11-24 00:22:00,769 - INFO - Marking path at: (12, 18)
# 2024-11-24 00:22:00,769 - INFO - Marking path at: (13, 18)
# 2024-11-24 00:22:00,769 - INFO - Marking path at: (13, 17)
# 2024-11-24 00:22:00,769 - INFO - Marking path at: (12, 17)
# 2024-11-24 00:22:00,770 - INFO - Marking path at: (11, 17)
# 2024-11-24 00:22:00,770 - INFO - Marking path at: (10, 17)
# 2024-11-24 00:22:00,770 - INFO - Marking path at: (9, 17)
# 2024-11-24 00:22:00,770 - INFO - Marking path at: (8, 17)
# 2024-11-24 00:22:00,771 - INFO - Marking path at: (7, 17)
# 2024-11-24 00:22:00,771 - INFO - Marking path at: (6, 17)
# 2024-11-24 00:22:00,771 - INFO - Marking path at: (5, 17)
# 2024-11-24 00:22:00,772 - INFO - Marking path at: (4, 17)
# 2024-11-24 00:22:00,772 - INFO - Marking path at: (4, 18)
# 2024-11-24 00:22:00,772 - INFO - Marking path at: (5, 18)
# 2024-11-24 00:22:00,773 - INFO - Marking path at: (5, 19)
# 2024-11-24 00:22:00,773 - INFO - Marking path at: (4, 19)
# 2024-11-24 00:22:00,774 - INFO - Marking path at: (4, 20)
# 2024-11-24 00:22:00,774 - INFO - Marking path at: (5, 20)
# 2024-11-24 00:22:00,775 - INFO - Marking path at: (5, 21)
# 2024-11-24 00:22:00,776 - INFO - Marking path at: (4, 21)
# 2024-11-24 00:22:00,776 - INFO - Marking path at: (3, 21)
# 2024-11-24 00:22:00,776 - INFO - Marking path at: (2, 21)
# 2024-11-24 00:22:00,777 - INFO - Marking path at: (1, 21)
# 2024-11-24 00:22:00,777 - INFO - Marking path at: (1, 20)
# 2024-11-24 00:22:00,778 - INFO - Marking path at: (2, 20)
# 2024-11-24 00:22:00,781 - INFO - Marking path at: (2, 19)
# 2024-11-24 00:22:00,783 - INFO - Marking path at: (1, 19)
# 2024-11-24 00:22:00,783 - INFO - Marking path at: (1, 18)
# 2024-11-24 00:22:00,783 - INFO - Marking path at: (2, 18)
# 2024-11-24 00:22:00,784 - INFO - Marking path at: (2, 17)
# 2024-11-24 00:22:00,784 - INFO - Marking path at: (1, 17)
# 2024-11-24 00:22:00,784 - INFO - Marking path at: (1, 16)
# 2024-11-24 00:22:00,785 - INFO - Marking path at: (2, 16)
# 2024-11-24 00:22:00,785 - INFO - Marking path at: (2, 15)
# 2024-11-24 00:22:00,786 - INFO - Marking path at: (1, 15)
# 2024-11-24 00:22:00,786 - INFO - Marking path at: (1, 14)
# 2024-11-24 00:22:00,787 - INFO - Marking path at: (2, 14)
# 2024-11-24 00:22:00,787 - INFO - Marking path at: (2, 13)
# 2024-11-24 00:22:00,787 - INFO - Marking path at: (1, 13)
# 2024-11-24 00:22:00,787 - INFO - Marking path at: (1, 12)
# 2024-11-24 00:22:00,788 - INFO - Marking path at: (2, 12)
# 2024-11-24 00:22:00,788 - INFO - Marking path at: (2, 11)
# 2024-11-24 00:22:00,788 - INFO - Marking path at: (1, 11)
# 2024-11-24 00:22:00,788 - INFO - Marking path at: (1, 10)
# 2024-11-24 00:22:00,789 - INFO - Marking path at: (2, 10)
# 2024-11-24 00:22:00,789 - INFO - Marking path at: (2, 9)
# 2024-11-24 00:22:00,789 - INFO - Marking path at: (1, 9)
# 2024-11-24 00:22:00,790 - INFO - Marking path at: (1, 8)
# 2024-11-24 00:22:00,791 - INFO - Marking path at: (2, 8)
# 2024-11-24 00:22:00,793 - INFO - Marking path at: (2, 7)
# 2024-11-24 00:22:00,793 - INFO - Marking path at: (1, 7)
# 2024-11-24 00:22:00,793 - INFO - Marking path at: (1, 6)
# 2024-11-24 00:22:00,793 - INFO - Marking path at: (2, 6)
# 2024-11-24 00:22:00,794 - INFO - Marking path at: (2, 5)
# 2024-11-24 00:22:00,794 - INFO - Marking path at: (1, 5)
# 2024-11-24 00:22:00,794 - INFO - Marking path at: (1, 4)
# 2024-11-24 00:22:00,795 - INFO - Marking path at: (2, 4)
# 2024-11-24 00:22:00,795 - INFO - Marking path at: (2, 3)
# 2024-11-24 00:22:00,796 - INFO - Maze with path:
# 2024-11-24 00:22:00,796 - INFO - ==========================================================================
# 2024-11-24 00:22:00,796 - INFO - |  S─│─│─│─│─│─│─│─│─│            |                             ─│─│─│─│ |
# 2024-11-24 00:22:00,797 - INFO - |  ─│─│─│─│─│─│─│─│─││            |                             ││││││││ |
# 2024-11-24 00:22:00,797 - INFO - |====================│            |                             ││││││││ |
# 2024-11-24 00:22:00,797 - INFO - |                │─│─│                                          ││││││││ |
# 2024-11-24 00:22:00,797 - INFO - |                ││─│─                                        * ││││││││ |
# 2024-11-24 00:22:00,797 - INFO - |                │ ===================                          ││││││││ |
# 2024-11-24 00:22:00,798 - INFO - |                │─│─│─│─│─│─│─│─│─│─│                          ││││││││ |
# 2024-11-24 00:22:00,798 - INFO - |                │││││││││││││││││││││                          ││││││││ |
# 2024-11-24 00:22:00,798 - INFO - |                │││││││││││││││││││││                          ││││││││ |
# 2024-11-24 00:22:00,798 - INFO - |                │││││││││││││││││││││==========================││││││││ |
# 2024-11-24 00:22:00,799 - INFO - |                │││││││││││││││││││││─│─│─│─│─│─│─│─│─│─│─│─│─│││││││││ |
# 2024-11-24 00:22:00,799 - INFO - |                ││││││││││││││││││││││││││││││─││││││││││││││││││││││││ |
# 2024-11-24 00:22:00,799 - INFO - |                ─│─│─│─│─│─│─│─│││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,799 - INFO - |================================││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,801 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,801 - INFO - |                     *          ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,801 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,801 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:22:00,804 - INFO - |                                ─│─│─│─│─│─│─│ |─│─│─│─│─│─│─│─│─│─│─│─*|
# 2024-11-24 00:22:00,804 - INFO - ==========================================================================
# 2024-11-24 00:22:00,804 - INFO - Saving the grid to file: output_maze_dfs.txt
# 2024-11-24 00:22:00,817 - INFO - Grid successfully saved to output_maze_dfs.txt
# 2024-11-24 00:22:00,818 - INFO - Result saved to output_maze_dfs.txt

# %%
import logging
from typing import List, Tuple

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


class Node:
    """Represents a node in the DFS search tree."""
    def __init__(self, x: int, y: int, parent: 'Node' = None):
        self.x = x
        self.y = y
        self.parent = parent


def parse_grid(file_path: str) -> Tuple[List[List[str]], Tuple[int, int], Tuple[int, int]]:
    """
    Parses a grid map from a text file into a 2D list and identifies the start ('S') and goal ('*') positions.
    """
    logging.info(f"Parsing the grid from file: {file_path}")
    grid = []
    start = None
    goal = None

    try:
        with open(file_path, 'r') as f:
            for line in f:
                grid.append(list(line.rstrip('\n')))  # Only remove newlines, not spaces
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
        raise ValueError(f"File not found: {file_path}")

    for i in range(len(grid)):          # Loop through rows
        for j in range(len(grid[i])):  # Loop through columns
            if grid[i][j].lower() == 's':  # Start position (case-insensitive)
                start = (i, j)
            elif grid[i][j] == '*':    # Goal position
                goal = (i, j)

    if start is None or goal is None:
        logging.error("The grid must contain both a start ('S') and a goal ('*').")
        raise ValueError("The grid must contain both a start ('S') and a goal ('*').")

    logging.info(f"Start position found at: {start}")
    logging.info(f"Goal position found at: {goal}")
    return grid, start, goal


def path_to_goal(node: Node, maze_map: List[List[str]]):
    """Backtracks from the goal node to the start node and assigns path characters."""
    logging.info("Backtracking to mark the path from goal to start.")
    while node.parent:  # Until we reach the start node
        prev_node = node.parent
        move_x = node.x - prev_node.x
        move_y = node.y - prev_node.y

        # Assign path characters based on the direction
        if move_x == 1 or move_x == -1:  # Vertical movement
            maze_map[prev_node.x][prev_node.y] = '│'
        elif move_y == 1 or move_y == -1:  # Horizontal movement
            maze_map[prev_node.x][prev_node.y] = '─'

        logging.info(f"Marking path at: ({node.x}, {node.y})")
        node = prev_node  # Move backward along the path

    maze_map[node.x][node.y] = 'S'  # Mark the start position explicitly


def depth_first_search(grid: List[List[str]], start: Tuple[int, int], goal: Tuple[int, int]) -> List[List[str]]:
    """
    Implements the Depth-First Search (DFS) algorithm to find a path
    from the start ('S') to the goal ('*') in a grid.

    Parameters
    ----------
    grid : List[List[str]]
        A 2D list representing the grid.
    start : Tuple[int, int]
        The (row, col) coordinates of the start position ('S').
    goal : Tuple[int, int]
        The (row, col) coordinates of the goal position ('*').

    Returns
    -------
    List[List[str]]
        The grid with the path marked from the start ('S') to the goal ('*').
    """
    logging.info("Starting Depth-First Search (DFS).")
    rows, cols = len(grid), len(grid[0])
    movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Possible moves: up, down, left, right
    visited = set()  # Set to keep track of visited cells

    def dfs_recursive(x: int, y: int, parent: Node) -> bool:
        """Recursive helper function for DFS."""
        if (x, y) in visited:
            return False  # Already visited

        visited.add((x, y))
        logging.info(f"Visiting node at: ({x}, {y})")

        # Check if the goal is reached
        if (x, y) == goal:
            logging.info(f"Goal reached at: ({x}, {y})")
            path_to_goal(Node(x=x, y=y, parent=parent), grid)
            return True

        # Explore neighbors
        for move_x, move_y in movements:
            new_x, new_y = x + move_x, y + move_y
            if (
                0 <= new_x < rows and 0 <= new_y < cols and
                grid[new_x][new_y] in (' ', '*') and
                (new_x, new_y) not in visited
            ):
                if dfs_recursive(new_x, new_y, Node(x=x, y=y, parent=parent)):
                    return True  # Path found

        return False  # No path found from this node

    # Start DFS from the starting position
    if not dfs_recursive(start[0], start[1], None):
        logging.error("No path found from start to goal.")
        raise ValueError("No path found from start to goal.")

    return grid


def save_grid_to_file(file_path: str, grid: List[List[str]]):
    """Saves the grid to a text file."""
    logging.info(f"Saving the grid to file: {file_path}")
    try:
        with open(file_path, 'w', encoding='utf-8') as f:  # Use UTF-8 encoding
            for row in grid:
                f.write(''.join(row) + '\n')
        logging.info(f"Grid successfully saved to {file_path}")
    except Exception as e:
        logging.error(f"Error saving grid to file: {e}")


def main():
    input_file = "map1.txt"  # Path to your maze file
    output_file = "output_dfs_shortest_path.txt"  # Path to save the output

    try:
        grid, start, goal = parse_grid(input_file)
        marked_grid = depth_first_search(grid, start, goal)

        logging.info("Maze with path:")
        for row in marked_grid:
            logging.info("".join(row))

        save_grid_to_file(output_file, marked_grid)
        logging.info(f"Result saved to {output_file}")

    except ValueError as e:
        logging.error(e)


if __name__ == "__main__":
    main()
# Out:
# 2024-11-24 00:33:47,193 - INFO - Parsing the grid from file: map1.txt
# 2024-11-24 00:33:47,207 - INFO - Start position found at: (1, 3)
# 2024-11-24 00:33:47,208 - INFO - Goal position found at: (19, 72)
# 2024-11-24 00:33:47,208 - INFO - Starting Depth-First Search (DFS).
# 2024-11-24 00:33:47,209 - INFO - Visiting node at: (1, 3)
# 2024-11-24 00:33:47,210 - INFO - Visiting node at: (2, 3)
# 2024-11-24 00:33:47,211 - INFO - Visiting node at: (2, 2)
# 2024-11-24 00:33:47,211 - INFO - Visiting node at: (1, 2)
# 2024-11-24 00:33:47,211 - INFO - Visiting node at: (1, 1)
# 2024-11-24 00:33:47,212 - INFO - Visiting node at: (2, 1)
# 2024-11-24 00:33:47,213 - INFO - Visiting node at: (2, 4)
# 2024-11-24 00:33:47,213 - INFO - Visiting node at: (1, 4)
# 2024-11-24 00:33:47,213 - INFO - Visiting node at: (1, 5)
# 2024-11-24 00:33:47,214 - INFO - Visiting node at: (2, 5)
# 2024-11-24 00:33:47,215 - INFO - Visiting node at: (2, 6)
# 2024-11-24 00:33:47,215 - INFO - Visiting node at: (1, 6)
# 2024-11-24 00:33:47,216 - INFO - Visiting node at: (1, 7)
# 2024-11-24 00:33:47,216 - INFO - Visiting node at: (2, 7)
# 2024-11-24 00:33:47,217 - INFO - Visiting node at: (2, 8)
# 2024-11-24 00:33:47,217 - INFO - Visiting node at: (1, 8)
# 2024-11-24 00:33:47,218 - INFO - Visiting node at: (1, 9)
# 2024-11-24 00:33:47,218 - INFO - Visiting node at: (2, 9)
# 2024-11-24 00:33:47,219 - INFO - Visiting node at: (2, 10)
# 2024-11-24 00:33:47,219 - INFO - Visiting node at: (1, 10)
# 2024-11-24 00:33:47,220 - INFO - Visiting node at: (1, 11)
# 2024-11-24 00:33:47,222 - INFO - Visiting node at: (2, 11)
# 2024-11-24 00:33:47,223 - INFO - Visiting node at: (2, 12)
# 2024-11-24 00:33:47,223 - INFO - Visiting node at: (1, 12)
# 2024-11-24 00:33:47,224 - INFO - Visiting node at: (1, 13)
# 2024-11-24 00:33:47,224 - INFO - Visiting node at: (2, 13)
# 2024-11-24 00:33:47,225 - INFO - Visiting node at: (2, 14)
# 2024-11-24 00:33:47,225 - INFO - Visiting node at: (1, 14)
# 2024-11-24 00:33:47,226 - INFO - Visiting node at: (1, 15)
# 2024-11-24 00:33:47,226 - INFO - Visiting node at: (2, 15)
# 2024-11-24 00:33:47,227 - INFO - Visiting node at: (2, 16)
# 2024-11-24 00:33:47,228 - INFO - Visiting node at: (1, 16)
# 2024-11-24 00:33:47,228 - INFO - Visiting node at: (1, 17)
# 2024-11-24 00:33:47,229 - INFO - Visiting node at: (2, 17)
# 2024-11-24 00:33:47,229 - INFO - Visiting node at: (2, 18)
# 2024-11-24 00:33:47,230 - INFO - Visiting node at: (1, 18)
# 2024-11-24 00:33:47,230 - INFO - Visiting node at: (1, 19)
# 2024-11-24 00:33:47,231 - INFO - Visiting node at: (2, 19)
# 2024-11-24 00:33:47,231 - INFO - Visiting node at: (2, 20)
# 2024-11-24 00:33:47,232 - INFO - Visiting node at: (1, 20)
# 2024-11-24 00:33:47,232 - INFO - Visiting node at: (1, 21)
# 2024-11-24 00:33:47,233 - INFO - Visiting node at: (2, 21)
# 2024-11-24 00:33:47,233 - INFO - Visiting node at: (3, 21)
# 2024-11-24 00:33:47,234 - INFO - Visiting node at: (4, 21)
# 2024-11-24 00:33:47,234 - INFO - Visiting node at: (5, 21)
# 2024-11-24 00:33:47,235 - INFO - Visiting node at: (5, 20)
# 2024-11-24 00:33:47,236 - INFO - Visiting node at: (4, 20)
# 2024-11-24 00:33:47,236 - INFO - Visiting node at: (4, 19)
# 2024-11-24 00:33:47,237 - INFO - Visiting node at: (5, 19)
# 2024-11-24 00:33:47,237 - INFO - Visiting node at: (5, 18)
# 2024-11-24 00:33:47,238 - INFO - Visiting node at: (4, 18)
# 2024-11-24 00:33:47,238 - INFO - Visiting node at: (4, 17)
# 2024-11-24 00:33:47,239 - INFO - Visiting node at: (5, 17)
# 2024-11-24 00:33:47,239 - INFO - Visiting node at: (6, 17)
# 2024-11-24 00:33:47,240 - INFO - Visiting node at: (7, 17)
# 2024-11-24 00:33:47,240 - INFO - Visiting node at: (8, 17)
# 2024-11-24 00:33:47,241 - INFO - Visiting node at: (9, 17)
# 2024-11-24 00:33:47,241 - INFO - Visiting node at: (10, 17)
# 2024-11-24 00:33:47,242 - INFO - Visiting node at: (11, 17)
# 2024-11-24 00:33:47,242 - INFO - Visiting node at: (12, 17)
# 2024-11-24 00:33:47,243 - INFO - Visiting node at: (13, 17)
# 2024-11-24 00:33:47,243 - INFO - Visiting node at: (13, 16)
# 2024-11-24 00:33:47,243 - INFO - Visiting node at: (12, 16)
# 2024-11-24 00:33:47,244 - INFO - Visiting node at: (11, 16)
# 2024-11-24 00:33:47,244 - INFO - Visiting node at: (10, 16)
# 2024-11-24 00:33:47,245 - INFO - Visiting node at: (9, 16)
# 2024-11-24 00:33:47,245 - INFO - Visiting node at: (8, 16)
# 2024-11-24 00:33:47,246 - INFO - Visiting node at: (7, 16)
# 2024-11-24 00:33:47,246 - INFO - Visiting node at: (6, 16)
# 2024-11-24 00:33:47,246 - INFO - Visiting node at: (5, 16)
# 2024-11-24 00:33:47,247 - INFO - Visiting node at: (4, 16)
# 2024-11-24 00:33:47,247 - INFO - Visiting node at: (4, 15)
# 2024-11-24 00:33:47,248 - INFO - Visiting node at: (5, 15)
# 2024-11-24 00:33:47,248 - INFO - Visiting node at: (6, 15)
# 2024-11-24 00:33:47,248 - INFO - Visiting node at: (7, 15)
# 2024-11-24 00:33:47,249 - INFO - Visiting node at: (8, 15)
# 2024-11-24 00:33:47,249 - INFO - Visiting node at: (9, 15)
# 2024-11-24 00:33:47,249 - INFO - Visiting node at: (10, 15)
# 2024-11-24 00:33:47,249 - INFO - Visiting node at: (11, 15)
# 2024-11-24 00:33:47,250 - INFO - Visiting node at: (12, 15)
# 2024-11-24 00:33:47,250 - INFO - Visiting node at: (13, 15)
# 2024-11-24 00:33:47,250 - INFO - Visiting node at: (13, 14)
# 2024-11-24 00:33:47,251 - INFO - Visiting node at: (12, 14)
# 2024-11-24 00:33:47,251 - INFO - Visiting node at: (11, 14)
# 2024-11-24 00:33:47,253 - INFO - Visiting node at: (10, 14)
# 2024-11-24 00:33:47,254 - INFO - Visiting node at: (9, 14)
# 2024-11-24 00:33:47,254 - INFO - Visiting node at: (8, 14)
# 2024-11-24 00:33:47,254 - INFO - Visiting node at: (7, 14)
# 2024-11-24 00:33:47,255 - INFO - Visiting node at: (6, 14)
# 2024-11-24 00:33:47,255 - INFO - Visiting node at: (5, 14)
# 2024-11-24 00:33:47,255 - INFO - Visiting node at: (4, 14)
# 2024-11-24 00:33:47,256 - INFO - Visiting node at: (4, 13)
# 2024-11-24 00:33:47,256 - INFO - Visiting node at: (5, 13)
# 2024-11-24 00:33:47,256 - INFO - Visiting node at: (6, 13)
# 2024-11-24 00:33:47,257 - INFO - Visiting node at: (7, 13)
# 2024-11-24 00:33:47,257 - INFO - Visiting node at: (8, 13)
# 2024-11-24 00:33:47,258 - INFO - Visiting node at: (9, 13)
# 2024-11-24 00:33:47,258 - INFO - Visiting node at: (10, 13)
# 2024-11-24 00:33:47,258 - INFO - Visiting node at: (11, 13)
# 2024-11-24 00:33:47,259 - INFO - Visiting node at: (12, 13)
# 2024-11-24 00:33:47,259 - INFO - Visiting node at: (13, 13)
# 2024-11-24 00:33:47,259 - INFO - Visiting node at: (13, 12)
# 2024-11-24 00:33:47,259 - INFO - Visiting node at: (12, 12)
# 2024-11-24 00:33:47,260 - INFO - Visiting node at: (11, 12)
# 2024-11-24 00:33:47,260 - INFO - Visiting node at: (10, 12)
# 2024-11-24 00:33:47,261 - INFO - Visiting node at: (9, 12)
# 2024-11-24 00:33:47,261 - INFO - Visiting node at: (8, 12)
# 2024-11-24 00:33:47,261 - INFO - Visiting node at: (7, 12)
# 2024-11-24 00:33:47,262 - INFO - Visiting node at: (6, 12)
# 2024-11-24 00:33:47,262 - INFO - Visiting node at: (5, 12)
# 2024-11-24 00:33:47,262 - INFO - Visiting node at: (4, 12)
# 2024-11-24 00:33:47,263 - INFO - Visiting node at: (4, 11)
# 2024-11-24 00:33:47,263 - INFO - Visiting node at: (5, 11)
# 2024-11-24 00:33:47,263 - INFO - Visiting node at: (6, 11)
# 2024-11-24 00:33:47,263 - INFO - Visiting node at: (7, 11)
# 2024-11-24 00:33:47,264 - INFO - Visiting node at: (8, 11)
# 2024-11-24 00:33:47,264 - INFO - Visiting node at: (9, 11)
# 2024-11-24 00:33:47,264 - INFO - Visiting node at: (10, 11)
# 2024-11-24 00:33:47,267 - INFO - Visiting node at: (11, 11)
# 2024-11-24 00:33:47,268 - INFO - Visiting node at: (12, 11)
# 2024-11-24 00:33:47,268 - INFO - Visiting node at: (13, 11)
# 2024-11-24 00:33:47,268 - INFO - Visiting node at: (13, 10)
# 2024-11-24 00:33:47,269 - INFO - Visiting node at: (12, 10)
# 2024-11-24 00:33:47,269 - INFO - Visiting node at: (11, 10)
# 2024-11-24 00:33:47,269 - INFO - Visiting node at: (10, 10)
# 2024-11-24 00:33:47,270 - INFO - Visiting node at: (9, 10)
# 2024-11-24 00:33:47,270 - INFO - Visiting node at: (8, 10)
# 2024-11-24 00:33:47,271 - INFO - Visiting node at: (7, 10)
# 2024-11-24 00:33:47,271 - INFO - Visiting node at: (6, 10)
# 2024-11-24 00:33:47,271 - INFO - Visiting node at: (5, 10)
# 2024-11-24 00:33:47,271 - INFO - Visiting node at: (4, 10)
# 2024-11-24 00:33:47,272 - INFO - Visiting node at: (4, 9)
# 2024-11-24 00:33:47,272 - INFO - Visiting node at: (5, 9)
# 2024-11-24 00:33:47,272 - INFO - Visiting node at: (6, 9)
# 2024-11-24 00:33:47,273 - INFO - Visiting node at: (7, 9)
# 2024-11-24 00:33:47,273 - INFO - Visiting node at: (8, 9)
# 2024-11-24 00:33:47,273 - INFO - Visiting node at: (9, 9)
# 2024-11-24 00:33:47,273 - INFO - Visiting node at: (10, 9)
# 2024-11-24 00:33:47,274 - INFO - Visiting node at: (11, 9)
# 2024-11-24 00:33:47,274 - INFO - Visiting node at: (12, 9)
# 2024-11-24 00:33:47,274 - INFO - Visiting node at: (13, 9)
# 2024-11-24 00:33:47,274 - INFO - Visiting node at: (13, 8)
# 2024-11-24 00:33:47,275 - INFO - Visiting node at: (12, 8)
# 2024-11-24 00:33:47,275 - INFO - Visiting node at: (11, 8)
# 2024-11-24 00:33:47,275 - INFO - Visiting node at: (10, 8)
# 2024-11-24 00:33:47,276 - INFO - Visiting node at: (9, 8)
# 2024-11-24 00:33:47,276 - INFO - Visiting node at: (8, 8)
# 2024-11-24 00:33:47,276 - INFO - Visiting node at: (7, 8)
# 2024-11-24 00:33:47,276 - INFO - Visiting node at: (6, 8)
# 2024-11-24 00:33:47,277 - INFO - Visiting node at: (5, 8)
# 2024-11-24 00:33:47,277 - INFO - Visiting node at: (4, 8)
# 2024-11-24 00:33:47,278 - INFO - Visiting node at: (4, 7)
# 2024-11-24 00:33:47,278 - INFO - Visiting node at: (5, 7)
# 2024-11-24 00:33:47,278 - INFO - Visiting node at: (6, 7)
# 2024-11-24 00:33:47,279 - INFO - Visiting node at: (7, 7)
# 2024-11-24 00:33:47,279 - INFO - Visiting node at: (8, 7)
# 2024-11-24 00:33:47,279 - INFO - Visiting node at: (9, 7)
# 2024-11-24 00:33:47,279 - INFO - Visiting node at: (10, 7)
# 2024-11-24 00:33:47,280 - INFO - Visiting node at: (11, 7)
# 2024-11-24 00:33:47,280 - INFO - Visiting node at: (12, 7)
# 2024-11-24 00:33:47,280 - INFO - Visiting node at: (13, 7)
# 2024-11-24 00:33:47,281 - INFO - Visiting node at: (13, 6)
# 2024-11-24 00:33:47,281 - INFO - Visiting node at: (12, 6)
# 2024-11-24 00:33:47,281 - INFO - Visiting node at: (11, 6)
# 2024-11-24 00:33:47,282 - INFO - Visiting node at: (10, 6)
# 2024-11-24 00:33:47,282 - INFO - Visiting node at: (9, 6)
# 2024-11-24 00:33:47,282 - INFO - Visiting node at: (8, 6)
# 2024-11-24 00:33:47,282 - INFO - Visiting node at: (7, 6)
# 2024-11-24 00:33:47,283 - INFO - Visiting node at: (6, 6)
# 2024-11-24 00:33:47,283 - INFO - Visiting node at: (5, 6)
# 2024-11-24 00:33:47,284 - INFO - Visiting node at: (4, 6)
# 2024-11-24 00:33:47,284 - INFO - Visiting node at: (4, 5)
# 2024-11-24 00:33:47,284 - INFO - Visiting node at: (5, 5)
# 2024-11-24 00:33:47,285 - INFO - Visiting node at: (6, 5)
# 2024-11-24 00:33:47,286 - INFO - Visiting node at: (7, 5)
# 2024-11-24 00:33:47,286 - INFO - Visiting node at: (8, 5)
# 2024-11-24 00:33:47,289 - INFO - Visiting node at: (9, 5)
# 2024-11-24 00:33:47,292 - INFO - Visiting node at: (10, 5)
# 2024-11-24 00:33:47,292 - INFO - Visiting node at: (11, 5)
# 2024-11-24 00:33:47,293 - INFO - Visiting node at: (12, 5)
# 2024-11-24 00:33:47,293 - INFO - Visiting node at: (13, 5)
# 2024-11-24 00:33:47,294 - INFO - Visiting node at: (13, 4)
# 2024-11-24 00:33:47,294 - INFO - Visiting node at: (12, 4)
# 2024-11-24 00:33:47,294 - INFO - Visiting node at: (11, 4)
# 2024-11-24 00:33:47,295 - INFO - Visiting node at: (10, 4)
# 2024-11-24 00:33:47,295 - INFO - Visiting node at: (9, 4)
# 2024-11-24 00:33:47,296 - INFO - Visiting node at: (8, 4)
# 2024-11-24 00:33:47,297 - INFO - Visiting node at: (7, 4)
# 2024-11-24 00:33:47,297 - INFO - Visiting node at: (6, 4)
# 2024-11-24 00:33:47,297 - INFO - Visiting node at: (5, 4)
# 2024-11-24 00:33:47,298 - INFO - Visiting node at: (4, 4)
# 2024-11-24 00:33:47,298 - INFO - Visiting node at: (4, 3)
# 2024-11-24 00:33:47,299 - INFO - Visiting node at: (5, 3)
# 2024-11-24 00:33:47,299 - INFO - Visiting node at: (6, 3)
# 2024-11-24 00:33:47,301 - INFO - Visiting node at: (7, 3)
# 2024-11-24 00:33:47,301 - INFO - Visiting node at: (8, 3)
# 2024-11-24 00:33:47,302 - INFO - Visiting node at: (9, 3)
# 2024-11-24 00:33:47,303 - INFO - Visiting node at: (10, 3)
# 2024-11-24 00:33:47,303 - INFO - Visiting node at: (11, 3)
# 2024-11-24 00:33:47,304 - INFO - Visiting node at: (12, 3)
# 2024-11-24 00:33:47,304 - INFO - Visiting node at: (13, 3)
# 2024-11-24 00:33:47,304 - INFO - Visiting node at: (13, 2)
# 2024-11-24 00:33:47,305 - INFO - Visiting node at: (12, 2)
# 2024-11-24 00:33:47,305 - INFO - Visiting node at: (11, 2)
# 2024-11-24 00:33:47,305 - INFO - Visiting node at: (10, 2)
# 2024-11-24 00:33:47,305 - INFO - Visiting node at: (9, 2)
# 2024-11-24 00:33:47,306 - INFO - Visiting node at: (8, 2)
# 2024-11-24 00:33:47,306 - INFO - Visiting node at: (7, 2)
# 2024-11-24 00:33:47,307 - INFO - Visiting node at: (6, 2)
# 2024-11-24 00:33:47,307 - INFO - Visiting node at: (5, 2)
# 2024-11-24 00:33:47,308 - INFO - Visiting node at: (4, 2)
# 2024-11-24 00:33:47,308 - INFO - Visiting node at: (4, 1)
# 2024-11-24 00:33:47,308 - INFO - Visiting node at: (5, 1)
# 2024-11-24 00:33:47,309 - INFO - Visiting node at: (6, 1)
# 2024-11-24 00:33:47,310 - INFO - Visiting node at: (7, 1)
# 2024-11-24 00:33:47,310 - INFO - Visiting node at: (8, 1)
# 2024-11-24 00:33:47,311 - INFO - Visiting node at: (9, 1)
# 2024-11-24 00:33:47,311 - INFO - Visiting node at: (10, 1)
# 2024-11-24 00:33:47,311 - INFO - Visiting node at: (11, 1)
# 2024-11-24 00:33:47,313 - INFO - Visiting node at: (12, 1)
# 2024-11-24 00:33:47,313 - INFO - Visiting node at: (13, 1)
# 2024-11-24 00:33:47,314 - INFO - Visiting node at: (13, 18)
# 2024-11-24 00:33:47,314 - INFO - Visiting node at: (12, 18)
# 2024-11-24 00:33:47,314 - INFO - Visiting node at: (11, 18)
# 2024-11-24 00:33:47,314 - INFO - Visiting node at: (10, 18)
# 2024-11-24 00:33:47,315 - INFO - Visiting node at: (9, 18)
# 2024-11-24 00:33:47,315 - INFO - Visiting node at: (8, 18)
# 2024-11-24 00:33:47,315 - INFO - Visiting node at: (7, 18)
# 2024-11-24 00:33:47,315 - INFO - Visiting node at: (6, 18)
# 2024-11-24 00:33:47,316 - INFO - Visiting node at: (7, 19)
# 2024-11-24 00:33:47,316 - INFO - Visiting node at: (8, 19)
# 2024-11-24 00:33:47,317 - INFO - Visiting node at: (9, 19)
# 2024-11-24 00:33:47,317 - INFO - Visiting node at: (10, 19)
# 2024-11-24 00:33:47,317 - INFO - Visiting node at: (11, 19)
# 2024-11-24 00:33:47,317 - INFO - Visiting node at: (12, 19)
# 2024-11-24 00:33:47,318 - INFO - Visiting node at: (13, 19)
# 2024-11-24 00:33:47,318 - INFO - Visiting node at: (13, 20)
# 2024-11-24 00:33:47,318 - INFO - Visiting node at: (12, 20)
# 2024-11-24 00:33:47,318 - INFO - Visiting node at: (11, 20)
# 2024-11-24 00:33:47,319 - INFO - Visiting node at: (10, 20)
# 2024-11-24 00:33:47,319 - INFO - Visiting node at: (9, 20)
# 2024-11-24 00:33:47,319 - INFO - Visiting node at: (8, 20)
# 2024-11-24 00:33:47,320 - INFO - Visiting node at: (7, 20)
# 2024-11-24 00:33:47,320 - INFO - Visiting node at: (7, 21)
# 2024-11-24 00:33:47,321 - INFO - Visiting node at: (8, 21)
# 2024-11-24 00:33:47,321 - INFO - Visiting node at: (9, 21)
# 2024-11-24 00:33:47,322 - INFO - Visiting node at: (10, 21)
# 2024-11-24 00:33:47,323 - INFO - Visiting node at: (11, 21)
# 2024-11-24 00:33:47,323 - INFO - Visiting node at: (12, 21)
# 2024-11-24 00:33:47,324 - INFO - Visiting node at: (13, 21)
# 2024-11-24 00:33:47,325 - INFO - Visiting node at: (13, 22)
# 2024-11-24 00:33:47,325 - INFO - Visiting node at: (12, 22)
# 2024-11-24 00:33:47,325 - INFO - Visiting node at: (11, 22)
# 2024-11-24 00:33:47,326 - INFO - Visiting node at: (10, 22)
# 2024-11-24 00:33:47,326 - INFO - Visiting node at: (9, 22)
# 2024-11-24 00:33:47,326 - INFO - Visiting node at: (8, 22)
# 2024-11-24 00:33:47,326 - INFO - Visiting node at: (7, 22)
# 2024-11-24 00:33:47,327 - INFO - Visiting node at: (7, 23)
# 2024-11-24 00:33:47,327 - INFO - Visiting node at: (8, 23)
# 2024-11-24 00:33:47,327 - INFO - Visiting node at: (9, 23)
# 2024-11-24 00:33:47,327 - INFO - Visiting node at: (10, 23)
# 2024-11-24 00:33:47,327 - INFO - Visiting node at: (11, 23)
# 2024-11-24 00:33:47,328 - INFO - Visiting node at: (12, 23)
# 2024-11-24 00:33:47,329 - INFO - Visiting node at: (13, 23)
# 2024-11-24 00:33:47,329 - INFO - Visiting node at: (13, 24)
# 2024-11-24 00:33:47,329 - INFO - Visiting node at: (12, 24)
# 2024-11-24 00:33:47,330 - INFO - Visiting node at: (11, 24)
# 2024-11-24 00:33:47,330 - INFO - Visiting node at: (10, 24)
# 2024-11-24 00:33:47,330 - INFO - Visiting node at: (9, 24)
# 2024-11-24 00:33:47,330 - INFO - Visiting node at: (8, 24)
# 2024-11-24 00:33:47,331 - INFO - Visiting node at: (7, 24)
# 2024-11-24 00:33:47,331 - INFO - Visiting node at: (7, 25)
# 2024-11-24 00:33:47,331 - INFO - Visiting node at: (8, 25)
# 2024-11-24 00:33:47,331 - INFO - Visiting node at: (9, 25)
# 2024-11-24 00:33:47,332 - INFO - Visiting node at: (10, 25)
# 2024-11-24 00:33:47,332 - INFO - Visiting node at: (11, 25)
# 2024-11-24 00:33:47,333 - INFO - Visiting node at: (12, 25)
# 2024-11-24 00:33:47,333 - INFO - Visiting node at: (13, 25)
# 2024-11-24 00:33:47,333 - INFO - Visiting node at: (13, 26)
# 2024-11-24 00:33:47,334 - INFO - Visiting node at: (12, 26)
# 2024-11-24 00:33:47,334 - INFO - Visiting node at: (11, 26)
# 2024-11-24 00:33:47,334 - INFO - Visiting node at: (10, 26)
# 2024-11-24 00:33:47,334 - INFO - Visiting node at: (9, 26)
# 2024-11-24 00:33:47,335 - INFO - Visiting node at: (8, 26)
# 2024-11-24 00:33:47,335 - INFO - Visiting node at: (7, 26)
# 2024-11-24 00:33:47,335 - INFO - Visiting node at: (7, 27)
# 2024-11-24 00:33:47,335 - INFO - Visiting node at: (8, 27)
# 2024-11-24 00:33:47,335 - INFO - Visiting node at: (9, 27)
# 2024-11-24 00:33:47,336 - INFO - Visiting node at: (10, 27)
# 2024-11-24 00:33:47,336 - INFO - Visiting node at: (11, 27)
# 2024-11-24 00:33:47,336 - INFO - Visiting node at: (12, 27)
# 2024-11-24 00:33:47,336 - INFO - Visiting node at: (13, 27)
# 2024-11-24 00:33:47,337 - INFO - Visiting node at: (13, 28)
# 2024-11-24 00:33:47,337 - INFO - Visiting node at: (12, 28)
# 2024-11-24 00:33:47,337 - INFO - Visiting node at: (11, 28)
# 2024-11-24 00:33:47,337 - INFO - Visiting node at: (10, 28)
# 2024-11-24 00:33:47,338 - INFO - Visiting node at: (9, 28)
# 2024-11-24 00:33:47,338 - INFO - Visiting node at: (8, 28)
# 2024-11-24 00:33:47,338 - INFO - Visiting node at: (7, 28)
# 2024-11-24 00:33:47,339 - INFO - Visiting node at: (7, 29)
# 2024-11-24 00:33:47,339 - INFO - Visiting node at: (8, 29)
# 2024-11-24 00:33:47,340 - INFO - Visiting node at: (9, 29)
# 2024-11-24 00:33:47,340 - INFO - Visiting node at: (10, 29)
# 2024-11-24 00:33:47,341 - INFO - Visiting node at: (11, 29)
# 2024-11-24 00:33:47,341 - INFO - Visiting node at: (12, 29)
# 2024-11-24 00:33:47,342 - INFO - Visiting node at: (13, 29)
# 2024-11-24 00:33:47,342 - INFO - Visiting node at: (13, 30)
# 2024-11-24 00:33:47,343 - INFO - Visiting node at: (12, 30)
# 2024-11-24 00:33:47,343 - INFO - Visiting node at: (11, 30)
# 2024-11-24 00:33:47,343 - INFO - Visiting node at: (10, 30)
# 2024-11-24 00:33:47,344 - INFO - Visiting node at: (9, 30)
# 2024-11-24 00:33:47,344 - INFO - Visiting node at: (8, 30)
# 2024-11-24 00:33:47,345 - INFO - Visiting node at: (7, 30)
# 2024-11-24 00:33:47,345 - INFO - Visiting node at: (7, 31)
# 2024-11-24 00:33:47,345 - INFO - Visiting node at: (8, 31)
# 2024-11-24 00:33:47,346 - INFO - Visiting node at: (9, 31)
# 2024-11-24 00:33:47,346 - INFO - Visiting node at: (10, 31)
# 2024-11-24 00:33:47,346 - INFO - Visiting node at: (11, 31)
# 2024-11-24 00:33:47,347 - INFO - Visiting node at: (12, 31)
# 2024-11-24 00:33:47,348 - INFO - Visiting node at: (13, 31)
# 2024-11-24 00:33:47,348 - INFO - Visiting node at: (13, 32)
# 2024-11-24 00:33:47,349 - INFO - Visiting node at: (12, 32)
# 2024-11-24 00:33:47,349 - INFO - Visiting node at: (11, 32)
# 2024-11-24 00:33:47,349 - INFO - Visiting node at: (10, 32)
# 2024-11-24 00:33:47,349 - INFO - Visiting node at: (9, 32)
# 2024-11-24 00:33:47,350 - INFO - Visiting node at: (8, 32)
# 2024-11-24 00:33:47,350 - INFO - Visiting node at: (7, 32)
# 2024-11-24 00:33:47,350 - INFO - Visiting node at: (7, 33)
# 2024-11-24 00:33:47,350 - INFO - Visiting node at: (8, 33)
# 2024-11-24 00:33:47,351 - INFO - Visiting node at: (9, 33)
# 2024-11-24 00:33:47,351 - INFO - Visiting node at: (10, 33)
# 2024-11-24 00:33:47,351 - INFO - Visiting node at: (11, 33)
# 2024-11-24 00:33:47,352 - INFO - Visiting node at: (12, 33)
# 2024-11-24 00:33:47,352 - INFO - Visiting node at: (13, 33)
# 2024-11-24 00:33:47,352 - INFO - Visiting node at: (14, 33)
# 2024-11-24 00:33:47,353 - INFO - Visiting node at: (15, 33)
# 2024-11-24 00:33:47,353 - INFO - Visiting node at: (16, 33)
# 2024-11-24 00:33:47,354 - INFO - Visiting node at: (17, 33)
# 2024-11-24 00:33:47,354 - INFO - Visiting node at: (18, 33)
# 2024-11-24 00:33:47,354 - INFO - Visiting node at: (19, 33)
# 2024-11-24 00:33:47,355 - INFO - Visiting node at: (19, 32)
# 2024-11-24 00:33:47,355 - INFO - Visiting node at: (18, 32)
# 2024-11-24 00:33:47,355 - INFO - Visiting node at: (17, 32)
# 2024-11-24 00:33:47,355 - INFO - Visiting node at: (16, 32)
# 2024-11-24 00:33:47,356 - INFO - Visiting node at: (15, 32)
# 2024-11-24 00:33:47,356 - INFO - Visiting node at: (15, 31)
# 2024-11-24 00:33:47,356 - INFO - Visiting node at: (16, 31)
# 2024-11-24 00:33:47,357 - INFO - Visiting node at: (17, 31)
# 2024-11-24 00:33:47,357 - INFO - Visiting node at: (18, 31)
# 2024-11-24 00:33:47,358 - INFO - Visiting node at: (19, 31)
# 2024-11-24 00:33:47,358 - INFO - Visiting node at: (19, 30)
# 2024-11-24 00:33:47,359 - INFO - Visiting node at: (18, 30)
# 2024-11-24 00:33:47,359 - INFO - Visiting node at: (17, 30)
# 2024-11-24 00:33:47,359 - INFO - Visiting node at: (16, 30)
# 2024-11-24 00:33:47,360 - INFO - Visiting node at: (15, 30)
# 2024-11-24 00:33:47,360 - INFO - Visiting node at: (15, 29)
# 2024-11-24 00:33:47,360 - INFO - Visiting node at: (16, 29)
# 2024-11-24 00:33:47,361 - INFO - Visiting node at: (17, 29)
# 2024-11-24 00:33:47,361 - INFO - Visiting node at: (18, 29)
# 2024-11-24 00:33:47,361 - INFO - Visiting node at: (19, 29)
# 2024-11-24 00:33:47,362 - INFO - Visiting node at: (19, 28)
# 2024-11-24 00:33:47,362 - INFO - Visiting node at: (18, 28)
# 2024-11-24 00:33:47,362 - INFO - Visiting node at: (17, 28)
# 2024-11-24 00:33:47,362 - INFO - Visiting node at: (16, 28)
# 2024-11-24 00:33:47,362 - INFO - Visiting node at: (15, 28)
# 2024-11-24 00:33:47,363 - INFO - Visiting node at: (15, 27)
# 2024-11-24 00:33:47,363 - INFO - Visiting node at: (16, 27)
# 2024-11-24 00:33:47,364 - INFO - Visiting node at: (17, 27)
# 2024-11-24 00:33:47,364 - INFO - Visiting node at: (18, 27)
# 2024-11-24 00:33:47,364 - INFO - Visiting node at: (19, 27)
# 2024-11-24 00:33:47,365 - INFO - Visiting node at: (19, 26)
# 2024-11-24 00:33:47,365 - INFO - Visiting node at: (18, 26)
# 2024-11-24 00:33:47,365 - INFO - Visiting node at: (17, 26)
# 2024-11-24 00:33:47,366 - INFO - Visiting node at: (16, 26)
# 2024-11-24 00:33:47,366 - INFO - Visiting node at: (15, 26)
# 2024-11-24 00:33:47,366 - INFO - Visiting node at: (15, 25)
# 2024-11-24 00:33:47,366 - INFO - Visiting node at: (16, 25)
# 2024-11-24 00:33:47,366 - INFO - Visiting node at: (17, 25)
# 2024-11-24 00:33:47,367 - INFO - Visiting node at: (18, 25)
# 2024-11-24 00:33:47,367 - INFO - Visiting node at: (19, 25)
# 2024-11-24 00:33:47,367 - INFO - Visiting node at: (19, 24)
# 2024-11-24 00:33:47,368 - INFO - Visiting node at: (18, 24)
# 2024-11-24 00:33:47,368 - INFO - Visiting node at: (17, 24)
# 2024-11-24 00:33:47,368 - INFO - Visiting node at: (16, 24)
# 2024-11-24 00:33:47,368 - INFO - Visiting node at: (15, 24)
# 2024-11-24 00:33:47,369 - INFO - Visiting node at: (15, 23)
# 2024-11-24 00:33:47,370 - INFO - Visiting node at: (16, 23)
# 2024-11-24 00:33:47,370 - INFO - Visiting node at: (17, 23)
# 2024-11-24 00:33:47,370 - INFO - Visiting node at: (18, 23)
# 2024-11-24 00:33:47,370 - INFO - Visiting node at: (19, 23)
# 2024-11-24 00:33:47,370 - INFO - Visiting node at: (19, 22)
# 2024-11-24 00:33:47,371 - INFO - Visiting node at: (18, 22)
# 2024-11-24 00:33:47,371 - INFO - Visiting node at: (17, 22)
# 2024-11-24 00:33:47,371 - INFO - Visiting node at: (16, 22)
# 2024-11-24 00:33:47,371 - INFO - Visiting node at: (15, 22)
# 2024-11-24 00:33:47,372 - INFO - Visiting node at: (15, 21)
# 2024-11-24 00:33:47,372 - INFO - Visiting node at: (16, 21)
# 2024-11-24 00:33:47,372 - INFO - Visiting node at: (17, 21)
# 2024-11-24 00:33:47,372 - INFO - Visiting node at: (18, 21)
# 2024-11-24 00:33:47,373 - INFO - Visiting node at: (19, 21)
# 2024-11-24 00:33:47,373 - INFO - Visiting node at: (19, 20)
# 2024-11-24 00:33:47,373 - INFO - Visiting node at: (18, 20)
# 2024-11-24 00:33:47,373 - INFO - Visiting node at: (17, 20)
# 2024-11-24 00:33:47,374 - INFO - Visiting node at: (16, 20)
# 2024-11-24 00:33:47,374 - INFO - Visiting node at: (15, 20)
# 2024-11-24 00:33:47,375 - INFO - Visiting node at: (15, 19)
# 2024-11-24 00:33:47,375 - INFO - Visiting node at: (16, 19)
# 2024-11-24 00:33:47,375 - INFO - Visiting node at: (17, 19)
# 2024-11-24 00:33:47,376 - INFO - Visiting node at: (18, 19)
# 2024-11-24 00:33:47,377 - INFO - Visiting node at: (19, 19)
# 2024-11-24 00:33:47,377 - INFO - Visiting node at: (19, 18)
# 2024-11-24 00:33:47,377 - INFO - Visiting node at: (18, 18)
# 2024-11-24 00:33:47,377 - INFO - Visiting node at: (17, 18)
# 2024-11-24 00:33:47,378 - INFO - Visiting node at: (16, 18)
# 2024-11-24 00:33:47,378 - INFO - Visiting node at: (15, 18)
# 2024-11-24 00:33:47,378 - INFO - Visiting node at: (15, 17)
# 2024-11-24 00:33:47,379 - INFO - Visiting node at: (16, 17)
# 2024-11-24 00:33:47,379 - INFO - Visiting node at: (17, 17)
# 2024-11-24 00:33:47,379 - INFO - Visiting node at: (18, 17)
# 2024-11-24 00:33:47,379 - INFO - Visiting node at: (19, 17)
# 2024-11-24 00:33:47,379 - INFO - Visiting node at: (19, 16)
# 2024-11-24 00:33:47,380 - INFO - Visiting node at: (18, 16)
# 2024-11-24 00:33:47,380 - INFO - Visiting node at: (17, 16)
# 2024-11-24 00:33:47,380 - INFO - Visiting node at: (16, 16)
# 2024-11-24 00:33:47,381 - INFO - Visiting node at: (15, 16)
# 2024-11-24 00:33:47,381 - INFO - Visiting node at: (15, 15)
# 2024-11-24 00:33:47,381 - INFO - Visiting node at: (16, 15)
# 2024-11-24 00:33:47,381 - INFO - Visiting node at: (17, 15)
# 2024-11-24 00:33:47,382 - INFO - Visiting node at: (18, 15)
# 2024-11-24 00:33:47,382 - INFO - Visiting node at: (19, 15)
# 2024-11-24 00:33:47,382 - INFO - Visiting node at: (19, 14)
# 2024-11-24 00:33:47,382 - INFO - Visiting node at: (18, 14)
# 2024-11-24 00:33:47,383 - INFO - Visiting node at: (17, 14)
# 2024-11-24 00:33:47,383 - INFO - Visiting node at: (16, 14)
# 2024-11-24 00:33:47,383 - INFO - Visiting node at: (15, 14)
# 2024-11-24 00:33:47,384 - INFO - Visiting node at: (15, 13)
# 2024-11-24 00:33:47,385 - INFO - Visiting node at: (16, 13)
# 2024-11-24 00:33:47,385 - INFO - Visiting node at: (17, 13)
# 2024-11-24 00:33:47,385 - INFO - Visiting node at: (18, 13)
# 2024-11-24 00:33:47,386 - INFO - Visiting node at: (19, 13)
# 2024-11-24 00:33:47,386 - INFO - Visiting node at: (19, 12)
# 2024-11-24 00:33:47,388 - INFO - Visiting node at: (18, 12)
# 2024-11-24 00:33:47,388 - INFO - Visiting node at: (17, 12)
# 2024-11-24 00:33:47,389 - INFO - Visiting node at: (16, 12)
# 2024-11-24 00:33:47,389 - INFO - Visiting node at: (15, 12)
# 2024-11-24 00:33:47,389 - INFO - Visiting node at: (15, 11)
# 2024-11-24 00:33:47,390 - INFO - Visiting node at: (16, 11)
# 2024-11-24 00:33:47,390 - INFO - Visiting node at: (17, 11)
# 2024-11-24 00:33:47,391 - INFO - Visiting node at: (18, 11)
# 2024-11-24 00:33:47,391 - INFO - Visiting node at: (19, 11)
# 2024-11-24 00:33:47,391 - INFO - Visiting node at: (19, 10)
# 2024-11-24 00:33:47,392 - INFO - Visiting node at: (18, 10)
# 2024-11-24 00:33:47,392 - INFO - Visiting node at: (17, 10)
# 2024-11-24 00:33:47,392 - INFO - Visiting node at: (16, 10)
# 2024-11-24 00:33:47,393 - INFO - Visiting node at: (15, 10)
# 2024-11-24 00:33:47,393 - INFO - Visiting node at: (15, 9)
# 2024-11-24 00:33:47,393 - INFO - Visiting node at: (16, 9)
# 2024-11-24 00:33:47,394 - INFO - Visiting node at: (17, 9)
# 2024-11-24 00:33:47,394 - INFO - Visiting node at: (18, 9)
# 2024-11-24 00:33:47,394 - INFO - Visiting node at: (19, 9)
# 2024-11-24 00:33:47,395 - INFO - Visiting node at: (19, 8)
# 2024-11-24 00:33:47,395 - INFO - Visiting node at: (18, 8)
# 2024-11-24 00:33:47,395 - INFO - Visiting node at: (17, 8)
# 2024-11-24 00:33:47,396 - INFO - Visiting node at: (16, 8)
# 2024-11-24 00:33:47,396 - INFO - Visiting node at: (15, 8)
# 2024-11-24 00:33:47,396 - INFO - Visiting node at: (15, 7)
# 2024-11-24 00:33:47,397 - INFO - Visiting node at: (16, 7)
# 2024-11-24 00:33:47,397 - INFO - Visiting node at: (17, 7)
# 2024-11-24 00:33:47,397 - INFO - Visiting node at: (18, 7)
# 2024-11-24 00:33:47,397 - INFO - Visiting node at: (19, 7)
# 2024-11-24 00:33:47,398 - INFO - Visiting node at: (19, 6)
# 2024-11-24 00:33:47,398 - INFO - Visiting node at: (18, 6)
# 2024-11-24 00:33:47,398 - INFO - Visiting node at: (17, 6)
# 2024-11-24 00:33:47,399 - INFO - Visiting node at: (16, 6)
# 2024-11-24 00:33:47,399 - INFO - Visiting node at: (15, 6)
# 2024-11-24 00:33:47,399 - INFO - Visiting node at: (15, 5)
# 2024-11-24 00:33:47,399 - INFO - Visiting node at: (16, 5)
# 2024-11-24 00:33:47,400 - INFO - Visiting node at: (17, 5)
# 2024-11-24 00:33:47,400 - INFO - Visiting node at: (18, 5)
# 2024-11-24 00:33:47,401 - INFO - Visiting node at: (19, 5)
# 2024-11-24 00:33:47,402 - INFO - Visiting node at: (19, 4)
# 2024-11-24 00:33:47,402 - INFO - Visiting node at: (18, 4)
# 2024-11-24 00:33:47,402 - INFO - Visiting node at: (17, 4)
# 2024-11-24 00:33:47,403 - INFO - Visiting node at: (16, 4)
# 2024-11-24 00:33:47,403 - INFO - Visiting node at: (15, 4)
# 2024-11-24 00:33:47,404 - INFO - Visiting node at: (15, 3)
# 2024-11-24 00:33:47,404 - INFO - Visiting node at: (16, 3)
# 2024-11-24 00:33:47,404 - INFO - Visiting node at: (17, 3)
# 2024-11-24 00:33:47,405 - INFO - Visiting node at: (18, 3)
# 2024-11-24 00:33:47,405 - INFO - Visiting node at: (19, 3)
# 2024-11-24 00:33:47,405 - INFO - Visiting node at: (19, 2)
# 2024-11-24 00:33:47,406 - INFO - Visiting node at: (18, 2)
# 2024-11-24 00:33:47,406 - INFO - Visiting node at: (17, 2)
# 2024-11-24 00:33:47,406 - INFO - Visiting node at: (16, 2)
# 2024-11-24 00:33:47,407 - INFO - Visiting node at: (15, 2)
# 2024-11-24 00:33:47,407 - INFO - Visiting node at: (15, 1)
# 2024-11-24 00:33:47,407 - INFO - Visiting node at: (16, 1)
# 2024-11-24 00:33:47,408 - INFO - Visiting node at: (17, 1)
# 2024-11-24 00:33:47,408 - INFO - Visiting node at: (18, 1)
# 2024-11-24 00:33:47,409 - INFO - Visiting node at: (19, 1)
# 2024-11-24 00:33:47,409 - INFO - Visiting node at: (19, 34)
# 2024-11-24 00:33:47,409 - INFO - Visiting node at: (18, 34)
# 2024-11-24 00:33:47,410 - INFO - Visiting node at: (17, 34)
# 2024-11-24 00:33:47,410 - INFO - Visiting node at: (16, 34)
# 2024-11-24 00:33:47,410 - INFO - Visiting node at: (15, 34)
# 2024-11-24 00:33:47,410 - INFO - Visiting node at: (14, 34)
# 2024-11-24 00:33:47,411 - INFO - Visiting node at: (13, 34)
# 2024-11-24 00:33:47,411 - INFO - Visiting node at: (12, 34)
# 2024-11-24 00:33:47,411 - INFO - Visiting node at: (11, 34)
# 2024-11-24 00:33:47,412 - INFO - Visiting node at: (10, 34)
# 2024-11-24 00:33:47,412 - INFO - Visiting node at: (9, 34)
# 2024-11-24 00:33:47,414 - INFO - Visiting node at: (8, 34)
# 2024-11-24 00:33:47,414 - INFO - Visiting node at: (7, 34)
# 2024-11-24 00:33:47,414 - INFO - Visiting node at: (7, 35)
# 2024-11-24 00:33:47,415 - INFO - Visiting node at: (8, 35)
# 2024-11-24 00:33:47,415 - INFO - Visiting node at: (9, 35)
# 2024-11-24 00:33:47,415 - INFO - Visiting node at: (10, 35)
# 2024-11-24 00:33:47,416 - INFO - Visiting node at: (11, 35)
# 2024-11-24 00:33:47,416 - INFO - Visiting node at: (12, 35)
# 2024-11-24 00:33:47,416 - INFO - Visiting node at: (13, 35)
# 2024-11-24 00:33:47,416 - INFO - Visiting node at: (14, 35)
# 2024-11-24 00:33:47,417 - INFO - Visiting node at: (15, 35)
# 2024-11-24 00:33:47,418 - INFO - Visiting node at: (16, 35)
# 2024-11-24 00:33:47,418 - INFO - Visiting node at: (17, 35)
# 2024-11-24 00:33:47,418 - INFO - Visiting node at: (18, 35)
# 2024-11-24 00:33:47,419 - INFO - Visiting node at: (19, 35)
# 2024-11-24 00:33:47,419 - INFO - Visiting node at: (19, 36)
# 2024-11-24 00:33:47,419 - INFO - Visiting node at: (18, 36)
# 2024-11-24 00:33:47,419 - INFO - Visiting node at: (17, 36)
# 2024-11-24 00:33:47,419 - INFO - Visiting node at: (16, 36)
# 2024-11-24 00:33:47,420 - INFO - Visiting node at: (15, 36)
# 2024-11-24 00:33:47,423 - INFO - Visiting node at: (14, 36)
# 2024-11-24 00:33:47,423 - INFO - Visiting node at: (13, 36)
# 2024-11-24 00:33:47,423 - INFO - Visiting node at: (12, 36)
# 2024-11-24 00:33:47,424 - INFO - Visiting node at: (11, 36)
# 2024-11-24 00:33:47,424 - INFO - Visiting node at: (10, 36)
# 2024-11-24 00:33:47,424 - INFO - Visiting node at: (9, 36)
# 2024-11-24 00:33:47,425 - INFO - Visiting node at: (8, 36)
# 2024-11-24 00:33:47,425 - INFO - Visiting node at: (7, 36)
# 2024-11-24 00:33:47,425 - INFO - Visiting node at: (7, 37)
# 2024-11-24 00:33:47,425 - INFO - Visiting node at: (8, 37)
# 2024-11-24 00:33:47,426 - INFO - Visiting node at: (9, 37)
# 2024-11-24 00:33:47,426 - INFO - Visiting node at: (10, 37)
# 2024-11-24 00:33:47,426 - INFO - Visiting node at: (11, 37)
# 2024-11-24 00:33:47,426 - INFO - Visiting node at: (12, 37)
# 2024-11-24 00:33:47,427 - INFO - Visiting node at: (13, 37)
# 2024-11-24 00:33:47,427 - INFO - Visiting node at: (14, 37)
# 2024-11-24 00:33:47,427 - INFO - Visiting node at: (15, 37)
# 2024-11-24 00:33:47,427 - INFO - Visiting node at: (16, 37)
# 2024-11-24 00:33:47,427 - INFO - Visiting node at: (17, 37)
# 2024-11-24 00:33:47,429 - INFO - Visiting node at: (18, 37)
# 2024-11-24 00:33:47,429 - INFO - Visiting node at: (19, 37)
# 2024-11-24 00:33:47,429 - INFO - Visiting node at: (19, 38)
# 2024-11-24 00:33:47,429 - INFO - Visiting node at: (18, 38)
# 2024-11-24 00:33:47,430 - INFO - Visiting node at: (17, 38)
# 2024-11-24 00:33:47,430 - INFO - Visiting node at: (16, 38)
# 2024-11-24 00:33:47,430 - INFO - Visiting node at: (15, 38)
# 2024-11-24 00:33:47,431 - INFO - Visiting node at: (14, 38)
# 2024-11-24 00:33:47,431 - INFO - Visiting node at: (13, 38)
# 2024-11-24 00:33:47,432 - INFO - Visiting node at: (12, 38)
# 2024-11-24 00:33:47,432 - INFO - Visiting node at: (11, 38)
# 2024-11-24 00:33:47,433 - INFO - Visiting node at: (11, 39)
# 2024-11-24 00:33:47,433 - INFO - Visiting node at: (12, 39)
# 2024-11-24 00:33:47,433 - INFO - Visiting node at: (13, 39)
# 2024-11-24 00:33:47,434 - INFO - Visiting node at: (14, 39)
# 2024-11-24 00:33:47,434 - INFO - Visiting node at: (15, 39)
# 2024-11-24 00:33:47,434 - INFO - Visiting node at: (16, 39)
# 2024-11-24 00:33:47,434 - INFO - Visiting node at: (17, 39)
# 2024-11-24 00:33:47,435 - INFO - Visiting node at: (18, 39)
# 2024-11-24 00:33:47,435 - INFO - Visiting node at: (19, 39)
# 2024-11-24 00:33:47,435 - INFO - Visiting node at: (19, 40)
# 2024-11-24 00:33:47,435 - INFO - Visiting node at: (18, 40)
# 2024-11-24 00:33:47,436 - INFO - Visiting node at: (17, 40)
# 2024-11-24 00:33:47,436 - INFO - Visiting node at: (16, 40)
# 2024-11-24 00:33:47,436 - INFO - Visiting node at: (15, 40)
# 2024-11-24 00:33:47,437 - INFO - Visiting node at: (14, 40)
# 2024-11-24 00:33:47,437 - INFO - Visiting node at: (13, 40)
# 2024-11-24 00:33:47,437 - INFO - Visiting node at: (12, 40)
# 2024-11-24 00:33:47,437 - INFO - Visiting node at: (11, 40)
# 2024-11-24 00:33:47,437 - INFO - Visiting node at: (11, 41)
# 2024-11-24 00:33:47,438 - INFO - Visiting node at: (12, 41)
# 2024-11-24 00:33:47,438 - INFO - Visiting node at: (13, 41)
# 2024-11-24 00:33:47,438 - INFO - Visiting node at: (14, 41)
# 2024-11-24 00:33:47,438 - INFO - Visiting node at: (15, 41)
# 2024-11-24 00:33:47,438 - INFO - Visiting node at: (16, 41)
# 2024-11-24 00:33:47,439 - INFO - Visiting node at: (17, 41)
# 2024-11-24 00:33:47,439 - INFO - Visiting node at: (18, 41)
# 2024-11-24 00:33:47,439 - INFO - Visiting node at: (19, 41)
# 2024-11-24 00:33:47,439 - INFO - Visiting node at: (19, 42)
# 2024-11-24 00:33:47,440 - INFO - Visiting node at: (18, 42)
# 2024-11-24 00:33:47,440 - INFO - Visiting node at: (17, 42)
# 2024-11-24 00:33:47,440 - INFO - Visiting node at: (16, 42)
# 2024-11-24 00:33:47,441 - INFO - Visiting node at: (15, 42)
# 2024-11-24 00:33:47,441 - INFO - Visiting node at: (14, 42)
# 2024-11-24 00:33:47,441 - INFO - Visiting node at: (13, 42)
# 2024-11-24 00:33:47,441 - INFO - Visiting node at: (12, 42)
# 2024-11-24 00:33:47,442 - INFO - Visiting node at: (11, 42)
# 2024-11-24 00:33:47,442 - INFO - Visiting node at: (11, 43)
# 2024-11-24 00:33:47,442 - INFO - Visiting node at: (12, 43)
# 2024-11-24 00:33:47,443 - INFO - Visiting node at: (13, 43)
# 2024-11-24 00:33:47,443 - INFO - Visiting node at: (14, 43)
# 2024-11-24 00:33:47,443 - INFO - Visiting node at: (15, 43)
# 2024-11-24 00:33:47,443 - INFO - Visiting node at: (16, 43)
# 2024-11-24 00:33:47,444 - INFO - Visiting node at: (17, 43)
# 2024-11-24 00:33:47,444 - INFO - Visiting node at: (18, 43)
# 2024-11-24 00:33:47,444 - INFO - Visiting node at: (19, 43)
# 2024-11-24 00:33:47,445 - INFO - Visiting node at: (19, 44)
# 2024-11-24 00:33:47,445 - INFO - Visiting node at: (18, 44)
# 2024-11-24 00:33:47,446 - INFO - Visiting node at: (17, 44)
# 2024-11-24 00:33:47,446 - INFO - Visiting node at: (16, 44)
# 2024-11-24 00:33:47,446 - INFO - Visiting node at: (15, 44)
# 2024-11-24 00:33:47,446 - INFO - Visiting node at: (14, 44)
# 2024-11-24 00:33:47,447 - INFO - Visiting node at: (13, 44)
# 2024-11-24 00:33:47,447 - INFO - Visiting node at: (12, 44)
# 2024-11-24 00:33:47,447 - INFO - Visiting node at: (11, 44)
# 2024-11-24 00:33:47,448 - INFO - Visiting node at: (11, 45)
# 2024-11-24 00:33:47,449 - INFO - Visiting node at: (12, 45)
# 2024-11-24 00:33:47,449 - INFO - Visiting node at: (13, 45)
# 2024-11-24 00:33:47,450 - INFO - Visiting node at: (14, 45)
# 2024-11-24 00:33:47,450 - INFO - Visiting node at: (15, 45)
# 2024-11-24 00:33:47,450 - INFO - Visiting node at: (16, 45)
# 2024-11-24 00:33:47,451 - INFO - Visiting node at: (17, 45)
# 2024-11-24 00:33:47,451 - INFO - Visiting node at: (18, 45)
# 2024-11-24 00:33:47,451 - INFO - Visiting node at: (19, 45)
# 2024-11-24 00:33:47,452 - INFO - Visiting node at: (19, 46)
# 2024-11-24 00:33:47,452 - INFO - Visiting node at: (18, 46)
# 2024-11-24 00:33:47,453 - INFO - Visiting node at: (17, 46)
# 2024-11-24 00:33:47,453 - INFO - Visiting node at: (16, 46)
# 2024-11-24 00:33:47,453 - INFO - Visiting node at: (15, 46)
# 2024-11-24 00:33:47,454 - INFO - Visiting node at: (14, 46)
# 2024-11-24 00:33:47,454 - INFO - Visiting node at: (13, 46)
# 2024-11-24 00:33:47,454 - INFO - Visiting node at: (12, 46)
# 2024-11-24 00:33:47,455 - INFO - Visiting node at: (11, 46)
# 2024-11-24 00:33:47,455 - INFO - Visiting node at: (11, 47)
# 2024-11-24 00:33:47,455 - INFO - Visiting node at: (12, 47)
# 2024-11-24 00:33:47,455 - INFO - Visiting node at: (13, 47)
# 2024-11-24 00:33:47,456 - INFO - Visiting node at: (14, 47)
# 2024-11-24 00:33:47,456 - INFO - Visiting node at: (15, 47)
# 2024-11-24 00:33:47,456 - INFO - Visiting node at: (16, 47)
# 2024-11-24 00:33:47,457 - INFO - Visiting node at: (17, 47)
# 2024-11-24 00:33:47,457 - INFO - Visiting node at: (18, 47)
# 2024-11-24 00:33:47,457 - INFO - Visiting node at: (19, 47)
# 2024-11-24 00:33:47,458 - INFO - Visiting node at: (12, 48)
# 2024-11-24 00:33:47,458 - INFO - Visiting node at: (11, 48)
# 2024-11-24 00:33:47,458 - INFO - Visiting node at: (11, 49)
# 2024-11-24 00:33:47,461 - INFO - Visiting node at: (12, 49)
# 2024-11-24 00:33:47,462 - INFO - Visiting node at: (13, 49)
# 2024-11-24 00:33:47,462 - INFO - Visiting node at: (14, 49)
# 2024-11-24 00:33:47,463 - INFO - Visiting node at: (15, 49)
# 2024-11-24 00:33:47,464 - INFO - Visiting node at: (16, 49)
# 2024-11-24 00:33:47,465 - INFO - Visiting node at: (17, 49)
# 2024-11-24 00:33:47,465 - INFO - Visiting node at: (18, 49)
# 2024-11-24 00:33:47,465 - INFO - Visiting node at: (19, 49)
# 2024-11-24 00:33:47,466 - INFO - Visiting node at: (19, 50)
# 2024-11-24 00:33:47,466 - INFO - Visiting node at: (18, 50)
# 2024-11-24 00:33:47,466 - INFO - Visiting node at: (17, 50)
# 2024-11-24 00:33:47,467 - INFO - Visiting node at: (16, 50)
# 2024-11-24 00:33:47,467 - INFO - Visiting node at: (15, 50)
# 2024-11-24 00:33:47,467 - INFO - Visiting node at: (14, 50)
# 2024-11-24 00:33:47,467 - INFO - Visiting node at: (13, 50)
# 2024-11-24 00:33:47,468 - INFO - Visiting node at: (12, 50)
# 2024-11-24 00:33:47,468 - INFO - Visiting node at: (11, 50)
# 2024-11-24 00:33:47,468 - INFO - Visiting node at: (11, 51)
# 2024-11-24 00:33:47,468 - INFO - Visiting node at: (12, 51)
# 2024-11-24 00:33:47,469 - INFO - Visiting node at: (13, 51)
# 2024-11-24 00:33:47,469 - INFO - Visiting node at: (14, 51)
# 2024-11-24 00:33:47,469 - INFO - Visiting node at: (15, 51)
# 2024-11-24 00:33:47,470 - INFO - Visiting node at: (16, 51)
# 2024-11-24 00:33:47,470 - INFO - Visiting node at: (17, 51)
# 2024-11-24 00:33:47,470 - INFO - Visiting node at: (18, 51)
# 2024-11-24 00:33:47,470 - INFO - Visiting node at: (19, 51)
# 2024-11-24 00:33:47,471 - INFO - Visiting node at: (19, 52)
# 2024-11-24 00:33:47,471 - INFO - Visiting node at: (18, 52)
# 2024-11-24 00:33:47,471 - INFO - Visiting node at: (17, 52)
# 2024-11-24 00:33:47,471 - INFO - Visiting node at: (16, 52)
# 2024-11-24 00:33:47,472 - INFO - Visiting node at: (15, 52)
# 2024-11-24 00:33:47,472 - INFO - Visiting node at: (14, 52)
# 2024-11-24 00:33:47,472 - INFO - Visiting node at: (13, 52)
# 2024-11-24 00:33:47,473 - INFO - Visiting node at: (12, 52)
# 2024-11-24 00:33:47,473 - INFO - Visiting node at: (11, 52)
# 2024-11-24 00:33:47,473 - INFO - Visiting node at: (11, 53)
# 2024-11-24 00:33:47,474 - INFO - Visiting node at: (12, 53)
# 2024-11-24 00:33:47,474 - INFO - Visiting node at: (13, 53)
# 2024-11-24 00:33:47,474 - INFO - Visiting node at: (14, 53)
# 2024-11-24 00:33:47,475 - INFO - Visiting node at: (15, 53)
# 2024-11-24 00:33:47,475 - INFO - Visiting node at: (16, 53)
# 2024-11-24 00:33:47,475 - INFO - Visiting node at: (17, 53)
# 2024-11-24 00:33:47,476 - INFO - Visiting node at: (18, 53)
# 2024-11-24 00:33:47,476 - INFO - Visiting node at: (19, 53)
# 2024-11-24 00:33:47,476 - INFO - Visiting node at: (19, 54)
# 2024-11-24 00:33:47,476 - INFO - Visiting node at: (18, 54)
# 2024-11-24 00:33:47,477 - INFO - Visiting node at: (17, 54)
# 2024-11-24 00:33:47,477 - INFO - Visiting node at: (16, 54)
# 2024-11-24 00:33:47,477 - INFO - Visiting node at: (15, 54)
# 2024-11-24 00:33:47,477 - INFO - Visiting node at: (14, 54)
# 2024-11-24 00:33:47,478 - INFO - Visiting node at: (13, 54)
# 2024-11-24 00:33:47,478 - INFO - Visiting node at: (12, 54)
# 2024-11-24 00:33:47,478 - INFO - Visiting node at: (11, 54)
# 2024-11-24 00:33:47,479 - INFO - Visiting node at: (11, 55)
# 2024-11-24 00:33:47,479 - INFO - Visiting node at: (12, 55)
# 2024-11-24 00:33:47,479 - INFO - Visiting node at: (13, 55)
# 2024-11-24 00:33:47,480 - INFO - Visiting node at: (14, 55)
# 2024-11-24 00:33:47,480 - INFO - Visiting node at: (15, 55)
# 2024-11-24 00:33:47,480 - INFO - Visiting node at: (16, 55)
# 2024-11-24 00:33:47,481 - INFO - Visiting node at: (17, 55)
# 2024-11-24 00:33:47,481 - INFO - Visiting node at: (18, 55)
# 2024-11-24 00:33:47,482 - INFO - Visiting node at: (19, 55)
# 2024-11-24 00:33:47,482 - INFO - Visiting node at: (19, 56)
# 2024-11-24 00:33:47,483 - INFO - Visiting node at: (18, 56)
# 2024-11-24 00:33:47,483 - INFO - Visiting node at: (17, 56)
# 2024-11-24 00:33:47,483 - INFO - Visiting node at: (16, 56)
# 2024-11-24 00:33:47,484 - INFO - Visiting node at: (15, 56)
# 2024-11-24 00:33:47,484 - INFO - Visiting node at: (14, 56)
# 2024-11-24 00:33:47,484 - INFO - Visiting node at: (13, 56)
# 2024-11-24 00:33:47,485 - INFO - Visiting node at: (12, 56)
# 2024-11-24 00:33:47,485 - INFO - Visiting node at: (11, 56)
# 2024-11-24 00:33:47,485 - INFO - Visiting node at: (11, 57)
# 2024-11-24 00:33:47,485 - INFO - Visiting node at: (12, 57)
# 2024-11-24 00:33:47,486 - INFO - Visiting node at: (13, 57)
# 2024-11-24 00:33:47,486 - INFO - Visiting node at: (14, 57)
# 2024-11-24 00:33:47,487 - INFO - Visiting node at: (15, 57)
# 2024-11-24 00:33:47,487 - INFO - Visiting node at: (16, 57)
# 2024-11-24 00:33:47,488 - INFO - Visiting node at: (17, 57)
# 2024-11-24 00:33:47,488 - INFO - Visiting node at: (18, 57)
# 2024-11-24 00:33:47,488 - INFO - Visiting node at: (19, 57)
# 2024-11-24 00:33:47,488 - INFO - Visiting node at: (19, 58)
# 2024-11-24 00:33:47,489 - INFO - Visiting node at: (18, 58)
# 2024-11-24 00:33:47,489 - INFO - Visiting node at: (17, 58)
# 2024-11-24 00:33:47,489 - INFO - Visiting node at: (16, 58)
# 2024-11-24 00:33:47,489 - INFO - Visiting node at: (15, 58)
# 2024-11-24 00:33:47,490 - INFO - Visiting node at: (14, 58)
# 2024-11-24 00:33:47,490 - INFO - Visiting node at: (13, 58)
# 2024-11-24 00:33:47,490 - INFO - Visiting node at: (12, 58)
# 2024-11-24 00:33:47,493 - INFO - Visiting node at: (11, 58)
# 2024-11-24 00:33:47,493 - INFO - Visiting node at: (11, 59)
# 2024-11-24 00:33:47,494 - INFO - Visiting node at: (12, 59)
# 2024-11-24 00:33:47,494 - INFO - Visiting node at: (13, 59)
# 2024-11-24 00:33:47,494 - INFO - Visiting node at: (14, 59)
# 2024-11-24 00:33:47,494 - INFO - Visiting node at: (15, 59)
# 2024-11-24 00:33:47,495 - INFO - Visiting node at: (16, 59)
# 2024-11-24 00:33:47,495 - INFO - Visiting node at: (17, 59)
# 2024-11-24 00:33:47,495 - INFO - Visiting node at: (18, 59)
# 2024-11-24 00:33:47,495 - INFO - Visiting node at: (19, 59)
# 2024-11-24 00:33:47,496 - INFO - Visiting node at: (19, 60)
# 2024-11-24 00:33:47,496 - INFO - Visiting node at: (18, 60)
# 2024-11-24 00:33:47,496 - INFO - Visiting node at: (17, 60)
# 2024-11-24 00:33:47,497 - INFO - Visiting node at: (16, 60)
# 2024-11-24 00:33:47,497 - INFO - Visiting node at: (15, 60)
# 2024-11-24 00:33:47,497 - INFO - Visiting node at: (14, 60)
# 2024-11-24 00:33:47,497 - INFO - Visiting node at: (13, 60)
# 2024-11-24 00:33:47,498 - INFO - Visiting node at: (12, 60)
# 2024-11-24 00:33:47,499 - INFO - Visiting node at: (11, 60)
# 2024-11-24 00:33:47,499 - INFO - Visiting node at: (11, 61)
# 2024-11-24 00:33:47,499 - INFO - Visiting node at: (12, 61)
# 2024-11-24 00:33:47,499 - INFO - Visiting node at: (13, 61)
# 2024-11-24 00:33:47,499 - INFO - Visiting node at: (14, 61)
# 2024-11-24 00:33:47,500 - INFO - Visiting node at: (15, 61)
# 2024-11-24 00:33:47,500 - INFO - Visiting node at: (16, 61)
# 2024-11-24 00:33:47,500 - INFO - Visiting node at: (17, 61)
# 2024-11-24 00:33:47,501 - INFO - Visiting node at: (18, 61)
# 2024-11-24 00:33:47,501 - INFO - Visiting node at: (19, 61)
# 2024-11-24 00:33:47,501 - INFO - Visiting node at: (19, 62)
# 2024-11-24 00:33:47,502 - INFO - Visiting node at: (18, 62)
# 2024-11-24 00:33:47,502 - INFO - Visiting node at: (17, 62)
# 2024-11-24 00:33:47,502 - INFO - Visiting node at: (16, 62)
# 2024-11-24 00:33:47,503 - INFO - Visiting node at: (15, 62)
# 2024-11-24 00:33:47,503 - INFO - Visiting node at: (14, 62)
# 2024-11-24 00:33:47,503 - INFO - Visiting node at: (13, 62)
# 2024-11-24 00:33:47,504 - INFO - Visiting node at: (12, 62)
# 2024-11-24 00:33:47,504 - INFO - Visiting node at: (11, 62)
# 2024-11-24 00:33:47,504 - INFO - Visiting node at: (11, 63)
# 2024-11-24 00:33:47,504 - INFO - Visiting node at: (12, 63)
# 2024-11-24 00:33:47,505 - INFO - Visiting node at: (13, 63)
# 2024-11-24 00:33:47,505 - INFO - Visiting node at: (14, 63)
# 2024-11-24 00:33:47,505 - INFO - Visiting node at: (15, 63)
# 2024-11-24 00:33:47,505 - INFO - Visiting node at: (16, 63)
# 2024-11-24 00:33:47,505 - INFO - Visiting node at: (17, 63)
# 2024-11-24 00:33:47,506 - INFO - Visiting node at: (18, 63)
# 2024-11-24 00:33:47,506 - INFO - Visiting node at: (19, 63)
# 2024-11-24 00:33:47,508 - INFO - Visiting node at: (19, 64)
# 2024-11-24 00:33:47,509 - INFO - Visiting node at: (18, 64)
# 2024-11-24 00:33:47,509 - INFO - Visiting node at: (17, 64)
# 2024-11-24 00:33:47,510 - INFO - Visiting node at: (16, 64)
# 2024-11-24 00:33:47,511 - INFO - Visiting node at: (15, 64)
# 2024-11-24 00:33:47,511 - INFO - Visiting node at: (14, 64)
# 2024-11-24 00:33:47,511 - INFO - Visiting node at: (13, 64)
# 2024-11-24 00:33:47,512 - INFO - Visiting node at: (12, 64)
# 2024-11-24 00:33:47,512 - INFO - Visiting node at: (11, 64)
# 2024-11-24 00:33:47,512 - INFO - Visiting node at: (10, 64)
# 2024-11-24 00:33:47,513 - INFO - Visiting node at: (9, 64)
# 2024-11-24 00:33:47,513 - INFO - Visiting node at: (8, 64)
# 2024-11-24 00:33:47,513 - INFO - Visiting node at: (7, 64)
# 2024-11-24 00:33:47,514 - INFO - Visiting node at: (6, 64)
# 2024-11-24 00:33:47,514 - INFO - Visiting node at: (5, 64)
# 2024-11-24 00:33:47,515 - INFO - Visiting node at: (4, 64)
# 2024-11-24 00:33:47,515 - INFO - Visiting node at: (3, 64)
# 2024-11-24 00:33:47,515 - INFO - Visiting node at: (2, 64)
# 2024-11-24 00:33:47,516 - INFO - Visiting node at: (1, 64)
# 2024-11-24 00:33:47,516 - INFO - Visiting node at: (1, 63)
# 2024-11-24 00:33:47,517 - INFO - Visiting node at: (2, 63)
# 2024-11-24 00:33:47,517 - INFO - Visiting node at: (3, 63)
# ...
# 2024-11-24 00:33:47,803 - INFO - Marking path at: (17, 38)
# 2024-11-24 00:33:47,803 - INFO - Marking path at: (18, 38)
# 2024-11-24 00:33:47,804 - INFO - Marking path at: (19, 38)
# 2024-11-24 00:33:47,804 - INFO - Marking path at: (19, 37)
# 2024-11-24 00:33:47,805 - INFO - Marking path at: (18, 37)
# 2024-11-24 00:33:47,806 - INFO - Marking path at: (17, 37)
# 2024-11-24 00:33:47,806 - INFO - Marking path at: (16, 37)
# 2024-11-24 00:33:47,806 - INFO - Marking path at: (15, 37)
# 2024-11-24 00:33:47,806 - INFO - Marking path at: (14, 37)
# 2024-11-24 00:33:47,807 - INFO - Marking path at: (13, 37)
# 2024-11-24 00:33:47,807 - INFO - Marking path at: (12, 37)
# 2024-11-24 00:33:47,807 - INFO - Marking path at: (11, 37)
# 2024-11-24 00:33:47,808 - INFO - Marking path at: (10, 37)
# 2024-11-24 00:33:47,808 - INFO - Marking path at: (9, 37)
# 2024-11-24 00:33:47,808 - INFO - Marking path at: (8, 37)
# 2024-11-24 00:33:47,808 - INFO - Marking path at: (7, 37)
# 2024-11-24 00:33:47,809 - INFO - Marking path at: (7, 36)
# 2024-11-24 00:33:47,809 - INFO - Marking path at: (8, 36)
# 2024-11-24 00:33:47,810 - INFO - Marking path at: (9, 36)
# 2024-11-24 00:33:47,810 - INFO - Marking path at: (10, 36)
# 2024-11-24 00:33:47,811 - INFO - Marking path at: (11, 36)
# 2024-11-24 00:33:47,811 - INFO - Marking path at: (12, 36)
# 2024-11-24 00:33:47,811 - INFO - Marking path at: (13, 36)
# 2024-11-24 00:33:47,811 - INFO - Marking path at: (14, 36)
# 2024-11-24 00:33:47,812 - INFO - Marking path at: (15, 36)
# 2024-11-24 00:33:47,812 - INFO - Marking path at: (16, 36)
# 2024-11-24 00:33:47,812 - INFO - Marking path at: (17, 36)
# 2024-11-24 00:33:47,813 - INFO - Marking path at: (18, 36)
# 2024-11-24 00:33:47,813 - INFO - Marking path at: (19, 36)
# 2024-11-24 00:33:47,813 - INFO - Marking path at: (19, 35)
# 2024-11-24 00:33:47,813 - INFO - Marking path at: (18, 35)
# 2024-11-24 00:33:47,814 - INFO - Marking path at: (17, 35)
# 2024-11-24 00:33:47,814 - INFO - Marking path at: (16, 35)
# 2024-11-24 00:33:47,814 - INFO - Marking path at: (15, 35)
# 2024-11-24 00:33:47,814 - INFO - Marking path at: (14, 35)
# 2024-11-24 00:33:47,815 - INFO - Marking path at: (13, 35)
# 2024-11-24 00:33:47,815 - INFO - Marking path at: (12, 35)
# 2024-11-24 00:33:47,815 - INFO - Marking path at: (11, 35)
# 2024-11-24 00:33:47,815 - INFO - Marking path at: (10, 35)
# 2024-11-24 00:33:47,816 - INFO - Marking path at: (9, 35)
# 2024-11-24 00:33:47,816 - INFO - Marking path at: (8, 35)
# 2024-11-24 00:33:47,816 - INFO - Marking path at: (7, 35)
# 2024-11-24 00:33:47,816 - INFO - Marking path at: (7, 34)
# 2024-11-24 00:33:47,817 - INFO - Marking path at: (8, 34)
# 2024-11-24 00:33:47,817 - INFO - Marking path at: (9, 34)
# 2024-11-24 00:33:47,817 - INFO - Marking path at: (10, 34)
# 2024-11-24 00:33:47,817 - INFO - Marking path at: (11, 34)
# 2024-11-24 00:33:47,817 - INFO - Marking path at: (12, 34)
# 2024-11-24 00:33:47,818 - INFO - Marking path at: (13, 34)
# 2024-11-24 00:33:47,818 - INFO - Marking path at: (14, 34)
# 2024-11-24 00:33:47,818 - INFO - Marking path at: (15, 34)
# 2024-11-24 00:33:47,819 - INFO - Marking path at: (16, 34)
# 2024-11-24 00:33:47,819 - INFO - Marking path at: (17, 34)
# 2024-11-24 00:33:47,819 - INFO - Marking path at: (18, 34)
# 2024-11-24 00:33:47,819 - INFO - Marking path at: (19, 34)
# 2024-11-24 00:33:47,820 - INFO - Marking path at: (19, 33)
# 2024-11-24 00:33:47,820 - INFO - Marking path at: (18, 33)
# 2024-11-24 00:33:47,820 - INFO - Marking path at: (17, 33)
# 2024-11-24 00:33:47,820 - INFO - Marking path at: (16, 33)
# 2024-11-24 00:33:47,821 - INFO - Marking path at: (15, 33)
# 2024-11-24 00:33:47,821 - INFO - Marking path at: (14, 33)
# 2024-11-24 00:33:47,821 - INFO - Marking path at: (13, 33)
# 2024-11-24 00:33:47,822 - INFO - Marking path at: (12, 33)
# 2024-11-24 00:33:47,822 - INFO - Marking path at: (11, 33)
# 2024-11-24 00:33:47,822 - INFO - Marking path at: (10, 33)
# 2024-11-24 00:33:47,823 - INFO - Marking path at: (9, 33)
# 2024-11-24 00:33:47,824 - INFO - Marking path at: (8, 33)
# 2024-11-24 00:33:47,824 - INFO - Marking path at: (7, 33)
# 2024-11-24 00:33:47,825 - INFO - Marking path at: (7, 32)
# 2024-11-24 00:33:47,825 - INFO - Marking path at: (8, 32)
# 2024-11-24 00:33:47,825 - INFO - Marking path at: (9, 32)
# 2024-11-24 00:33:47,826 - INFO - Marking path at: (10, 32)
# 2024-11-24 00:33:47,826 - INFO - Marking path at: (11, 32)
# 2024-11-24 00:33:47,826 - INFO - Marking path at: (12, 32)
# 2024-11-24 00:33:47,826 - INFO - Marking path at: (13, 32)
# 2024-11-24 00:33:47,830 - INFO - Marking path at: (13, 31)
# 2024-11-24 00:33:47,831 - INFO - Marking path at: (12, 31)
# 2024-11-24 00:33:47,831 - INFO - Marking path at: (11, 31)
# 2024-11-24 00:33:47,832 - INFO - Marking path at: (10, 31)
# 2024-11-24 00:33:47,832 - INFO - Marking path at: (9, 31)
# 2024-11-24 00:33:47,832 - INFO - Marking path at: (8, 31)
# 2024-11-24 00:33:47,832 - INFO - Marking path at: (7, 31)
# 2024-11-24 00:33:47,833 - INFO - Marking path at: (7, 30)
# 2024-11-24 00:33:47,833 - INFO - Marking path at: (8, 30)
# 2024-11-24 00:33:47,833 - INFO - Marking path at: (9, 30)
# 2024-11-24 00:33:47,834 - INFO - Marking path at: (10, 30)
# 2024-11-24 00:33:47,834 - INFO - Marking path at: (11, 30)
# 2024-11-24 00:33:47,835 - INFO - Marking path at: (12, 30)
# 2024-11-24 00:33:47,835 - INFO - Marking path at: (13, 30)
# 2024-11-24 00:33:47,835 - INFO - Marking path at: (13, 29)
# 2024-11-24 00:33:47,836 - INFO - Marking path at: (12, 29)
# 2024-11-24 00:33:47,836 - INFO - Marking path at: (11, 29)
# 2024-11-24 00:33:47,836 - INFO - Marking path at: (10, 29)
# 2024-11-24 00:33:47,836 - INFO - Marking path at: (9, 29)
# 2024-11-24 00:33:47,837 - INFO - Marking path at: (8, 29)
# 2024-11-24 00:33:47,837 - INFO - Marking path at: (7, 29)
# 2024-11-24 00:33:47,838 - INFO - Marking path at: (7, 28)
# 2024-11-24 00:33:47,838 - INFO - Marking path at: (8, 28)
# 2024-11-24 00:33:47,841 - INFO - Marking path at: (9, 28)
# 2024-11-24 00:33:47,842 - INFO - Marking path at: (10, 28)
# 2024-11-24 00:33:47,842 - INFO - Marking path at: (11, 28)
# 2024-11-24 00:33:47,842 - INFO - Marking path at: (12, 28)
# 2024-11-24 00:33:47,843 - INFO - Marking path at: (13, 28)
# 2024-11-24 00:33:47,843 - INFO - Marking path at: (13, 27)
# 2024-11-24 00:33:47,843 - INFO - Marking path at: (12, 27)
# 2024-11-24 00:33:47,843 - INFO - Marking path at: (11, 27)
# 2024-11-24 00:33:47,844 - INFO - Marking path at: (10, 27)
# 2024-11-24 00:33:47,844 - INFO - Marking path at: (9, 27)
# 2024-11-24 00:33:47,844 - INFO - Marking path at: (8, 27)
# 2024-11-24 00:33:47,844 - INFO - Marking path at: (7, 27)
# 2024-11-24 00:33:47,844 - INFO - Marking path at: (7, 26)
# 2024-11-24 00:33:47,845 - INFO - Marking path at: (8, 26)
# 2024-11-24 00:33:47,845 - INFO - Marking path at: (9, 26)
# 2024-11-24 00:33:47,845 - INFO - Marking path at: (10, 26)
# 2024-11-24 00:33:47,845 - INFO - Marking path at: (11, 26)
# 2024-11-24 00:33:47,846 - INFO - Marking path at: (12, 26)
# 2024-11-24 00:33:47,846 - INFO - Marking path at: (13, 26)
# 2024-11-24 00:33:47,846 - INFO - Marking path at: (13, 25)
# 2024-11-24 00:33:47,846 - INFO - Marking path at: (12, 25)
# 2024-11-24 00:33:47,847 - INFO - Marking path at: (11, 25)
# 2024-11-24 00:33:47,847 - INFO - Marking path at: (10, 25)
# 2024-11-24 00:33:47,847 - INFO - Marking path at: (9, 25)
# 2024-11-24 00:33:47,847 - INFO - Marking path at: (8, 25)
# 2024-11-24 00:33:47,848 - INFO - Marking path at: (7, 25)
# 2024-11-24 00:33:47,848 - INFO - Marking path at: (7, 24)
# 2024-11-24 00:33:47,849 - INFO - Marking path at: (8, 24)
# 2024-11-24 00:33:47,849 - INFO - Marking path at: (9, 24)
# 2024-11-24 00:33:47,849 - INFO - Marking path at: (10, 24)
# 2024-11-24 00:33:47,850 - INFO - Marking path at: (11, 24)
# 2024-11-24 00:33:47,850 - INFO - Marking path at: (12, 24)
# 2024-11-24 00:33:47,851 - INFO - Marking path at: (13, 24)
# 2024-11-24 00:33:47,851 - INFO - Marking path at: (13, 23)
# 2024-11-24 00:33:47,852 - INFO - Marking path at: (12, 23)
# 2024-11-24 00:33:47,853 - INFO - Marking path at: (11, 23)
# 2024-11-24 00:33:47,854 - INFO - Marking path at: (10, 23)
# 2024-11-24 00:33:47,855 - INFO - Marking path at: (9, 23)
# 2024-11-24 00:33:47,856 - INFO - Marking path at: (8, 23)
# 2024-11-24 00:33:47,857 - INFO - Marking path at: (7, 23)
# 2024-11-24 00:33:47,857 - INFO - Marking path at: (7, 22)
# 2024-11-24 00:33:47,857 - INFO - Marking path at: (8, 22)
# 2024-11-24 00:33:47,858 - INFO - Marking path at: (9, 22)
# 2024-11-24 00:33:47,858 - INFO - Marking path at: (10, 22)
# 2024-11-24 00:33:47,859 - INFO - Marking path at: (11, 22)
# 2024-11-24 00:33:47,859 - INFO - Marking path at: (12, 22)
# 2024-11-24 00:33:47,860 - INFO - Marking path at: (13, 22)
# 2024-11-24 00:33:47,860 - INFO - Marking path at: (13, 21)
# 2024-11-24 00:33:47,860 - INFO - Marking path at: (12, 21)
# 2024-11-24 00:33:47,861 - INFO - Marking path at: (11, 21)
# 2024-11-24 00:33:47,861 - INFO - Marking path at: (10, 21)
# 2024-11-24 00:33:47,863 - INFO - Marking path at: (9, 21)
# 2024-11-24 00:33:47,863 - INFO - Marking path at: (8, 21)
# 2024-11-24 00:33:47,864 - INFO - Marking path at: (7, 21)
# 2024-11-24 00:33:47,864 - INFO - Marking path at: (7, 20)
# 2024-11-24 00:33:47,864 - INFO - Marking path at: (8, 20)
# 2024-11-24 00:33:47,865 - INFO - Marking path at: (9, 20)
# 2024-11-24 00:33:47,865 - INFO - Marking path at: (10, 20)
# 2024-11-24 00:33:47,866 - INFO - Marking path at: (11, 20)
# 2024-11-24 00:33:47,866 - INFO - Marking path at: (12, 20)
# 2024-11-24 00:33:47,866 - INFO - Marking path at: (13, 20)
# 2024-11-24 00:33:47,867 - INFO - Marking path at: (13, 19)
# 2024-11-24 00:33:47,867 - INFO - Marking path at: (12, 19)
# 2024-11-24 00:33:47,867 - INFO - Marking path at: (11, 19)
# 2024-11-24 00:33:47,868 - INFO - Marking path at: (10, 19)
# 2024-11-24 00:33:47,868 - INFO - Marking path at: (9, 19)
# 2024-11-24 00:33:47,869 - INFO - Marking path at: (8, 19)
# 2024-11-24 00:33:47,869 - INFO - Marking path at: (7, 19)
# 2024-11-24 00:33:47,873 - INFO - Marking path at: (7, 18)
# 2024-11-24 00:33:47,873 - INFO - Marking path at: (8, 18)
# 2024-11-24 00:33:47,874 - INFO - Marking path at: (9, 18)
# 2024-11-24 00:33:47,874 - INFO - Marking path at: (10, 18)
# 2024-11-24 00:33:47,875 - INFO - Marking path at: (11, 18)
# 2024-11-24 00:33:47,875 - INFO - Marking path at: (12, 18)
# 2024-11-24 00:33:47,876 - INFO - Marking path at: (13, 18)
# 2024-11-24 00:33:47,876 - INFO - Marking path at: (13, 17)
# 2024-11-24 00:33:47,876 - INFO - Marking path at: (12, 17)
# 2024-11-24 00:33:47,877 - INFO - Marking path at: (11, 17)
# 2024-11-24 00:33:47,877 - INFO - Marking path at: (10, 17)
# 2024-11-24 00:33:47,877 - INFO - Marking path at: (9, 17)
# 2024-11-24 00:33:47,878 - INFO - Marking path at: (8, 17)
# 2024-11-24 00:33:47,878 - INFO - Marking path at: (7, 17)
# 2024-11-24 00:33:47,878 - INFO - Marking path at: (6, 17)
# 2024-11-24 00:33:47,878 - INFO - Marking path at: (5, 17)
# 2024-11-24 00:33:47,879 - INFO - Marking path at: (4, 17)
# 2024-11-24 00:33:47,880 - INFO - Marking path at: (4, 18)
# 2024-11-24 00:33:47,880 - INFO - Marking path at: (5, 18)
# 2024-11-24 00:33:47,880 - INFO - Marking path at: (5, 19)
# 2024-11-24 00:33:47,881 - INFO - Marking path at: (4, 19)
# 2024-11-24 00:33:47,881 - INFO - Marking path at: (4, 20)
# 2024-11-24 00:33:47,881 - INFO - Marking path at: (5, 20)
# 2024-11-24 00:33:47,882 - INFO - Marking path at: (5, 21)
# 2024-11-24 00:33:47,883 - INFO - Marking path at: (4, 21)
# 2024-11-24 00:33:47,883 - INFO - Marking path at: (3, 21)
# 2024-11-24 00:33:47,883 - INFO - Marking path at: (2, 21)
# 2024-11-24 00:33:47,884 - INFO - Marking path at: (1, 21)
# 2024-11-24 00:33:47,884 - INFO - Marking path at: (1, 20)
# 2024-11-24 00:33:47,884 - INFO - Marking path at: (2, 20)
# 2024-11-24 00:33:47,884 - INFO - Marking path at: (2, 19)
# 2024-11-24 00:33:47,885 - INFO - Marking path at: (1, 19)
# 2024-11-24 00:33:47,885 - INFO - Marking path at: (1, 18)
# 2024-11-24 00:33:47,885 - INFO - Marking path at: (2, 18)
# 2024-11-24 00:33:47,886 - INFO - Marking path at: (2, 17)
# 2024-11-24 00:33:47,886 - INFO - Marking path at: (1, 17)
# 2024-11-24 00:33:47,886 - INFO - Marking path at: (1, 16)
# 2024-11-24 00:33:47,887 - INFO - Marking path at: (2, 16)
# 2024-11-24 00:33:47,887 - INFO - Marking path at: (2, 15)
# 2024-11-24 00:33:47,887 - INFO - Marking path at: (1, 15)
# 2024-11-24 00:33:47,888 - INFO - Marking path at: (1, 14)
# 2024-11-24 00:33:47,888 - INFO - Marking path at: (2, 14)
# 2024-11-24 00:33:47,888 - INFO - Marking path at: (2, 13)
# 2024-11-24 00:33:47,888 - INFO - Marking path at: (1, 13)
# 2024-11-24 00:33:47,889 - INFO - Marking path at: (1, 12)
# 2024-11-24 00:33:47,889 - INFO - Marking path at: (2, 12)
# 2024-11-24 00:33:47,889 - INFO - Marking path at: (2, 11)
# 2024-11-24 00:33:47,889 - INFO - Marking path at: (1, 11)
# 2024-11-24 00:33:47,890 - INFO - Marking path at: (1, 10)
# 2024-11-24 00:33:47,890 - INFO - Marking path at: (2, 10)
# 2024-11-24 00:33:47,890 - INFO - Marking path at: (2, 9)
# 2024-11-24 00:33:47,890 - INFO - Marking path at: (1, 9)
# 2024-11-24 00:33:47,890 - INFO - Marking path at: (1, 8)
# 2024-11-24 00:33:47,891 - INFO - Marking path at: (2, 8)
# 2024-11-24 00:33:47,891 - INFO - Marking path at: (2, 7)
# 2024-11-24 00:33:47,891 - INFO - Marking path at: (1, 7)
# 2024-11-24 00:33:47,891 - INFO - Marking path at: (1, 6)
# 2024-11-24 00:33:47,892 - INFO - Marking path at: (2, 6)
# 2024-11-24 00:33:47,892 - INFO - Marking path at: (2, 5)
# 2024-11-24 00:33:47,892 - INFO - Marking path at: (1, 5)
# 2024-11-24 00:33:47,893 - INFO - Marking path at: (1, 4)
# 2024-11-24 00:33:47,893 - INFO - Marking path at: (2, 4)
# 2024-11-24 00:33:47,893 - INFO - Marking path at: (2, 3)
# 2024-11-24 00:33:47,894 - INFO - Maze with path:
# 2024-11-24 00:33:47,894 - INFO - ==========================================================================
# 2024-11-24 00:33:47,895 - INFO - |  S─│─│─│─│─│─│─│─│─│            |                             ─│─│─│─│ |
# 2024-11-24 00:33:47,895 - INFO - |  ─│─│─│─│─│─│─│─│─││            |                             ││││││││ |
# 2024-11-24 00:33:47,895 - INFO - |====================│            |                             ││││││││ |
# 2024-11-24 00:33:47,896 - INFO - |                │─│─│                                          ││││││││ |
# 2024-11-24 00:33:47,896 - INFO - |                ││─│─                                        * ││││││││ |
# 2024-11-24 00:33:47,896 - INFO - |                │ ===================                          ││││││││ |
# 2024-11-24 00:33:47,898 - INFO - |                │─│─│─│─│─│─│─│─│─│─│                          ││││││││ |
# 2024-11-24 00:33:47,898 - INFO - |                │││││││││││││││││││││                          ││││││││ |
# 2024-11-24 00:33:47,898 - INFO - |                │││││││││││││││││││││                          ││││││││ |
# 2024-11-24 00:33:47,900 - INFO - |                │││││││││││││││││││││==========================││││││││ |
# 2024-11-24 00:33:47,900 - INFO - |                │││││││││││││││││││││─│─│─│─│─│─│─│─│─│─│─│─│─│││││││││ |
# 2024-11-24 00:33:47,900 - INFO - |                ││││││││││││││││││││││││││││││─││││││││││││││││││││││││ |
# 2024-11-24 00:33:47,900 - INFO - |                ─│─│─│─│─│─│─│─│││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,900 - INFO - |================================││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,901 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,901 - INFO - |                     *          ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,901 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,903 - INFO - |                                ││││││││││││││ |│││││││││││││││││││││││ |
# 2024-11-24 00:33:47,903 - INFO - |                                ─│─│─│─│─│─│─│ |─│─│─│─│─│─│─│─│─│─│─│─*|
# 2024-11-24 00:33:47,903 - INFO - ==========================================================================
# 2024-11-24 00:33:47,904 - INFO - Saving the grid to file: output_dfs_shortest_path.txt
# 2024-11-24 00:33:47,905 - INFO - Grid successfully saved to output_dfs_shortest_path.txt
# 2024-11-24 00:33:47,905 - INFO - Result saved to output_dfs_shortest_path.txt

# %%
# Test

# Please write your code test here!

# %% [markdown]
# ## Task 2.5
#
# **[20 Point(s)]**

# %% [markdown]
# ## Iterative Deepening Search [20 Points]
#
# Implement *Iterative Deepening Search*. Make sure to fill the docstring of the function and add typehints such that one can understand what arguments are expected and what it returns.
#
# Run the search algorithm for each map and save the results into `./data/results/<search_algo_name>_<map_number>.txt`.

# %%
def iterative_deepening_depth_first_search(maze_map, monitor=False):
    """ This function implements the iterative deepening depth-first search (IDDFS) algorithm.
    THe key point about IDDFS is that it uses depth-limited depth-first search with an incrementing depth
    limit and thereby explores the node basically breadth first, but at the same time makes use of the space
    saving procedure of DFS, which keeps only b number of nodes in the memory, with b being the branching
    factor of the current node.
    
    Parameters
    ----------
    maze_map : [type]
        [description]
    monitor : bool
        Flag for enabling or disabling command line output for the search run. Defaults to False: No
        monitoring.
    
    Returns
    -------
    [type]
        [description]
    """

    
    

    # YOUR CODE HERE
    #raise NotImplementedError()

# %%
# Test

# Please write your code test here!
